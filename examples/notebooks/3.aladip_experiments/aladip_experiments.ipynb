# %% [markdown]
# # Alanine Dipeptide Experiments
#
# This notebook contains experiments on the alanine dipeptide example.
#
# 10 ns trajectories at 300, 400 and 500 K are available as input. The value of the coordinates and the $\phi$ and $\psi$ angles were saved every 1 ps. Thus we have $10^4$ frames for each trajectory and the same number of samples for the $\phi$ and $\psi$ torsion angles.
#
# The typical free energy surface of alanine dipeptide is shown below.
#
# <center><img src="../../../deep_cartograph/data/alanine_dipeptide/aldip.png" width="800"/></center>
#
# In this system there are two main transitions.
#
# - Transitions between C5 and C7eq (fast transition)
# - Transition between C7eq or C5 and C7ax (slow transition)
#
# Plotting the time series we can see how slow is each transition:

# %%
from deep_cartograph.modules.plumed.colvars import read_colvars
import importlib.resources as resources
from deep_cartograph import data

import matplotlib.pyplot as plt
import math

# Get the path to the data
data_folder = resources.files(data)

temperature = 500 # K
max_time = 200    # ps
font_size = 12

models = ['pca', 'ae', 'vae', 'tica', 'deep_tica']

# Find csv with projected trajectory onto phi psi
phi_psi_path = f"{data_folder}/alanine_dipeptide/input/{temperature}K/phi_psi.dat"

# Read the data
phi_psi = read_colvars(phi_psi_path)

# Convert time from ns to ps
phi_psi['time'] = phi_psi['time'] * 1000

# Sample just the first 200 ps for the plot
phi_psi = phi_psi[phi_psi['time'] < max_time]

# Plot time series of phi and psi
plt.figure(figsize=(10, 5))

# Plot phi and psi without lines and with different colors
plt.plot(phi_psi['time'], phi_psi['phi'], label='Phi', linestyle='--', marker='x', linewidth=1)
plt.plot(phi_psi['time'], phi_psi['psi'], label='Psi', linestyle='--', marker='x', linewidth=1)

plt.xlim(0, max_time)
plt.ylim(-math.pi, math.pi)

plt.xticks(fontsize=font_size)
plt.yticks(fontsize=font_size)

plt.xlabel('Time (ps)', fontsize=font_size)
plt.ylabel('Angle (radians)', fontsize=font_size)

plt.legend(fontsize=font_size)

plt.title(f'Phi and Psi angles at {temperature}K', fontsize=font_size)

plt.show()

# %% [markdown]
# Clearly $\phi$ encodes the slowest transition to and from C7ax.

# %%
from deep_cartograph.deep_carto import deep_cartograph
from IPython.display import display, HTML
from typing import Literal, Dict
from decimal import Decimal
import pandas as pd
import logging
import shutil
import yaml
import time
import os


# Set logging level
logging.basicConfig(level=logging.INFO)

font_size = 12

def run_deep_cartograph(configuration: Dict, features: Literal['torsions', 'distances'], temperature: int, test_name: str = None, 
                        traj_path: str = None, topology_path: str = None): 
    """
    Runs deep cartograph using one of the alanine dipeptide trajectories at a certain temperature. Using one of the feature dictionaries
    and the provided configuration.

    Input
    -----

        configuration: configuration for all the steps of the deep cartograph main workflow
        features:      choice of features to use to train/compute the CVs
        temperature:   temperature of the alanine dipeptide simulations to use
        test_name:     name of the test that will be used as output folder name
        traj_path:     path to the trajectory file
        topology_path: path to the topology file
    """

    # Input paths
    input_path = f"{data_folder}/alanine_dipeptide/input/"

    if not traj_path:
        traj_folder = os.path.join(input_path, f"{temperature}K")
        traj_path = os.path.join(traj_folder, "trajectory.xtc")
    
    if not topology_path:
        top_path = os.path.join(input_path, 'topology.pdb')
        
    # Output folder
    output_folder = f"{data_folder}/alanine_dipeptide/output/{temperature}K/{features}"

    if test_name:
        output_folder = os.path.join(output_folder, test_name)

    # Clean output folder
    if os.path.exists(output_folder):
        shutil.rmtree(output_folder)

    # Run workflow 
    deep_cartograph(
        configuration = configuration,
        trajectory_data = traj_path,
        topology_data = top_path,
        output_folder = output_folder)

def show_results(features: Literal['torsions', 'distances'], temperature: int, model_name: str, test_name: str = None,
                 phi_psi_path: str = None):
    """
    Show the most important results for a specific model trained with deep cartograph

    Input
    -----

        features:     choice of input features used
        temperature:  temperature of the alanine dipeptide simulations used
        model_name:   type of cv to analyze (pca, ae, tica or deep_tica)
        test_name:    name of the test that was used for the output folder
    """

    def get_alpha(size):
        """
        Compute alpha value for the scatter plot

        Input
        -----

            size: size of the dataset

        Output
        ------

            alpha: alpha value
        """

        if size > 5000:
            alpha = 0.3
        elif size > 1000:
            alpha = 0.5
        elif size > 500:
            alpha = 0.7
        else:
            alpha = 1.0

        return alpha
    
    def show_score(score_path):
        """
        Print score path in a nice format 

        Input
        -----

            score_path: path to the score file
        """

        # Read score
        with open(score_path, 'r') as file:
            score = file.read()

        # Print score in scientific notation
        print(f"Final model score: {Decimal(score):.4E}")

    def show_eigenvalues(eig_path):
        """
        Print eigenvalues in a nice format

        Input
        -----

            eig_path: path to the eigenvalues file
        """

        # Read eigenvalues
        with open(eig_path, 'r') as file:
            eigenvalues = file.readlines()

        # Print eigenvalues
        for i, eig in enumerate(eigenvalues):
            print(f"Eigenvalue {i+1}: {Decimal(eig):.4E}")
            
    def ramachandran_projection(phi_psi_path: str, cv_path: str):   
        """
        Project the phi, psi samples coloring them by the CV values

        Input
        -----

            phi_psi_path: path to plumed colvars file with phi, psi data along trajectory
            cv_path:      path to csv file with cv data along trajectory
        """

        import matplotlib.pyplot as plt
        from pathlib import Path

        # Read phi psi data as pandas dataframe
        phi_psi_df = read_colvars(phi_psi_path)

        # Find size of dataframe
        size = phi_psi_df.shape[0]

        # Drop "time" column
        phi_psi_df = phi_psi_df.drop(columns = ['time'])

        # Read CV csv as pandas dataframe
        cv_df = pd.read_csv(cv_path)

        # Find model path
        model_path = Path(cv_path).parent

        # Drop "cluster" column if present
        if 'cluster' in cv_df.columns:
            cv_df = cv_df.drop(columns = ['cluster'])

        # Find the rest of the columns / CV components
        components = cv_df.columns

        images_html = []

        # Check if both dataframes have the same number of samples
        delta_samples = phi_psi_df['phi'].shape[0] - cv_df[components[0]].shape[0]

        # If not, the CV is a Deep TICA model with a lag time different from 0, discard the last delta_samples from the phi, psi data
        if delta_samples > 0:
            phi_psi_df = phi_psi_df.iloc[:-delta_samples]

        # For each CV column in the cv_df
        for component in components:
            
            plt.figure()  

            # Add limits to the plot (-pi, pi)
            plt.xlim(-math.pi, math.pi)
            plt.ylim(-math.pi, math.pi)
            
            # Create scatter plot
            scatter = plt.scatter(phi_psi_df['phi'], phi_psi_df['psi'], c=cv_df[component], s=8, alpha=get_alpha(size))

            # Set labels and title
            plt.xlabel('Phi', fontsize=font_size)
            plt.ylabel('Psi', fontsize=font_size)
            plt.title(f'{component} projection onto Ramachandran space', fontsize=font_size)
            
            # Increase tick size
            plt.xticks(fontsize=font_size)
            plt.yticks(fontsize=font_size)

            # Add colorbar
            cbar = plt.colorbar(scatter)
            cbar.set_label(component, fontsize=font_size)
            cbar.ax.tick_params(labelsize=font_size)
                
            # Set alpha for the colorbar by modifying the colormap
            cbar.solids.set_alpha(1.0)  

            # Create path for figure
            figure_path = os.path.join(model_path, f'{component}_ramachandran.png')

            # Generate HTML image tag and append to list
            timestamp = int(time.time()) # Add timestamp to avoid caching
            images_html.append(f'<img src="{figure_path}?{timestamp}" style="width: 600px; margin-right: 10px;">')

            # Save figure 
            plt.savefig(figure_path)

            # Close figure
            plt.close()

        # Display images
        display(HTML(''.join(images_html)))

    # Output_folder
    output_folder = f"{data_folder}/alanine_dipeptide/output/{temperature}K/{features}"

    if test_name:
        output_folder = os.path.join(output_folder, test_name)

    # Show output folder
    print(f"Output folder: {output_folder}")

    # Find csv with projected trajectory onto phi psi
    if not phi_psi_path:
        phi_psi_path = f"{data_folder}/alanine_dipeptide/input/{temperature}K/phi_psi.dat"

    # Show phi psi path
    print(f"Phi psi path: {phi_psi_path}")

    # Find model path
    model_path = os.path.join(output_folder, "train_colvars", model_name)

    # Find csv with projected trajectory onto CV
    cv_path = os.path.join(model_path, "traj_data", "trajectory", "projected_trajectory.csv")

    # Find score if any
    if model_name in models:
        score_path = os.path.join(model_path, "training", "model_score.txt")
        if os.path.exists(score_path):
            show_score(score_path)
        else:
            print("Score file not found")

    # Find eigenvalues if any
    if model_name == 'deep_tica':
        eig_path = os.path.join(model_path, "training", "eigenvalues.txt")
        if os.path.exists(eig_path):
            show_eigenvalues(eig_path)
        else:
            print("Eigenvalues file not found")

    # Project CV onto Ramachandran space
    ramachandran_projection(phi_psi_path, cv_path)

    # Paths to images
    loss = os.path.join(model_path, 'loss.png')
    eigenvalues = os.path.join(model_path, 'eigenvalues.png')
    paths = [loss, eigenvalues]

    # Generate HTML image tags
    timestamp = int(time.time()) # Add timestamp to avoid caching
    images_html = [f'<img src="{path}?{timestamp}" style="width: 600px; margin-right: 10px;">' for path in paths if os.path.exists(path)]

    # Display images
    display(HTML(''.join(images_html)))

# %% [markdown]
# ## Using torsion angles
#
# Let's see if the autoencoder and the deep-tica models are able to identify the slow modes in the trajectory.
#
# Here we use real torsion angles between heavy atoms as input features, see the 'dihedral_group' definition in the input YAML. It should be relatively easy for the models to identify the slow torsion angles $\phi$ and $\psi$.

# %% [markdown]
# ### Testing batch size
#
# Train the Autoencoder or the Deep TICA model with different batch sizes.
#
# In general, we know that smaller batch sizes can introduce more noise in the gradient updates, which can help the model scape local or sharp minima and find better solutions. Thus generalize better (see relation between training and validation loss). Smaller batch sizes can also slow down the training process but in this case we are using small models and small datasets so it should not be a problem.

# %%
# Choose the features to work with (torsions or distances)
features = 'torsions'

# Choose temperature of the simulations (300 K shows just one transition, 400 K starts to show two, 500 K clearly shows two transitions)
temperature = 500

# Load initial configuration
config_path = f"{data_folder}/alanine_dipeptide/input/{features}_config.yml"

with open(config_path, 'r') as file:
    configuration = yaml.load(file, Loader = yaml.FullLoader)

# Select model
configuration['train_colvars']['cvs'] = models

# Select batch sizes - Alanine trajs have a total of 10000 samples
batch_sizes = [128, 2048]

for batch_size in batch_sizes:

    # Name of the test
    test_name = f'bs_{batch_size}'

    # Make a copy of the initial configuration
    test_configuration = configuration.copy()

    # Update batch size
    test_configuration['train_colvars']['common']['training']['general']['batch_size'] = batch_size

    # Run deep cartograph
    run_deep_cartograph(test_configuration, features, temperature, test_name)
# Out:
# INFO:deep_cartograph:================
# INFO:deep_cartograph:Analyze geometry
# INFO:deep_cartograph:================
# INFO:deep_cartograph:Elapsed time (Analyze geometry): 00 h 00 min 00 s
# INFO:deep_cartograph:================
# INFO:deep_cartograph:Compute features
# INFO:deep_cartograph:================
# /home/pnavarro/.conda/envs/deep_cartograph/lib/python3.10/site-packages/MDAnalysis/topology/PDBParser.py:350: UserWarning: Element information is missing, elements attribute will not be populated. If needed these can be guessed using universe.guess_TopologyAttrs(context='default', to_guess=['elements']).
#   warnings.warn("Element information is missing, elements attribute "
# INFO:MDAnalysis.core.universe:attribute types has been guessed successfully.
# INFO:MDAnalysis.core.universe:attribute masses has been guessed successfully.
# /home/pnavarro/.conda/envs/deep_cartograph/lib/python3.10/site-packages/MDAnalysis/coordinates/PDB.py:1154: UserWarning: Found no information for attr: 'elements' Using default value of ' '
#   warnings.warn("Found no information for attr: '{}'"
# /home/pnavarro/.conda/envs/deep_cartograph/lib/python3.10/site-packages/MDAnalysis/coordinates/PDB.py:1154: UserWarning: Found no information for attr: 'formalcharges' Using default value of '0'
#   warnings.warn("Found no information for attr: '{}'"
# INFO:MDAnalysis.core.universe:attribute types has been guessed successfully.
# INFO:MDAnalysis.core.universe:attribute masses has been guessed successfully.
# INFO:deep_cartograph.modules.md.md:Topology does not contain bonds. Bonds will be guessed using a distance criterion (bond_length < 2.0).
# WARNING:deep_cartograph.modules.md.md:Topology does not contain bonds. Using a distance criterion (bond_length < 2.0) to guess bonds.
# INFO:MDAnalysis.core.universe:attribute types has been guessed successfully.
# INFO:MDAnalysis.core.universe:attribute masses has been guessed successfully.
# INFO:deep_cartograph:Computing features for trajectory with topology topology...
# /home/pnavarro/.conda/envs/deep_cartograph/lib/python3.10/site-packages/MDAnalysis/topology/PDBParser.py:350: UserWarning: Element information is missing, elements attribute will not be populated. If needed these can be guessed using universe.guess_TopologyAttrs(context='default', to_guess=['elements']).
#   warnings.warn("Element information is missing, elements attribute "
# INFO:MDAnalysis.core.universe:attribute types has been guessed successfully.
# INFO:MDAnalysis.core.universe:attribute masses has been guessed successfully.
# INFO:MDAnalysis.core.universe:attribute types has been guessed successfully.
# INFO:MDAnalysis.core.universe:attribute masses has been guessed successfully.
# INFO:deep_cartograph.modules.plumed.cli:Executing PLUMED command: plumed driver --plumed /home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/torsions/bs_128/compute_features/trajectory/plumed_input.dat --mf_xtc /home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/input/500K/trajectory.xtc --natoms 22
# INFO:deep_cartograph.modules.plumed.cli:Restored working directory to: /home/pnavarro/repos/mlcolvar
# INFO:deep_cartograph:Elapsed time (Compute features): 00 h 00 min 01 s
# INFO:deep_cartograph:==================
# INFO:deep_cartograph:Filtering features
# INFO:deep_cartograph:==================
# INFO:deep_cartograph:Finding the features that contains the most information about the transitions or conformational changes.
# INFO:deep_cartograph:The following algorithms are available:
# INFO:deep_cartograph:- Hartigan's dip test filter. Keeps features that are not unimodal.
# INFO:deep_cartograph:- Shannon entropy filter. Keeps features with entropy greater than a threshold.
# INFO:deep_cartograph:- Standard deviation filter. Keeps features with standard deviation greater than a threshold.
# INFO:deep_cartograph:Note that the all features must be in the same units to apply the entropy and standard deviation filters meaningfully.
# INFO:deep_cartograph.modules.features.filter:Initializing Filter
# INFO:deep_cartograph.modules.features.filter:Initial size of features set (only common features): 20.
# INFO:deep_cartograph.modules.features.filter:Processed 2/20 features. Estimated time left: 0.46 seconds.
# INFO:deep_cartograph.modules.features.filter:Processed 4/20 features. Estimated time left: 0.40 seconds.
# INFO:deep_cartograph.modules.features.filter:Processed 6/20 features. Estimated time left: 0.35 seconds.
# INFO:deep_cartograph.modules.features.filter:Processed 8/20 features. Estimated time left: 0.30 seconds.
# INFO:deep_cartograph.modules.features.filter:Processed 10/20 features. Estimated time left: 0.25 seconds.
# INFO:deep_cartograph.modules.features.filter:Processed 12/20 features. Estimated time left: 0.20 seconds.
# INFO:deep_cartograph.modules.features.filter:Processed 14/20 features. Estimated time left: 0.14 seconds.
# INFO:deep_cartograph.modules.features.filter:Processed 16/20 features. Estimated time left: 0.09 seconds.
# INFO:deep_cartograph.modules.features.filter:Processed 18/20 features. Estimated time left: 0.05 seconds.
# INFO:deep_cartograph.modules.features.filter:Processed 20/20 features. Estimated time left: 0.00 seconds.
# INFO:deep_cartograph.modules.features.filter:Filtered 6 features.
# INFO:deep_cartograph:Elapsed time (Filter features): 00 h 00 min 00 s
# INFO:deep_cartograph.modules.common.common: Using features in /home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/torsions/bs_128/filter_features/filtered_features.txt
# INFO:deep_cartograph:================================
# INFO:deep_cartograph:Training of Collective Variables
# INFO:deep_cartograph:================================
# INFO:deep_cartograph:Training of collective variables using the mlcolvar library.
# INFO:deep_cartograph.tools.train_colvars.train_colvars_workflow:Collective variables to compute: ['pca', 'ae', 'vae', 'tica', 'deep_tica']
# INFO:deep_cartograph.modules.cv_learning.cv_calculator:Creating PCA Calculator ...
# INFO:deep_cartograph.modules.cv_learning.cv_calculator:Reading training data from colvars files...
# INFO:deep_cartograph.modules.cv_learning.cv_calculator:Number of features: 14
# INFO:deep_cartograph.modules.cv_learning.cv_calculator:Number of samples: 10001
# /home/pnavarro/.conda/envs/deep_cartograph/lib/python3.10/site-packages/MDAnalysis/topology/PDBParser.py:350: UserWarning: Element information is missing, elements attribute will not be populated. If needed these can be guessed using universe.guess_TopologyAttrs(context='default', to_guess=['elements']).
#   warnings.warn("Element information is missing, elements attribute "
# INFO:MDAnalysis.core.universe:attribute types has been guessed successfully.
# INFO:MDAnalysis.core.universe:attribute masses has been guessed successfully.
# /home/pnavarro/.conda/envs/deep_cartograph/lib/python3.10/site-packages/MDAnalysis/coordinates/PDB.py:1154: UserWarning: Found no information for attr: 'elements' Using default value of ' '
#   warnings.warn("Found no information for attr: '{}'"
# /home/pnavarro/.conda/envs/deep_cartograph/lib/python3.10/site-packages/MDAnalysis/coordinates/PDB.py:1154: UserWarning: Found no information for attr: 'formalcharges' Using default value of '0'
#   warnings.warn("Found no information for attr: '{}'"
# INFO:deep_cartograph.modules.common.common:Starting compression to '/home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/torsions/bs_128/train_colvars/pca/model.zip'...
# INFO:deep_cartograph.modules.common.common:Successfully created zip file: '/home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/torsions/bs_128/train_colvars/pca/model.zip'
# INFO:deep_cartograph.modules.cv_learning.cv_calculator:Model saved to /home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/torsions/bs_128/train_colvars/pca/model.zip
# INFO:deep_cartograph.tools.train_colvars.train_colvars_workflow:Processing trajectory: trajectory
# INFO:deep_cartograph.tools.train_colvars.train_colvars_workflow:Corresponding colvars file: /home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/torsions/bs_128/compute_features/trajectory/colvars.dat
# INFO:deep_cartograph.tools.train_colvars.train_colvars_workflow:Corresponding topology file: /home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/input/topology.pdb
# /home/pnavarro/.conda/envs/deep_cartograph/lib/python3.10/site-packages/MDAnalysis/topology/PDBParser.py:350: UserWarning: Element information is missing, elements attribute will not be populated. If needed these can be guessed using universe.guess_TopologyAttrs(context='default', to_guess=['elements']).
#   warnings.warn("Element information is missing, elements attribute "
# INFO:MDAnalysis.core.universe:attribute types has been guessed successfully.
# INFO:MDAnalysis.core.universe:attribute masses has been guessed successfully.
# /home/pnavarro/.conda/envs/deep_cartograph/lib/python3.10/site-packages/MDAnalysis/coordinates/PDB.py:1154: UserWarning: Found no information for attr: 'elements' Using default value of ' '
#   warnings.warn("Found no information for attr: '{}'"
# /home/pnavarro/.conda/envs/deep_cartograph/lib/python3.10/site-packages/MDAnalysis/coordinates/PDB.py:1154: UserWarning: Found no information for attr: 'formalcharges' Using default value of '0'
#   warnings.warn("Found no information for attr: '{}'"
# INFO:MDAnalysis.core.universe:attribute types has been guessed successfully.
# INFO:MDAnalysis.core.universe:attribute masses has been guessed successfully.
# /home/pnavarro/.conda/envs/deep_cartograph/lib/python3.10/site-packages/MDAnalysis/topology/PDBParser.py:350: UserWarning: Element information is missing, elements attribute will not be populated. If needed these can be guessed using universe.guess_TopologyAttrs(context='default', to_guess=['elements']).
#   warnings.warn("Element information is missing, elements attribute "
# INFO:MDAnalysis.core.universe:attribute types has been guessed successfully.
# INFO:MDAnalysis.core.universe:attribute masses has been guessed successfully.
# INFO:deep_cartograph.modules.common.common:Starting compression to '/home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/torsions/bs_128/train_colvars/pca/traj_data/trajectory/plumed_inputs/plumed_pca_unbiased.zip'...
# INFO:deep_cartograph.modules.common.common:Successfully created zip file: '/home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/torsions/bs_128/train_colvars/pca/traj_data/trajectory/plumed_inputs/plumed_pca_unbiased.zip'
# INFO:MDAnalysis.core.universe:attribute types has been guessed successfully.
# INFO:MDAnalysis.core.universe:attribute masses has been guessed successfully.
# INFO:deep_cartograph.modules.common.common:Starting compression to '/home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/torsions/bs_128/train_colvars/pca/traj_data/trajectory/plumed_inputs/plumed_pca_biased.zip'...
# INFO:deep_cartograph.modules.common.common:Successfully created zip file: '/home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/torsions/bs_128/train_colvars/pca/traj_data/trajectory/plumed_inputs/plumed_pca_biased.zip'
# INFO:deep_cartograph.modules.cv_learning.cv_calculator:Creating AE Calculator ...
# INFO:deep_cartograph.modules.cv_learning.cv_calculator:Reading training data from colvars files...
# INFO:deep_cartograph.modules.cv_learning.cv_calculator:Number of features: 14
# INFO:deep_cartograph.modules.cv_learning.cv_calculator:Number of samples: 10001
# INFO:deep_cartograph.modules.cv_learning.cv_calculator:Training AE ...
# INFO:deep_cartograph.modules.cv_learning.cv_calculator:Model architecture: AutoEncoderCV(
#   (loss_fn): MSELoss()
#   (norm_in): Normalization(in_features=14, out_features=14, mode=custom)
#   (encoder): FeedForward(
#     (nn): Sequential(
#       (0): Linear(in_features=14, out_features=8, bias=True)
#       (1): LeakyReLU(negative_slope=0.01, inplace=True)
#       (2): Linear(in_features=8, out_features=4, bias=True)
#       (3): LeakyReLU(negative_slope=0.01, inplace=True)
#       (4): Linear(in_features=4, out_features=1, bias=True)
#     )
#   )
#   (decoder): FeedForward(
#     (nn): Sequential(
#       (0): Linear(in_features=1, out_features=4, bias=True)
#       (1): LeakyReLU(negative_slope=0.01, inplace=True)
#       (2): Linear(in_features=4, out_features=8, bias=True)
#       (3): LeakyReLU(negative_slope=0.01, inplace=True)
#       (4): Linear(in_features=8, out_features=14, bias=True)
#     )
#   )
# )
# /home/pnavarro/.conda/envs/deep_cartograph/lib/python3.10/site-packages/lightning/fabric/plugins/environments/slurm.py:204: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/pnavarro/.conda/envs/deep_cartograph/lib/p ...
# INFO: GPU available: False, used: False
# INFO:lightning.pytorch.utilities.rank_zero:GPU available: False, used: False
# INFO: TPU available: False, using: 0 TPU cores
# INFO:lightning.pytorch.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO: HPU available: False, using: 0 HPUs
# INFO:lightning.pytorch.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:
#   | Name    | Type          | Params | Mode  | In sizes | Out sizes
# -------------------------------------------------------------------------
# 0 | loss_fn | MSELoss       | 0      | train | ?        | ?
# 1 | norm_in | Normalization | 0      | train | [1, 14]  | [1, 14]
# 2 | encoder | FeedForward   | 161    | train | [1, 14]  | [1, 1]
# 3 | decoder | FeedForward   | 174    | train | ?        | ?
# -------------------------------------------------------------------------
# 335       Trainable params
# 0         Non-trainable params
# 335       Total params
# 0.001     Total estimated model params size (MB)
# 16        Modules in train mode
# 0         Modules in eval mode
# INFO:lightning.pytorch.callbacks.model_summary:
#   | Name    | Type          | Params | Mode  | In sizes | Out sizes
# -------------------------------------------------------------------------
# 0 | loss_fn | MSELoss       | 0      | train | ?        | ?
# 1 | norm_in | Normalization | 0      | train | [1, 14]  | [1, 14]
# 2 | encoder | FeedForward   | 161    | train | [1, 14]  | [1, 1]
# 3 | decoder | FeedForward   | 174    | train | ?        | ?
# -------------------------------------------------------------------------
# 335       Trainable params
# 0         Non-trainable params
# 335       Total params
# 0.001     Total estimated model params size (MB)
# 16        Modules in train mode
# 0         Modules in eval mode
# INFO: `Trainer.fit` stopped: `max_epochs=100` reached.
# INFO:lightning.pytorch.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=100` reached.
# INFO:deep_cartograph.modules.cv_learning.cv_calculator:Successfully loaded the 'last' model from: /home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/torsions/bs_128/train_colvars/ae/training/checkpoints/last.ckpt
# INFO:deep_cartograph.modules.cv_learning.cv_calculator:  -> Best Overall Score:      0.00564
# INFO:deep_cartograph.modules.cv_learning.cv_calculator:  -> Last Model Score:          0.00564
# WARNING:deep_cartograph.modules.cv_learning.cv_calculator:Learning rate not found in metrics. Learning rate plot will not be generated.
# INFO:deep_cartograph.modules.common.common:Starting compression to '/home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/torsions/bs_128/train_colvars/ae/training/training_metrics.zip'...
# INFO:deep_cartograph.modules.common.common:Successfully created zip file: '/home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/torsions/bs_128/train_colvars/ae/training/training_metrics.zip'
# INFO:deep_cartograph.modules.cv_learning.cv_calculator:Training metrics saved to /home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/torsions/bs_128/train_colvars/ae/training/training_metrics.zip
# INFO:deep_cartograph.modules.cv_learning.cv_calculator:Projecting data onto AE ...
# /home/pnavarro/.conda/envs/deep_cartograph/lib/python3.10/site-packages/MDAnalysis/topology/PDBParser.py:350: UserWarning: Element information is missing, elements attribute will not be populated. If needed these can be guessed using universe.guess_TopologyAttrs(context='default', to_guess=['elements']).
#   warnings.warn("Element information is missing, elements attribute "
# INFO:MDAnalysis.core.universe:attribute types has been guessed successfully.
# INFO:MDAnalysis.core.universe:attribute masses has been guessed successfully.
# /home/pnavarro/.conda/envs/deep_cartograph/lib/python3.10/site-packages/MDAnalysis/coordinates/PDB.py:1154: UserWarning: Found no information for attr: 'elements' Using default value of ' '
#   warnings.warn("Found no information for attr: '{}'"
# /home/pnavarro/.conda/envs/deep_cartograph/lib/python3.10/site-packages/MDAnalysis/coordinates/PDB.py:1154: UserWarning: Found no information for attr: 'formalcharges' Using default value of '0'
#   warnings.warn("Found no information for attr: '{}'"
# INFO:deep_cartograph.modules.common.common:Starting compression to '/home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/torsions/bs_128/train_colvars/ae/model.zip'...
# INFO:deep_cartograph.modules.common.common:Successfully created zip file: '/home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/torsions/bs_128/train_colvars/ae/model.zip'
# INFO:deep_cartograph.modules.cv_learning.cv_calculator:Model saved to /home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/torsions/bs_128/train_colvars/ae/model.zip
# KEY:  data
# INFO:deep_cartograph.tools.train_colvars.train_colvars_workflow:Processing trajectory: trajectory
# INFO:deep_cartograph.tools.train_colvars.train_colvars_workflow:Corresponding colvars file: /home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/torsions/bs_128/compute_features/trajectory/colvars.dat
# INFO:deep_cartograph.tools.train_colvars.train_colvars_workflow:Corresponding topology file: /home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/input/topology.pdb
# /home/pnavarro/.conda/envs/deep_cartograph/lib/python3.10/site-packages/MDAnalysis/topology/PDBParser.py:350: UserWarning: Element information is missing, elements attribute will not be populated. If needed these can be guessed using universe.guess_TopologyAttrs(context='default', to_guess=['elements']).
#   warnings.warn("Element information is missing, elements attribute "
# INFO:MDAnalysis.core.universe:attribute types has been guessed successfully.
# INFO:MDAnalysis.core.universe:attribute masses has been guessed successfully.
# /home/pnavarro/.conda/envs/deep_cartograph/lib/python3.10/site-packages/MDAnalysis/coordinates/PDB.py:1154: UserWarning: Found no information for attr: 'elements' Using default value of ' '
#   warnings.warn("Found no information for attr: '{}'"
# /home/pnavarro/.conda/envs/deep_cartograph/lib/python3.10/site-packages/MDAnalysis/coordinates/PDB.py:1154: UserWarning: Found no information for attr: 'formalcharges' Using default value of '0'
#   warnings.warn("Found no information for attr: '{}'"
# INFO:MDAnalysis.core.universe:attribute types has been guessed successfully.
# INFO:MDAnalysis.core.universe:attribute masses has been guessed successfully.
# /home/pnavarro/.conda/envs/deep_cartograph/lib/python3.10/site-packages/MDAnalysis/topology/PDBParser.py:350: UserWarning: Element information is missing, elements attribute will not be populated. If needed these can be guessed using universe.guess_TopologyAttrs(context='default', to_guess=['elements']).
#   warnings.warn("Element information is missing, elements attribute "
# INFO:MDAnalysis.core.universe:attribute types has been guessed successfully.
# INFO:MDAnalysis.core.universe:attribute masses has been guessed successfully.
# INFO:deep_cartograph.modules.common.common:Starting compression to '/home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/torsions/bs_128/train_colvars/ae/traj_data/trajectory/plumed_inputs/plumed_ae_unbiased.zip'...
# INFO:deep_cartograph.modules.common.common:Successfully created zip file: '/home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/torsions/bs_128/train_colvars/ae/traj_data/trajectory/plumed_inputs/plumed_ae_unbiased.zip'
# INFO:MDAnalysis.core.universe:attribute types has been guessed successfully.
# INFO:MDAnalysis.core.universe:attribute masses has been guessed successfully.
# INFO:deep_cartograph.modules.common.common:Starting compression to '/home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/torsions/bs_128/train_colvars/ae/traj_data/trajectory/plumed_inputs/plumed_ae_biased.zip'...
# INFO:deep_cartograph.modules.common.common:Successfully created zip file: '/home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/torsions/bs_128/train_colvars/ae/traj_data/trajectory/plumed_inputs/plumed_ae_biased.zip'
# INFO:deep_cartograph.modules.cv_learning.cv_calculator:Creating VAE Calculator ...
# INFO:deep_cartograph.modules.cv_learning.cv_calculator:Reading training data from colvars files...
# INFO:deep_cartograph.modules.cv_learning.cv_calculator:Number of features: 14
# INFO:deep_cartograph.modules.cv_learning.cv_calculator:Number of samples: 10001
# INFO:deep_cartograph.modules.cv_learning.cv_calculator:Training VAE ...
# INFO:deep_cartograph.modules.cv_learning.cv_calculator:Model architecture: VariationalAutoEncoderCV(
#   (loss_fn): ELBOGaussiansLoss()
#   (norm_in): Normalization(in_features=14, out_features=14, mode=custom)
#   (encoder): FeedForward(
#     (nn): Sequential(
#       (0): Linear(in_features=14, out_features=8, bias=True)
#       (1): LeakyReLU(negative_slope=0.01, inplace=True)
#       (2): Linear(in_features=8, out_features=4, bias=True)
#       (3): LeakyReLU(negative_slope=0.01, inplace=True)
#     )
#   )
#   (mean_nn): Linear(in_features=4, out_features=1, bias=True)
#   (log_var_nn): Linear(in_features=4, out_features=1, bias=True)
#   (decoder): FeedForward(
#     (nn): Sequential(
#       (0): Linear(in_features=1, out_features=4, bias=True)
#       (1): LeakyReLU(negative_slope=0.01, inplace=True)
#       (2): Linear(in_features=4, out_features=8, bias=True)
#       (3): LeakyReLU(negative_slope=0.01, inplace=True)
#       (4): Linear(in_features=8, out_features=14, bias=True)
#     )
#   )
# )
# /home/pnavarro/.conda/envs/deep_cartograph/lib/python3.10/site-packages/lightning/fabric/plugins/environments/slurm.py:204: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/pnavarro/.conda/envs/deep_cartograph/lib/p ...
# INFO: GPU available: False, used: False
# INFO:lightning.pytorch.utilities.rank_zero:GPU available: False, used: False
# INFO: TPU available: False, using: 0 TPU cores
# INFO:lightning.pytorch.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO: HPU available: False, using: 0 HPUs
# INFO:lightning.pytorch.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:
#   | Name       | Type              | Params | Mode  | In sizes | Out sizes
# --------------------------------------------------------------------------------
# 0 | loss_fn    | ELBOGaussiansLoss | 0      | train | ?        | ?
# 1 | norm_in    | Normalization     | 0      | train | [1, 14]  | [1, 14]
# 2 | encoder    | FeedForward       | 156    | train | [1, 14]  | [1, 4]
# 3 | mean_nn    | Linear            | 5      | train | [1, 4]   | [1, 1]
# 4 | log_var_nn | Linear            | 5      | train | ?        | ?
# 5 | decoder    | FeedForward       | 174    | train | ?        | ?
# --------------------------------------------------------------------------------
# 340       Trainable params
# 0         Non-trainable params
# 340       Total params
# 0.001     Total estimated model params size (MB)
# 17        Modules in train mode
# 0         Modules in eval mode
# INFO:lightning.pytorch.callbacks.model_summary:
#   | Name       | Type              | Params | Mode  | In sizes | Out sizes
# --------------------------------------------------------------------------------
# 0 | loss_fn    | ELBOGaussiansLoss | 0      | train | ?        | ?
# 1 | norm_in    | Normalization     | 0      | train | [1, 14]  | [1, 14]
# 2 | encoder    | FeedForward       | 156    | train | [1, 14]  | [1, 4]
# 3 | mean_nn    | Linear            | 5      | train | [1, 4]   | [1, 1]
# 4 | log_var_nn | Linear            | 5      | train | ?        | ?
# 5 | decoder    | FeedForward       | 174    | train | ?        | ?
# --------------------------------------------------------------------------------
# 340       Trainable params
# 0         Non-trainable params
# 340       Total params
# 0.001     Total estimated model params size (MB)
# 17        Modules in train mode
# 0         Modules in eval mode
# KLAAnnealing initialized with type=cyclical, start_beta=0.0, max_beta=0.01)
# INFO: `Trainer.fit` stopped: `max_epochs=100` reached.
# INFO:lightning.pytorch.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=100` reached.
# INFO:deep_cartograph.modules.cv_learning.cv_calculator:Successfully loaded the 'last' model from: /home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/torsions/bs_128/train_colvars/vae/training/checkpoints/last.ckpt
# INFO:deep_cartograph.modules.cv_learning.cv_calculator:  -> Best Overall Score:      0.00549
# INFO:deep_cartograph.modules.cv_learning.cv_calculator:  -> Best Post-Annealing Score: inf
# INFO:deep_cartograph.modules.cv_learning.cv_calculator:  -> Last Model Score:          0.00549
# INFO:deep_cartograph.modules.common.common:Starting compression to '/home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/torsions/bs_128/train_colvars/vae/training/training_metrics.zip'...
# INFO:deep_cartograph.modules.common.common:Successfully created zip file: '/home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/torsions/bs_128/train_colvars/vae/training/training_metrics.zip'
# INFO:deep_cartograph.modules.cv_learning.cv_calculator:Training metrics saved to /home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/torsions/bs_128/train_colvars/vae/training/training_metrics.zip
# INFO:deep_cartograph.modules.cv_learning.cv_calculator:Projecting data onto VAE ...
# /home/pnavarro/.conda/envs/deep_cartograph/lib/python3.10/site-packages/MDAnalysis/topology/PDBParser.py:350: UserWarning: Element information is missing, elements attribute will not be populated. If needed these can be guessed using universe.guess_TopologyAttrs(context='default', to_guess=['elements']).
#   warnings.warn("Element information is missing, elements attribute "
# INFO:MDAnalysis.core.universe:attribute types has been guessed successfully.
# INFO:MDAnalysis.core.universe:attribute masses has been guessed successfully.
# /home/pnavarro/.conda/envs/deep_cartograph/lib/python3.10/site-packages/MDAnalysis/coordinates/PDB.py:1154: UserWarning: Found no information for attr: 'elements' Using default value of ' '
#   warnings.warn("Found no information for attr: '{}'"
# /home/pnavarro/.conda/envs/deep_cartograph/lib/python3.10/site-packages/MDAnalysis/coordinates/PDB.py:1154: UserWarning: Found no information for attr: 'formalcharges' Using default value of '0'
#   warnings.warn("Found no information for attr: '{}'"
# INFO:deep_cartograph.modules.common.common:Starting compression to '/home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/torsions/bs_128/train_colvars/vae/model.zip'...
# INFO:deep_cartograph.modules.common.common:Successfully created zip file: '/home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/torsions/bs_128/train_colvars/vae/model.zip'
# INFO:deep_cartograph.modules.cv_learning.cv_calculator:Model saved to /home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/torsions/bs_128/train_colvars/vae/model.zip
# KEY:  data
# INFO:deep_cartograph.tools.train_colvars.train_colvars_workflow:Processing trajectory: trajectory
# INFO:deep_cartograph.tools.train_colvars.train_colvars_workflow:Corresponding colvars file: /home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/torsions/bs_128/compute_features/trajectory/colvars.dat
# INFO:deep_cartograph.tools.train_colvars.train_colvars_workflow:Corresponding topology file: /home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/input/topology.pdb
# /home/pnavarro/.conda/envs/deep_cartograph/lib/python3.10/site-packages/MDAnalysis/topology/PDBParser.py:350: UserWarning: Element information is missing, elements attribute will not be populated. If needed these can be guessed using universe.guess_TopologyAttrs(context='default', to_guess=['elements']).
#   warnings.warn("Element information is missing, elements attribute "
# INFO:MDAnalysis.core.universe:attribute types has been guessed successfully.
# INFO:MDAnalysis.core.universe:attribute masses has been guessed successfully.
# /home/pnavarro/.conda/envs/deep_cartograph/lib/python3.10/site-packages/MDAnalysis/coordinates/PDB.py:1154: UserWarning: Found no information for attr: 'elements' Using default value of ' '
#   warnings.warn("Found no information for attr: '{}'"
# /home/pnavarro/.conda/envs/deep_cartograph/lib/python3.10/site-packages/MDAnalysis/coordinates/PDB.py:1154: UserWarning: Found no information for attr: 'formalcharges' Using default value of '0'
#   warnings.warn("Found no information for attr: '{}'"
# INFO:MDAnalysis.core.universe:attribute types has been guessed successfully.
# INFO:MDAnalysis.core.universe:attribute masses has been guessed successfully.
# /home/pnavarro/.conda/envs/deep_cartograph/lib/python3.10/site-packages/MDAnalysis/topology/PDBParser.py:350: UserWarning: Element information is missing, elements attribute will not be populated. If needed these can be guessed using universe.guess_TopologyAttrs(context='default', to_guess=['elements']).
#   warnings.warn("Element information is missing, elements attribute "
# INFO:MDAnalysis.core.universe:attribute types has been guessed successfully.
# INFO:MDAnalysis.core.universe:attribute masses has been guessed successfully.
# INFO:deep_cartograph.modules.common.common:Starting compression to '/home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/torsions/bs_128/train_colvars/vae/traj_data/trajectory/plumed_inputs/plumed_vae_unbiased.zip'...
# INFO:deep_cartograph.modules.common.common:Successfully created zip file: '/home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/torsions/bs_128/train_colvars/vae/traj_data/trajectory/plumed_inputs/plumed_vae_unbiased.zip'
# INFO:MDAnalysis.core.universe:attribute types has been guessed successfully.
# INFO:MDAnalysis.core.universe:attribute masses has been guessed successfully.
# INFO:deep_cartograph.modules.common.common:Starting compression to '/home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/torsions/bs_128/train_colvars/vae/traj_data/trajectory/plumed_inputs/plumed_vae_biased.zip'...
# INFO:deep_cartograph.modules.common.common:Successfully created zip file: '/home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/torsions/bs_128/train_colvars/vae/traj_data/trajectory/plumed_inputs/plumed_vae_biased.zip'
# INFO:deep_cartograph.modules.cv_learning.cv_calculator:Creating TICA Calculator ...
# INFO:deep_cartograph.modules.cv_learning.cv_calculator:Reading training data from colvars files...
# INFO:deep_cartograph.modules.cv_learning.cv_calculator:Number of features: 14
# INFO:deep_cartograph.modules.cv_learning.cv_calculator:Number of samples: 10001
# /home/pnavarro/repos/mlcolvar/mlcolvar/utils/timelagged.py:140: UserWarning: Monitoring the progress for the search of time-lagged configurations with a progress_bar requires `tqdm`.
#   warnings.warn(
# /home/pnavarro/.conda/envs/deep_cartograph/lib/python3.10/site-packages/MDAnalysis/topology/PDBParser.py:350: UserWarning: Element information is missing, elements attribute will not be populated. If needed these can be guessed using universe.guess_TopologyAttrs(context='default', to_guess=['elements']).
#   warnings.warn("Element information is missing, elements attribute "
# INFO:MDAnalysis.core.universe:attribute types has been guessed successfully.
# INFO:MDAnalysis.core.universe:attribute masses has been guessed successfully.
# /home/pnavarro/.conda/envs/deep_cartograph/lib/python3.10/site-packages/MDAnalysis/coordinates/PDB.py:1154: UserWarning: Found no information for attr: 'elements' Using default value of ' '
#   warnings.warn("Found no information for attr: '{}'"
# /home/pnavarro/.conda/envs/deep_cartograph/lib/python3.10/site-packages/MDAnalysis/coordinates/PDB.py:1154: UserWarning: Found no information for attr: 'formalcharges' Using default value of '0'
#   warnings.warn("Found no information for attr: '{}'"
# INFO:deep_cartograph.modules.common.common:Starting compression to '/home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/torsions/bs_128/train_colvars/tica/model.zip'...
# INFO:deep_cartograph.modules.common.common:Successfully created zip file: '/home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/torsions/bs_128/train_colvars/tica/model.zip'
# INFO:deep_cartograph.modules.cv_learning.cv_calculator:Model saved to /home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/torsions/bs_128/train_colvars/tica/model.zip
# INFO:deep_cartograph.tools.train_colvars.train_colvars_workflow:Processing trajectory: trajectory
# INFO:deep_cartograph.tools.train_colvars.train_colvars_workflow:Corresponding colvars file: /home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/torsions/bs_128/compute_features/trajectory/colvars.dat
# INFO:deep_cartograph.tools.train_colvars.train_colvars_workflow:Corresponding topology file: /home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/input/topology.pdb
# /home/pnavarro/.conda/envs/deep_cartograph/lib/python3.10/site-packages/MDAnalysis/topology/PDBParser.py:350: UserWarning: Element information is missing, elements attribute will not be populated. If needed these can be guessed using universe.guess_TopologyAttrs(context='default', to_guess=['elements']).
#   warnings.warn("Element information is missing, elements attribute "
# INFO:MDAnalysis.core.universe:attribute types has been guessed successfully.
# INFO:MDAnalysis.core.universe:attribute masses has been guessed successfully.
# /home/pnavarro/.conda/envs/deep_cartograph/lib/python3.10/site-packages/MDAnalysis/coordinates/PDB.py:1154: UserWarning: Found no information for attr: 'elements' Using default value of ' '
#   warnings.warn("Found no information for attr: '{}'"
# /home/pnavarro/.conda/envs/deep_cartograph/lib/python3.10/site-packages/MDAnalysis/coordinates/PDB.py:1154: UserWarning: Found no information for attr: 'formalcharges' Using default value of '0'
#   warnings.warn("Found no information for attr: '{}'"
# INFO:MDAnalysis.core.universe:attribute types has been guessed successfully.
# INFO:MDAnalysis.core.universe:attribute masses has been guessed successfully.
# /home/pnavarro/.conda/envs/deep_cartograph/lib/python3.10/site-packages/MDAnalysis/topology/PDBParser.py:350: UserWarning: Element information is missing, elements attribute will not be populated. If needed these can be guessed using universe.guess_TopologyAttrs(context='default', to_guess=['elements']).
#   warnings.warn("Element information is missing, elements attribute "
# INFO:MDAnalysis.core.universe:attribute types has been guessed successfully.
# INFO:MDAnalysis.core.universe:attribute masses has been guessed successfully.
# INFO:deep_cartograph.modules.common.common:Starting compression to '/home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/torsions/bs_128/train_colvars/tica/traj_data/trajectory/plumed_inputs/plumed_tica_unbiased.zip'...
# INFO:deep_cartograph.modules.common.common:Successfully created zip file: '/home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/torsions/bs_128/train_colvars/tica/traj_data/trajectory/plumed_inputs/plumed_tica_unbiased.zip'
# INFO:MDAnalysis.core.universe:attribute types has been guessed successfully.
# INFO:MDAnalysis.core.universe:attribute masses has been guessed successfully.
# INFO:deep_cartograph.modules.common.common:Starting compression to '/home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/torsions/bs_128/train_colvars/tica/traj_data/trajectory/plumed_inputs/plumed_tica_biased.zip'...
# INFO:deep_cartograph.modules.common.common:Successfully created zip file: '/home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/torsions/bs_128/train_colvars/tica/traj_data/trajectory/plumed_inputs/plumed_tica_biased.zip'
# INFO:deep_cartograph.modules.cv_learning.cv_calculator:Creating DeepTICA Calculator ...
# INFO:deep_cartograph.modules.cv_learning.cv_calculator:Reading training data from colvars files...
# INFO:deep_cartograph.modules.cv_learning.cv_calculator:Number of features: 14
# INFO:deep_cartograph.modules.cv_learning.cv_calculator:Number of samples: 10001
# /home/pnavarro/repos/mlcolvar/mlcolvar/utils/timelagged.py:140: UserWarning: Monitoring the progress for the search of time-lagged configurations with a progress_bar requires `tqdm`.
#   warnings.warn(
# INFO:deep_cartograph.modules.cv_learning.cv_calculator:Training DeepTICA ...
# INFO:deep_cartograph.modules.cv_learning.cv_calculator:Model architecture: DeepTICA(
#   (loss_fn): ReduceEigenvaluesLoss()
#   (norm_in): Normalization(in_features=14, out_features=14, mode=custom)
#   (nn): FeedForward(
#     (nn): Sequential(
#       (0): Linear(in_features=14, out_features=8, bias=True)
#       (1): LeakyReLU(negative_slope=0.01, inplace=True)
#       (2): Linear(in_features=8, out_features=4, bias=True)
#       (3): LeakyReLU(negative_slope=0.01, inplace=True)
#       (4): Linear(in_features=4, out_features=1, bias=True)
#     )
#   )
#   (tica): TICA(in_features=1, out_features=1)
# )
# /home/pnavarro/.conda/envs/deep_cartograph/lib/python3.10/site-packages/lightning/fabric/plugins/environments/slurm.py:204: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/pnavarro/.conda/envs/deep_cartograph/lib/p ...
# INFO: GPU available: False, used: False
# INFO:lightning.pytorch.utilities.rank_zero:GPU available: False, used: False
# INFO: TPU available: False, using: 0 TPU cores
# INFO:lightning.pytorch.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO: HPU available: False, using: 0 HPUs
# INFO:lightning.pytorch.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:
#   | Name    | Type                  | Params | Mode  | In sizes | Out sizes
# ---------------------------------------------------------------------------------
# 0 | loss_fn | ReduceEigenvaluesLoss | 0      | train | ?        | ?
# 1 | norm_in | Normalization         | 0      | train | [1, 14]  | [1, 14]
# 2 | nn      | FeedForward           | 161    | train | [1, 14]  | [1, 1]
# 3 | tica    | TICA                  | 0      | train | [1, 1]   | [1, 1]
# ---------------------------------------------------------------------------------
# 161       Trainable params
# 0         Non-trainable params
# 161       Total params
# 0.001     Total estimated model params size (MB)
# 10        Modules in train mode
# 0         Modules in eval mode
# INFO:lightning.pytorch.callbacks.model_summary:
#   | Name    | Type                  | Params | Mode  | In sizes | Out sizes
# ---------------------------------------------------------------------------------
# 0 | loss_fn | ReduceEigenvaluesLoss | 0      | train | ?        | ?
# 1 | norm_in | Normalization         | 0      | train | [1, 14]  | [1, 14]
# 2 | nn      | FeedForward           | 161    | train | [1, 14]  | [1, 1]
# 3 | tica    | TICA                  | 0      | train | [1, 1]   | [1, 1]
# ---------------------------------------------------------------------------------
# 161       Trainable params
# 0         Non-trainable params
# 161       Total params
# 0.001     Total estimated model params size (MB)
# 10        Modules in train mode
# 0         Modules in eval mode
# INFO: `Trainer.fit` stopped: `max_epochs=100` reached.
# INFO:lightning.pytorch.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=100` reached.
# INFO:deep_cartograph.modules.cv_learning.cv_calculator:Successfully loaded the 'last' model from: /home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/torsions/bs_128/train_colvars/deep_tica/training/checkpoints/last.ckpt
# INFO:deep_cartograph.modules.cv_learning.cv_calculator:  -> Best Overall Score:      -0.98347
# INFO:deep_cartograph.modules.cv_learning.cv_calculator:  -> Last Model Score:          -0.94364
# /home/pnavarro/repos/mlcolvar/mlcolvar/utils/plot.py:255: UserWarning: Data has no positive values, and therefore cannot be log-scaled.
#   ax.set_yscale(yscale)
# WARNING:deep_cartograph.modules.cv_learning.cv_calculator:Learning rate not found in metrics. Learning rate plot will not be generated.
# INFO:deep_cartograph.modules.cv_learning.cv_calculator:Took 99 epochs
# INFO:deep_cartograph.modules.cv_learning.cv_calculator:Eigenvalue 1: 0.9701682329177856
# INFO:deep_cartograph.modules.common.common:Starting compression to '/home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/torsions/bs_128/train_colvars/deep_tica/training/training_metrics.zip'...
# INFO:deep_cartograph.modules.common.common:Successfully created zip file: '/home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/torsions/bs_128/train_colvars/deep_tica/training/training_metrics.zip'
# INFO:deep_cartograph.modules.cv_learning.cv_calculator:Training metrics saved to /home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/torsions/bs_128/train_colvars/deep_tica/training/training_metrics.zip
# INFO:deep_cartograph.modules.cv_learning.cv_calculator:Projecting data onto DeepTICA ...
# /home/pnavarro/.conda/envs/deep_cartograph/lib/python3.10/site-packages/MDAnalysis/topology/PDBParser.py:350: UserWarning: Element information is missing, elements attribute will not be populated. If needed these can be guessed using universe.guess_TopologyAttrs(context='default', to_guess=['elements']).
#   warnings.warn("Element information is missing, elements attribute "
# INFO:MDAnalysis.core.universe:attribute types has been guessed successfully.
# INFO:MDAnalysis.core.universe:attribute masses has been guessed successfully.
# /home/pnavarro/.conda/envs/deep_cartograph/lib/python3.10/site-packages/MDAnalysis/coordinates/PDB.py:1154: UserWarning: Found no information for attr: 'elements' Using default value of ' '
#   warnings.warn("Found no information for attr: '{}'"
# /home/pnavarro/.conda/envs/deep_cartograph/lib/python3.10/site-packages/MDAnalysis/coordinates/PDB.py:1154: UserWarning: Found no information for attr: 'formalcharges' Using default value of '0'
#   warnings.warn("Found no information for attr: '{}'"
# INFO:deep_cartograph.modules.common.common:Starting compression to '/home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/torsions/bs_128/train_colvars/deep_tica/model.zip'...
# INFO:deep_cartograph.modules.common.common:Successfully created zip file: '/home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/torsions/bs_128/train_colvars/deep_tica/model.zip'
# INFO:deep_cartograph.modules.cv_learning.cv_calculator:Model saved to /home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/torsions/bs_128/train_colvars/deep_tica/model.zip
# KEY:  data
#
#
# KEY:  data_lag
#
#
# KEY:  weights
#
#
# KEY:  weights_lag
# INFO:deep_cartograph.tools.train_colvars.train_colvars_workflow:Processing trajectory: trajectory
# INFO:deep_cartograph.tools.train_colvars.train_colvars_workflow:Corresponding colvars file: /home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/torsions/bs_128/compute_features/trajectory/colvars.dat
# INFO:deep_cartograph.tools.train_colvars.train_colvars_workflow:Corresponding topology file: /home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/input/topology.pdb
# /home/pnavarro/.conda/envs/deep_cartograph/lib/python3.10/site-packages/MDAnalysis/topology/PDBParser.py:350: UserWarning: Element information is missing, elements attribute will not be populated. If needed these can be guessed using universe.guess_TopologyAttrs(context='default', to_guess=['elements']).
#   warnings.warn("Element information is missing, elements attribute "
# INFO:MDAnalysis.core.universe:attribute types has been guessed successfully.
# INFO:MDAnalysis.core.universe:attribute masses has been guessed successfully.
# /home/pnavarro/.conda/envs/deep_cartograph/lib/python3.10/site-packages/MDAnalysis/coordinates/PDB.py:1154: UserWarning: Found no information for attr: 'elements' Using default value of ' '
#   warnings.warn("Found no information for attr: '{}'"
# /home/pnavarro/.conda/envs/deep_cartograph/lib/python3.10/site-packages/MDAnalysis/coordinates/PDB.py:1154: UserWarning: Found no information for attr: 'formalcharges' Using default value of '0'
#   warnings.warn("Found no information for attr: '{}'"
# INFO:MDAnalysis.core.universe:attribute types has been guessed successfully.
# INFO:MDAnalysis.core.universe:attribute masses has been guessed successfully.
# /home/pnavarro/.conda/envs/deep_cartograph/lib/python3.10/site-packages/MDAnalysis/topology/PDBParser.py:350: UserWarning: Element information is missing, elements attribute will not be populated. If needed these can be guessed using universe.guess_TopologyAttrs(context='default', to_guess=['elements']).
#   warnings.warn("Element information is missing, elements attribute "
# INFO:MDAnalysis.core.universe:attribute types has been guessed successfully.
# INFO:MDAnalysis.core.universe:attribute masses has been guessed successfully.
# INFO:deep_cartograph.modules.common.common:Starting compression to '/home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/torsions/bs_128/train_colvars/deep_tica/traj_data/trajectory/plumed_inputs/plumed_deep_tica_unbiased.zip'...
# INFO:deep_cartograph.modules.common.common:Successfully created zip file: '/home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/torsions/bs_128/train_colvars/deep_tica/traj_data/trajectory/plumed_inputs/plumed_deep_tica_unbiased.zip'
# INFO:MDAnalysis.core.universe:attribute types has been guessed successfully.
# ...
# KEY:  data
#
#
# KEY:  data_lag
#
#
# KEY:  weights
#
#
# KEY:  weights_lag
# INFO:deep_cartograph.tools.train_colvars.train_colvars_workflow:Processing trajectory: trajectory
# INFO:deep_cartograph.tools.train_colvars.train_colvars_workflow:Corresponding colvars file: /home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/torsions/bs_2048/compute_features/trajectory/colvars.dat
# INFO:deep_cartograph.tools.train_colvars.train_colvars_workflow:Corresponding topology file: /home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/input/topology.pdb
# /home/pnavarro/.conda/envs/deep_cartograph/lib/python3.10/site-packages/MDAnalysis/topology/PDBParser.py:350: UserWarning: Element information is missing, elements attribute will not be populated. If needed these can be guessed using universe.guess_TopologyAttrs(context='default', to_guess=['elements']).
#   warnings.warn("Element information is missing, elements attribute "
# INFO:MDAnalysis.core.universe:attribute types has been guessed successfully.
# INFO:MDAnalysis.core.universe:attribute masses has been guessed successfully.
# /home/pnavarro/.conda/envs/deep_cartograph/lib/python3.10/site-packages/MDAnalysis/coordinates/PDB.py:1154: UserWarning: Found no information for attr: 'elements' Using default value of ' '
#   warnings.warn("Found no information for attr: '{}'"
# /home/pnavarro/.conda/envs/deep_cartograph/lib/python3.10/site-packages/MDAnalysis/coordinates/PDB.py:1154: UserWarning: Found no information for attr: 'formalcharges' Using default value of '0'
#   warnings.warn("Found no information for attr: '{}'"
# INFO:MDAnalysis.core.universe:attribute types has been guessed successfully.
# INFO:MDAnalysis.core.universe:attribute masses has been guessed successfully.
# /home/pnavarro/.conda/envs/deep_cartograph/lib/python3.10/site-packages/MDAnalysis/topology/PDBParser.py:350: UserWarning: Element information is missing, elements attribute will not be populated. If needed these can be guessed using universe.guess_TopologyAttrs(context='default', to_guess=['elements']).
#   warnings.warn("Element information is missing, elements attribute "
# INFO:MDAnalysis.core.universe:attribute types has been guessed successfully.
# INFO:MDAnalysis.core.universe:attribute masses has been guessed successfully.
# INFO:deep_cartograph.modules.common.common:Starting compression to '/home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/torsions/bs_2048/train_colvars/deep_tica/traj_data/trajectory/plumed_inputs/plumed_deep_tica_unbiased.zip'...
# INFO:deep_cartograph.modules.common.common:Successfully created zip file: '/home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/torsions/bs_2048/train_colvars/deep_tica/traj_data/trajectory/plumed_inputs/plumed_deep_tica_unbiased.zip'
# INFO:MDAnalysis.core.universe:attribute types has been guessed successfully.
# INFO:MDAnalysis.core.universe:attribute masses has been guessed successfully.
# INFO:deep_cartograph.modules.common.common:Starting compression to '/home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/torsions/bs_2048/train_colvars/deep_tica/traj_data/trajectory/plumed_inputs/plumed_deep_tica_biased.zip'...
# INFO:deep_cartograph.modules.common.common:Successfully created zip file: '/home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/torsions/bs_2048/train_colvars/deep_tica/traj_data/trajectory/plumed_inputs/plumed_deep_tica_biased.zip'
# INFO:deep_cartograph:Elapsed time (Train colvars): 00 h 00 min 21 s
# INFO:deep_cartograph:Clustering trajectories in CV space: pca
# INFO:deep_cartograph:=====================================
# INFO:deep_cartograph:Trajectory clustering on the CV space
# INFO:deep_cartograph:=====================================
# INFO:deep_cartograph:Clustering of trajectories using sklearn.
# INFO:deep_cartograph.tools.traj_cluster.traj_cluster_workflow:Starting traj_cluster workflow...
# INFO:deep_cartograph.modules.statistics.statistics:Best number of clusters: 3
# INFO:deep_cartograph.tools.traj_cluster.traj_cluster_workflow:Extracting centroids from the trajectories...
# INFO:deep_cartograph.tools.traj_cluster.traj_cluster_workflow:Extracting centroid for cluster 0 from trajectory trajectory.xtc at frame 518.
# /home/pnavarro/.conda/envs/deep_cartograph/lib/python3.10/site-packages/MDAnalysis/topology/PDBParser.py:350: UserWarning: Element information is missing, elements attribute will not be populated. If needed these can be guessed using universe.guess_TopologyAttrs(context='default', to_guess=['elements']).
#   warnings.warn("Element information is missing, elements attribute "
# INFO:MDAnalysis.core.universe:attribute types has been guessed successfully.
# INFO:MDAnalysis.core.universe:attribute masses has been guessed successfully.
# /home/pnavarro/.conda/envs/deep_cartograph/lib/python3.10/site-packages/MDAnalysis/coordinates/PDB.py:1154: UserWarning: Found no information for attr: 'elements' Using default value of ' '
#   warnings.warn("Found no information for attr: '{}'"
# /home/pnavarro/.conda/envs/deep_cartograph/lib/python3.10/site-packages/MDAnalysis/coordinates/PDB.py:1154: UserWarning: Found no information for attr: 'formalcharges' Using default value of '0'
#   warnings.warn("Found no information for attr: '{}'"
# INFO:deep_cartograph.tools.traj_cluster.traj_cluster_workflow:Extracting centroid for cluster 2 from trajectory trajectory.xtc at frame 2132.
# INFO:MDAnalysis.core.universe:attribute types has been guessed successfully.
# INFO:MDAnalysis.core.universe:attribute masses has been guessed successfully.
# INFO:deep_cartograph.tools.traj_cluster.traj_cluster_workflow:Extracting centroid for cluster 1 from trajectory trajectory.xtc at frame 8757.
# INFO:MDAnalysis.core.universe:attribute types has been guessed successfully.
# INFO:MDAnalysis.core.universe:attribute masses has been guessed successfully.
# INFO:deep_cartograph:Elapsed time (Train colvars): 00 h 00 min 26 s
# INFO:deep_cartograph:Clustering trajectories in CV space: ae
# INFO:deep_cartograph:=====================================
# INFO:deep_cartograph:Trajectory clustering on the CV space
# INFO:deep_cartograph:=====================================
# INFO:deep_cartograph:Clustering of trajectories using sklearn.
# INFO:deep_cartograph.tools.traj_cluster.traj_cluster_workflow:Starting traj_cluster workflow...
# INFO:deep_cartograph.modules.statistics.statistics:Best number of clusters: 3
# INFO:deep_cartograph.tools.traj_cluster.traj_cluster_workflow:Extracting centroids from the trajectories...
# INFO:deep_cartograph.tools.traj_cluster.traj_cluster_workflow:Extracting centroid for cluster 0 from trajectory trajectory.xtc at frame 7244.
# /home/pnavarro/.conda/envs/deep_cartograph/lib/python3.10/site-packages/MDAnalysis/topology/PDBParser.py:350: UserWarning: Element information is missing, elements attribute will not be populated. If needed these can be guessed using universe.guess_TopologyAttrs(context='default', to_guess=['elements']).
#   warnings.warn("Element information is missing, elements attribute "
# INFO:MDAnalysis.core.universe:attribute types has been guessed successfully.
# INFO:MDAnalysis.core.universe:attribute masses has been guessed successfully.
# /home/pnavarro/.conda/envs/deep_cartograph/lib/python3.10/site-packages/MDAnalysis/coordinates/PDB.py:1154: UserWarning: Found no information for attr: 'elements' Using default value of ' '
#   warnings.warn("Found no information for attr: '{}'"
# /home/pnavarro/.conda/envs/deep_cartograph/lib/python3.10/site-packages/MDAnalysis/coordinates/PDB.py:1154: UserWarning: Found no information for attr: 'formalcharges' Using default value of '0'
#   warnings.warn("Found no information for attr: '{}'"
# INFO:deep_cartograph.tools.traj_cluster.traj_cluster_workflow:Extracting centroid for cluster 1 from trajectory trajectory.xtc at frame 8621.
# INFO:MDAnalysis.core.universe:attribute types has been guessed successfully.
# INFO:MDAnalysis.core.universe:attribute masses has been guessed successfully.
# INFO:deep_cartograph.tools.traj_cluster.traj_cluster_workflow:Extracting centroid for cluster 2 from trajectory trajectory.xtc at frame 9324.
# INFO:MDAnalysis.core.universe:attribute types has been guessed successfully.
# INFO:MDAnalysis.core.universe:attribute masses has been guessed successfully.
# INFO:deep_cartograph:Elapsed time (Train colvars): 00 h 00 min 29 s
# INFO:deep_cartograph:Clustering trajectories in CV space: vae
# INFO:deep_cartograph:=====================================
# INFO:deep_cartograph:Trajectory clustering on the CV space
# INFO:deep_cartograph:=====================================
# INFO:deep_cartograph:Clustering of trajectories using sklearn.
# INFO:deep_cartograph.tools.traj_cluster.traj_cluster_workflow:Starting traj_cluster workflow...
# INFO:deep_cartograph.modules.statistics.statistics:Best number of clusters: 3
# INFO:deep_cartograph.tools.traj_cluster.traj_cluster_workflow:Extracting centroids from the trajectories...
# INFO:deep_cartograph.tools.traj_cluster.traj_cluster_workflow:Extracting centroid for cluster 1 from trajectory trajectory.xtc at frame 541.
# /home/pnavarro/.conda/envs/deep_cartograph/lib/python3.10/site-packages/MDAnalysis/topology/PDBParser.py:350: UserWarning: Element information is missing, elements attribute will not be populated. If needed these can be guessed using universe.guess_TopologyAttrs(context='default', to_guess=['elements']).
#   warnings.warn("Element information is missing, elements attribute "
# INFO:MDAnalysis.core.universe:attribute types has been guessed successfully.
# INFO:MDAnalysis.core.universe:attribute masses has been guessed successfully.
# /home/pnavarro/.conda/envs/deep_cartograph/lib/python3.10/site-packages/MDAnalysis/coordinates/PDB.py:1154: UserWarning: Found no information for attr: 'elements' Using default value of ' '
#   warnings.warn("Found no information for attr: '{}'"
# /home/pnavarro/.conda/envs/deep_cartograph/lib/python3.10/site-packages/MDAnalysis/coordinates/PDB.py:1154: UserWarning: Found no information for attr: 'formalcharges' Using default value of '0'
#   warnings.warn("Found no information for attr: '{}'"
# INFO:deep_cartograph.tools.traj_cluster.traj_cluster_workflow:Extracting centroid for cluster 0 from trajectory trajectory.xtc at frame 2998.
# INFO:MDAnalysis.core.universe:attribute types has been guessed successfully.
# INFO:MDAnalysis.core.universe:attribute masses has been guessed successfully.
# INFO:deep_cartograph.tools.traj_cluster.traj_cluster_workflow:Extracting centroid for cluster 2 from trajectory trajectory.xtc at frame 9013.
# INFO:MDAnalysis.core.universe:attribute types has been guessed successfully.
# INFO:MDAnalysis.core.universe:attribute masses has been guessed successfully.
# INFO:deep_cartograph:Elapsed time (Train colvars): 00 h 00 min 24 s
# INFO:deep_cartograph:Clustering trajectories in CV space: tica
# INFO:deep_cartograph:=====================================
# INFO:deep_cartograph:Trajectory clustering on the CV space
# INFO:deep_cartograph:=====================================
# INFO:deep_cartograph:Clustering of trajectories using sklearn.
# INFO:deep_cartograph.tools.traj_cluster.traj_cluster_workflow:Starting traj_cluster workflow...
# INFO:deep_cartograph.modules.statistics.statistics:Best number of clusters: 3
# INFO:deep_cartograph.tools.traj_cluster.traj_cluster_workflow:Extracting centroids from the trajectories...
# INFO:deep_cartograph.tools.traj_cluster.traj_cluster_workflow:Extracting centroid for cluster 2 from trajectory trajectory.xtc at frame 4683.
# /home/pnavarro/.conda/envs/deep_cartograph/lib/python3.10/site-packages/MDAnalysis/topology/PDBParser.py:350: UserWarning: Element information is missing, elements attribute will not be populated. If needed these can be guessed using universe.guess_TopologyAttrs(context='default', to_guess=['elements']).
#   warnings.warn("Element information is missing, elements attribute "
# INFO:MDAnalysis.core.universe:attribute types has been guessed successfully.
# INFO:MDAnalysis.core.universe:attribute masses has been guessed successfully.
# /home/pnavarro/.conda/envs/deep_cartograph/lib/python3.10/site-packages/MDAnalysis/coordinates/PDB.py:1154: UserWarning: Found no information for attr: 'elements' Using default value of ' '
#   warnings.warn("Found no information for attr: '{}'"
# /home/pnavarro/.conda/envs/deep_cartograph/lib/python3.10/site-packages/MDAnalysis/coordinates/PDB.py:1154: UserWarning: Found no information for attr: 'formalcharges' Using default value of '0'
#   warnings.warn("Found no information for attr: '{}'"
# INFO:deep_cartograph.tools.traj_cluster.traj_cluster_workflow:Extracting centroid for cluster 1 from trajectory trajectory.xtc at frame 4967.
# INFO:MDAnalysis.core.universe:attribute types has been guessed successfully.
# INFO:MDAnalysis.core.universe:attribute masses has been guessed successfully.
# INFO:deep_cartograph.tools.traj_cluster.traj_cluster_workflow:Extracting centroid for cluster 0 from trajectory trajectory.xtc at frame 5899.
# INFO:MDAnalysis.core.universe:attribute types has been guessed successfully.
# INFO:MDAnalysis.core.universe:attribute masses has been guessed successfully.
# INFO:deep_cartograph:Elapsed time (Train colvars): 00 h 00 min 24 s
# INFO:deep_cartograph:Clustering trajectories in CV space: deep_tica
# INFO:deep_cartograph:=====================================
# INFO:deep_cartograph:Trajectory clustering on the CV space
# INFO:deep_cartograph:=====================================
# INFO:deep_cartograph:Clustering of trajectories using sklearn.
# INFO:deep_cartograph.tools.traj_cluster.traj_cluster_workflow:Starting traj_cluster workflow...
# INFO:deep_cartograph.modules.statistics.statistics:Best number of clusters: 3
# INFO:deep_cartograph.tools.traj_cluster.traj_cluster_workflow:Extracting centroids from the trajectories...
# INFO:deep_cartograph.tools.traj_cluster.traj_cluster_workflow:Extracting centroid for cluster 1 from trajectory trajectory.xtc at frame 317.
# /home/pnavarro/.conda/envs/deep_cartograph/lib/python3.10/site-packages/MDAnalysis/topology/PDBParser.py:350: UserWarning: Element information is missing, elements attribute will not be populated. If needed these can be guessed using universe.guess_TopologyAttrs(context='default', to_guess=['elements']).
#   warnings.warn("Element information is missing, elements attribute "
# INFO:MDAnalysis.core.universe:attribute types has been guessed successfully.
# INFO:MDAnalysis.core.universe:attribute masses has been guessed successfully.
# /home/pnavarro/.conda/envs/deep_cartograph/lib/python3.10/site-packages/MDAnalysis/coordinates/PDB.py:1154: UserWarning: Found no information for attr: 'elements' Using default value of ' '
#   warnings.warn("Found no information for attr: '{}'"
# /home/pnavarro/.conda/envs/deep_cartograph/lib/python3.10/site-packages/MDAnalysis/coordinates/PDB.py:1154: UserWarning: Found no information for attr: 'formalcharges' Using default value of '0'
#   warnings.warn("Found no information for attr: '{}'"
# INFO:deep_cartograph.tools.traj_cluster.traj_cluster_workflow:Extracting centroid for cluster 2 from trajectory trajectory.xtc at frame 8105.
# INFO:MDAnalysis.core.universe:attribute types has been guessed successfully.
# INFO:MDAnalysis.core.universe:attribute masses has been guessed successfully.
# INFO:deep_cartograph.tools.traj_cluster.traj_cluster_workflow:Extracting centroid for cluster 0 from trajectory trajectory.xtc at frame 9017.
# INFO:MDAnalysis.core.universe:attribute types has been guessed successfully.
# INFO:MDAnalysis.core.universe:attribute masses has been guessed successfully.
# INFO:deep_cartograph:Elapsed time (Train colvars): 00 h 00 min 19 s
# INFO:deep_cartograph:Total elapsed time: 00 h 02 min 26 s

# %% [markdown]
# ### Testing batch size

# %%
# Show results for the Autoencoder, Variational Autoencoder and Deep TICA models with different batch sizes
for model in ['ae', 'vae', 'deep_tica']:
    
    print(f"Model: {model} ########################################################### #")
    
    for batch_size in batch_sizes:

        print(f"Batch size: {batch_size} ----------------------------------------------- #")

        # Test name
        test_name = f'bs_{batch_size}'

        # Show main results
        show_results(features, temperature, model, test_name)
# Out:
# Model: ae ########################################################### #
# Batch size: 128 ----------------------------------------------- #
# Output folder: /home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/torsions/bs_128
# Phi psi path: /home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/input/500K/phi_psi.dat
# Final model score: 5.6366E-3
# <img src="/home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/torsions/bs_128/train_colvars/ae/traj_data/trajectory/AE 1_ramachandran.png?1765903916" style="width: 600px; margin-right: 10px;">
# Batch size: 2048 ----------------------------------------------- #
# Output folder: /home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/torsions/bs_2048
# Phi psi path: /home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/input/500K/phi_psi.dat
# Final model score: 2.5956E-2
# <img src="/home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/torsions/bs_2048/train_colvars/ae/traj_data/trajectory/AE 1_ramachandran.png?1765903916" style="width: 600px; margin-right: 10px;">
# Model: vae ########################################################### #
# Batch size: 128 ----------------------------------------------- #
# Output folder: /home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/torsions/bs_128
# Phi psi path: /home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/input/500K/phi_psi.dat
# Final model score: 5.4910E-3
# <img src="/home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/torsions/bs_128/train_colvars/vae/traj_data/trajectory/VAE 1_ramachandran.png?1765903917" style="width: 600px; margin-right: 10px;">
# Batch size: 2048 ----------------------------------------------- #
# Output folder: /home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/torsions/bs_2048
# Phi psi path: /home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/input/500K/phi_psi.dat
# Final model score: 2.3298E-2
# <img src="/home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/torsions/bs_2048/train_colvars/vae/traj_data/trajectory/VAE 1_ramachandran.png?1765903917" style="width: 600px; margin-right: 10px;">
# Model: deep_tica ########################################################### #
# Batch size: 128 ----------------------------------------------- #
# Output folder: /home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/torsions/bs_128
# Phi psi path: /home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/input/500K/phi_psi.dat
# Final model score: -9.4364E-1
# Eigenvalue 1: 9.7017E-1
# <img src="/home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/torsions/bs_128/train_colvars/deep_tica/traj_data/trajectory/DeepTIC 1_ramachandran.png?1765903918" style="width: 600px; margin-right: 10px;">
# Batch size: 2048 ----------------------------------------------- #
# Output folder: /home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/torsions/bs_2048
# Phi psi path: /home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/input/500K/phi_psi.dat
# Final model score: -9.6240E-1
# Eigenvalue 1: 9.8102E-1
# <img src="/home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/torsions/bs_2048/train_colvars/deep_tica/traj_data/trajectory/DeepTIC 1_ramachandran.png?1765903918" style="width: 600px; margin-right: 10px;">

# %%
# Show results for the pca and htica models
for model in ['pca', 'tica']:
    
    print(f"Model: {model} ########################################################### #")
    
    for batch_size in batch_sizes:

        print(f"Batch size: {batch_size} ----------------------------------------------- #")

        # Test name
        test_name = f'bs_{batch_size}'

        # Show main results
        show_results(features, temperature, model, test_name)
# Out:
# Model: pca ########################################################### #
# Batch size: 128 ----------------------------------------------- #
# Output folder: /home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/torsions/bs_128
# Phi psi path: /home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/input/500K/phi_psi.dat
# Score file not found
# <img src="/home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/torsions/bs_128/train_colvars/pca/traj_data/trajectory/PC 1_ramachandran.png?1765903918" style="width: 600px; margin-right: 10px;">
# Batch size: 2048 ----------------------------------------------- #
# Output folder: /home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/torsions/bs_2048
# Phi psi path: /home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/input/500K/phi_psi.dat
# Score file not found
# <img src="/home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/torsions/bs_2048/train_colvars/pca/traj_data/trajectory/PC 1_ramachandran.png?1765903919" style="width: 600px; margin-right: 10px;">
# Model: tica ########################################################### #
# Batch size: 128 ----------------------------------------------- #
# Output folder: /home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/torsions/bs_128
# Phi psi path: /home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/input/500K/phi_psi.dat
# Score file not found
# <img src="/home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/torsions/bs_128/train_colvars/tica/traj_data/trajectory/TIC 1_ramachandran.png?1765903919" style="width: 600px; margin-right: 10px;">
# Batch size: 2048 ----------------------------------------------- #
# Output folder: /home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/torsions/bs_2048
# Phi psi path: /home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/input/500K/phi_psi.dat
# Score file not found
# <img src="/home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/torsions/bs_2048/train_colvars/tica/traj_data/trajectory/TIC 1_ramachandran.png?1765903920" style="width: 600px; margin-right: 10px;">

# %% [markdown]
# - Trainings with smaller batch sizes reach lower validation losses in fewer epochs and better models!
# - Models trained with smaller batch size show latent space variables that encode different slow modes of the system and better generalization capabilities (see difference between training and validation losses).
#
# In this case the computational cost of each epoch is not a concern, so the recommendation is to use a small batch size for the autoencoder (64-256 or 0.5 - 3 % of the training data).

# %% [markdown]
# - Latent space of models trained with lower batch sizes capture better the slow modes (128-256 samples or 1-3 % of the dataset size).
#
# Here we can see that a lower loss doesn't always correspond to a better model. The lower batch size models are able to capture both
# slow modes, while the higher batch size models only capture the slowest mode.

# %% [markdown]
# Both models are able to learn the main slow mode of the system from the torsion angles. However the Autoencoder yields a smooth CV that captures all slow transitions while the Deep TICA model only captures the main slow mode.
#
# - In general, the training of the Deep TICA model is more delicate than the Autoencoder. There are more hyper-parameters involved.
#
# Note that these results are also dependent on other hyper-parameters and the dataset itself.

# %% [markdown]
# ### Testing different lag times (Deep TICA)

# %%
# Choose the features to work with (torsions or distances)
features = 'torsions'

# Choose temperature of the simulations (300 K shows just one transition, 400 K starts to show two, 500 K clearly shows two transitions)
temperature = 500

# Load initial configuration
config_path = f"{data_folder}/alanine_dipeptide/input/{features}_config.yml"

with open(config_path, 'r') as file:
    configuration = yaml.load(file, Loader = yaml.FullLoader)

# Select model
configuration['train_colvars']['cvs'] = ['deep_tica']

# Select batch size
batch_size = 256

# Select lag times to test (in number of samples)
# The delta t between samples is 1 ps, thus the lag time is in ps in this case
lag_times = [1, 10, 50, 200]

for lag_time in lag_times:

    # Name of the test
    test_name = f'lag_{lag_time}_1D'

    # Make a copy of the initial configuration
    test_configuration = configuration.copy()

    # Update configuration
    test_configuration['train_colvars']['common']['training']['general']['batch_size'] = batch_size
    test_configuration['train_colvars']['common']['dimension'] = 1
    test_configuration['train_colvars']['common']['lag_time'] = lag_time

    # Run deep cartograph
    run_deep_cartograph(test_configuration, features, temperature, test_name)
# Out:
# INFO:deep_cartograph:================
# INFO:deep_cartograph:Analyze geometry
# INFO:deep_cartograph:================
# INFO:deep_cartograph:Elapsed time (Analyze geometry): 00 h 00 min 00 s
# INFO:deep_cartograph:================
# INFO:deep_cartograph:Compute features
# INFO:deep_cartograph:================
# /home/pnavarro/.conda/envs/deep_cartograph/lib/python3.10/site-packages/MDAnalysis/topology/PDBParser.py:350: UserWarning: Element information is missing, elements attribute will not be populated. If needed these can be guessed using universe.guess_TopologyAttrs(context='default', to_guess=['elements']).
#   warnings.warn("Element information is missing, elements attribute "
# INFO:MDAnalysis.core.universe:attribute types has been guessed successfully.
# INFO:MDAnalysis.core.universe:attribute masses has been guessed successfully.
# /home/pnavarro/.conda/envs/deep_cartograph/lib/python3.10/site-packages/MDAnalysis/coordinates/PDB.py:1154: UserWarning: Found no information for attr: 'elements' Using default value of ' '
#   warnings.warn("Found no information for attr: '{}'"
# /home/pnavarro/.conda/envs/deep_cartograph/lib/python3.10/site-packages/MDAnalysis/coordinates/PDB.py:1154: UserWarning: Found no information for attr: 'formalcharges' Using default value of '0'
#   warnings.warn("Found no information for attr: '{}'"
# INFO:MDAnalysis.core.universe:attribute types has been guessed successfully.
# INFO:MDAnalysis.core.universe:attribute masses has been guessed successfully.
# INFO:deep_cartograph.modules.md.md:Topology does not contain bonds. Bonds will be guessed using a distance criterion (bond_length < 2.0).
# WARNING:deep_cartograph.modules.md.md:Topology does not contain bonds. Using a distance criterion (bond_length < 2.0) to guess bonds.
# INFO:MDAnalysis.core.universe:attribute types has been guessed successfully.
# INFO:MDAnalysis.core.universe:attribute masses has been guessed successfully.
# INFO:deep_cartograph:Computing features for trajectory with topology topology...
# /home/pnavarro/.conda/envs/deep_cartograph/lib/python3.10/site-packages/MDAnalysis/topology/PDBParser.py:350: UserWarning: Element information is missing, elements attribute will not be populated. If needed these can be guessed using universe.guess_TopologyAttrs(context='default', to_guess=['elements']).
#   warnings.warn("Element information is missing, elements attribute "
# INFO:MDAnalysis.core.universe:attribute types has been guessed successfully.
# INFO:MDAnalysis.core.universe:attribute masses has been guessed successfully.
# INFO:MDAnalysis.core.universe:attribute types has been guessed successfully.
# INFO:MDAnalysis.core.universe:attribute masses has been guessed successfully.
# INFO:deep_cartograph.modules.plumed.cli:Executing PLUMED command: plumed driver --plumed /home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/torsions/lag_1_1D/compute_features/trajectory/plumed_input.dat --mf_xtc /home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/input/500K/trajectory.xtc --natoms 22
# INFO:deep_cartograph.modules.plumed.cli:Restored working directory to: /home/pnavarro/repos/mlcolvar
# INFO:deep_cartograph:Elapsed time (Compute features): 00 h 00 min 00 s
# INFO:deep_cartograph:==================
# INFO:deep_cartograph:Filtering features
# INFO:deep_cartograph:==================
# INFO:deep_cartograph:Finding the features that contains the most information about the transitions or conformational changes.
# INFO:deep_cartograph:The following algorithms are available:
# INFO:deep_cartograph:- Hartigan's dip test filter. Keeps features that are not unimodal.
# INFO:deep_cartograph:- Shannon entropy filter. Keeps features with entropy greater than a threshold.
# INFO:deep_cartograph:- Standard deviation filter. Keeps features with standard deviation greater than a threshold.
# INFO:deep_cartograph:Note that the all features must be in the same units to apply the entropy and standard deviation filters meaningfully.
# INFO:deep_cartograph.modules.features.filter:Initializing Filter
# INFO:deep_cartograph.modules.features.filter:Initial size of features set (only common features): 20.
# INFO:deep_cartograph.modules.features.filter:Processed 2/20 features. Estimated time left: 3.26 seconds.
# INFO:deep_cartograph.modules.features.filter:Processed 4/20 features. Estimated time left: 1.57 seconds.
# INFO:deep_cartograph.modules.features.filter:Processed 6/20 features. Estimated time left: 0.98 seconds.
# INFO:deep_cartograph.modules.features.filter:Processed 8/20 features. Estimated time left: 0.68 seconds.
# INFO:deep_cartograph.modules.features.filter:Processed 10/20 features. Estimated time left: 0.48 seconds.
# INFO:deep_cartograph.modules.features.filter:Processed 12/20 features. Estimated time left: 0.34 seconds.
# INFO:deep_cartograph.modules.features.filter:Processed 14/20 features. Estimated time left: 0.23 seconds.
# INFO:deep_cartograph.modules.features.filter:Processed 16/20 features. Estimated time left: 0.14 seconds.
# INFO:deep_cartograph.modules.features.filter:Processed 18/20 features. Estimated time left: 0.07 seconds.
# INFO:deep_cartograph.modules.features.filter:Processed 20/20 features. Estimated time left: 0.00 seconds.
# INFO:deep_cartograph.modules.features.filter:Filtered 6 features.
# INFO:deep_cartograph:Elapsed time (Filter features): 00 h 00 min 00 s
# INFO:deep_cartograph.modules.common.common: Using features in /home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/torsions/lag_1_1D/filter_features/filtered_features.txt
# INFO:deep_cartograph:================================
# INFO:deep_cartograph:Training of Collective Variables
# INFO:deep_cartograph:================================
# INFO:deep_cartograph:Training of collective variables using the mlcolvar library.
# INFO:deep_cartograph.tools.train_colvars.train_colvars_workflow:Collective variables to compute: ['deep_tica']
# INFO:deep_cartograph.modules.cv_learning.cv_calculator:Creating DeepTICA Calculator ...
# INFO:deep_cartograph.modules.cv_learning.cv_calculator:Reading training data from colvars files...
# INFO:deep_cartograph.modules.cv_learning.cv_calculator:Number of features: 14
# INFO:deep_cartograph.modules.cv_learning.cv_calculator:Number of samples: 10001
# /home/pnavarro/repos/mlcolvar/mlcolvar/utils/timelagged.py:140: UserWarning: Monitoring the progress for the search of time-lagged configurations with a progress_bar requires `tqdm`.
#   warnings.warn(
# INFO:deep_cartograph.modules.cv_learning.cv_calculator:Training DeepTICA ...
# INFO:deep_cartograph.modules.cv_learning.cv_calculator:Model architecture: DeepTICA(
#   (loss_fn): ReduceEigenvaluesLoss()
#   (norm_in): Normalization(in_features=14, out_features=14, mode=custom)
#   (nn): FeedForward(
#     (nn): Sequential(
#       (0): Linear(in_features=14, out_features=8, bias=True)
#       (1): LeakyReLU(negative_slope=0.01, inplace=True)
#       (2): Linear(in_features=8, out_features=4, bias=True)
#       (3): LeakyReLU(negative_slope=0.01, inplace=True)
#       (4): Linear(in_features=4, out_features=1, bias=True)
#     )
#   )
#   (tica): TICA(in_features=1, out_features=1)
# )
# /home/pnavarro/.conda/envs/deep_cartograph/lib/python3.10/site-packages/lightning/fabric/plugins/environments/slurm.py:204: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/pnavarro/.conda/envs/deep_cartograph/lib/p ...
# INFO: GPU available: False, used: False
# INFO:lightning.pytorch.utilities.rank_zero:GPU available: False, used: False
# INFO: TPU available: False, using: 0 TPU cores
# INFO:lightning.pytorch.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO: HPU available: False, using: 0 HPUs
# INFO:lightning.pytorch.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:
#   | Name    | Type                  | Params | Mode  | In sizes | Out sizes
# ---------------------------------------------------------------------------------
# 0 | loss_fn | ReduceEigenvaluesLoss | 0      | train | ?        | ?
# 1 | norm_in | Normalization         | 0      | train | [1, 14]  | [1, 14]
# 2 | nn      | FeedForward           | 161    | train | [1, 14]  | [1, 1]
# 3 | tica    | TICA                  | 0      | train | [1, 1]   | [1, 1]
# ---------------------------------------------------------------------------------
# 161       Trainable params
# 0         Non-trainable params
# 161       Total params
# 0.001     Total estimated model params size (MB)
# 10        Modules in train mode
# 0         Modules in eval mode
# INFO:lightning.pytorch.callbacks.model_summary:
#   | Name    | Type                  | Params | Mode  | In sizes | Out sizes
# ---------------------------------------------------------------------------------
# 0 | loss_fn | ReduceEigenvaluesLoss | 0      | train | ?        | ?
# 1 | norm_in | Normalization         | 0      | train | [1, 14]  | [1, 14]
# 2 | nn      | FeedForward           | 161    | train | [1, 14]  | [1, 1]
# 3 | tica    | TICA                  | 0      | train | [1, 1]   | [1, 1]
# ---------------------------------------------------------------------------------
# 161       Trainable params
# 0         Non-trainable params
# 161       Total params
# 0.001     Total estimated model params size (MB)
# 10        Modules in train mode
# 0         Modules in eval mode
# INFO: `Trainer.fit` stopped: `max_epochs=100` reached.
# INFO:lightning.pytorch.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=100` reached.
# INFO:deep_cartograph.modules.cv_learning.cv_calculator:Successfully loaded the 'last' model from: /home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/torsions/lag_1_1D/train_colvars/deep_tica/training/checkpoints/last.ckpt
# INFO:deep_cartograph.modules.cv_learning.cv_calculator:  -> Best Overall Score:      -0.97350
# INFO:deep_cartograph.modules.cv_learning.cv_calculator:  -> Last Model Score:          -0.95487
# /home/pnavarro/repos/mlcolvar/mlcolvar/utils/plot.py:255: UserWarning: Data has no positive values, and therefore cannot be log-scaled.
#   ax.set_yscale(yscale)
# WARNING:deep_cartograph.modules.cv_learning.cv_calculator:Learning rate not found in metrics. Learning rate plot will not be generated.
# INFO:deep_cartograph.modules.cv_learning.cv_calculator:Took 99 epochs
# INFO:deep_cartograph.modules.cv_learning.cv_calculator:Eigenvalue 1: 0.9767636060714722
# INFO:deep_cartograph.modules.common.common:Starting compression to '/home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/torsions/lag_1_1D/train_colvars/deep_tica/training/training_metrics.zip'...
# INFO:deep_cartograph.modules.common.common:Successfully created zip file: '/home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/torsions/lag_1_1D/train_colvars/deep_tica/training/training_metrics.zip'
# INFO:deep_cartograph.modules.cv_learning.cv_calculator:Training metrics saved to /home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/torsions/lag_1_1D/train_colvars/deep_tica/training/training_metrics.zip
# INFO:deep_cartograph.modules.cv_learning.cv_calculator:Projecting data onto DeepTICA ...
# /home/pnavarro/.conda/envs/deep_cartograph/lib/python3.10/site-packages/MDAnalysis/topology/PDBParser.py:350: UserWarning: Element information is missing, elements attribute will not be populated. If needed these can be guessed using universe.guess_TopologyAttrs(context='default', to_guess=['elements']).
#   warnings.warn("Element information is missing, elements attribute "
# INFO:MDAnalysis.core.universe:attribute types has been guessed successfully.
# INFO:MDAnalysis.core.universe:attribute masses has been guessed successfully.
# /home/pnavarro/.conda/envs/deep_cartograph/lib/python3.10/site-packages/MDAnalysis/coordinates/PDB.py:1154: UserWarning: Found no information for attr: 'elements' Using default value of ' '
#   warnings.warn("Found no information for attr: '{}'"
# /home/pnavarro/.conda/envs/deep_cartograph/lib/python3.10/site-packages/MDAnalysis/coordinates/PDB.py:1154: UserWarning: Found no information for attr: 'formalcharges' Using default value of '0'
#   warnings.warn("Found no information for attr: '{}'"
# INFO:deep_cartograph.modules.common.common:Starting compression to '/home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/torsions/lag_1_1D/train_colvars/deep_tica/model.zip'...
# INFO:deep_cartograph.modules.common.common:Successfully created zip file: '/home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/torsions/lag_1_1D/train_colvars/deep_tica/model.zip'
# INFO:deep_cartograph.modules.cv_learning.cv_calculator:Model saved to /home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/torsions/lag_1_1D/train_colvars/deep_tica/model.zip
# KEY:  data
#
#
# KEY:  data_lag
#
#
# KEY:  weights
#
#
# KEY:  weights_lag
# INFO:deep_cartograph.tools.train_colvars.train_colvars_workflow:Processing trajectory: trajectory
# INFO:deep_cartograph.tools.train_colvars.train_colvars_workflow:Corresponding colvars file: /home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/torsions/lag_1_1D/compute_features/trajectory/colvars.dat
# INFO:deep_cartograph.tools.train_colvars.train_colvars_workflow:Corresponding topology file: /home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/input/topology.pdb
# /home/pnavarro/.conda/envs/deep_cartograph/lib/python3.10/site-packages/MDAnalysis/topology/PDBParser.py:350: UserWarning: Element information is missing, elements attribute will not be populated. If needed these can be guessed using universe.guess_TopologyAttrs(context='default', to_guess=['elements']).
#   warnings.warn("Element information is missing, elements attribute "
# INFO:MDAnalysis.core.universe:attribute types has been guessed successfully.
# INFO:MDAnalysis.core.universe:attribute masses has been guessed successfully.
# /home/pnavarro/.conda/envs/deep_cartograph/lib/python3.10/site-packages/MDAnalysis/coordinates/PDB.py:1154: UserWarning: Found no information for attr: 'elements' Using default value of ' '
#   warnings.warn("Found no information for attr: '{}'"
# /home/pnavarro/.conda/envs/deep_cartograph/lib/python3.10/site-packages/MDAnalysis/coordinates/PDB.py:1154: UserWarning: Found no information for attr: 'formalcharges' Using default value of '0'
#   warnings.warn("Found no information for attr: '{}'"
# INFO:MDAnalysis.core.universe:attribute types has been guessed successfully.
# INFO:MDAnalysis.core.universe:attribute masses has been guessed successfully.
# /home/pnavarro/.conda/envs/deep_cartograph/lib/python3.10/site-packages/MDAnalysis/topology/PDBParser.py:350: UserWarning: Element information is missing, elements attribute will not be populated. If needed these can be guessed using universe.guess_TopologyAttrs(context='default', to_guess=['elements']).
#   warnings.warn("Element information is missing, elements attribute "
# INFO:MDAnalysis.core.universe:attribute types has been guessed successfully.
# INFO:MDAnalysis.core.universe:attribute masses has been guessed successfully.
# INFO:deep_cartograph.modules.common.common:Starting compression to '/home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/torsions/lag_1_1D/train_colvars/deep_tica/traj_data/trajectory/plumed_inputs/plumed_deep_tica_unbiased.zip'...
# INFO:deep_cartograph.modules.common.common:Successfully created zip file: '/home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/torsions/lag_1_1D/train_colvars/deep_tica/traj_data/trajectory/plumed_inputs/plumed_deep_tica_unbiased.zip'
# INFO:MDAnalysis.core.universe:attribute types has been guessed successfully.
# INFO:MDAnalysis.core.universe:attribute masses has been guessed successfully.
# INFO:deep_cartograph.modules.common.common:Starting compression to '/home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/torsions/lag_1_1D/train_colvars/deep_tica/traj_data/trajectory/plumed_inputs/plumed_deep_tica_biased.zip'...
# INFO:deep_cartograph.modules.common.common:Successfully created zip file: '/home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/torsions/lag_1_1D/train_colvars/deep_tica/traj_data/trajectory/plumed_inputs/plumed_deep_tica_biased.zip'
# INFO:deep_cartograph:Elapsed time (Train colvars): 00 h 00 min 19 s
# INFO:deep_cartograph:Clustering trajectories in CV space: deep_tica
# INFO:deep_cartograph:=====================================
# INFO:deep_cartograph:Trajectory clustering on the CV space
# INFO:deep_cartograph:=====================================
# INFO:deep_cartograph:Clustering of trajectories using sklearn.
# INFO:deep_cartograph.tools.traj_cluster.traj_cluster_workflow:Starting traj_cluster workflow...
# INFO:deep_cartograph.modules.statistics.statistics:Best number of clusters: 3
# INFO:deep_cartograph.tools.traj_cluster.traj_cluster_workflow:Extracting centroids from the trajectories...
# INFO:deep_cartograph.tools.traj_cluster.traj_cluster_workflow:Extracting centroid for cluster 0 from trajectory trajectory.xtc at frame 49.
# /home/pnavarro/.conda/envs/deep_cartograph/lib/python3.10/site-packages/MDAnalysis/topology/PDBParser.py:350: UserWarning: Element information is missing, elements attribute will not be populated. If needed these can be guessed using universe.guess_TopologyAttrs(context='default', to_guess=['elements']).
#   warnings.warn("Element information is missing, elements attribute "
# INFO:MDAnalysis.core.universe:attribute types has been guessed successfully.
# INFO:MDAnalysis.core.universe:attribute masses has been guessed successfully.
# /home/pnavarro/.conda/envs/deep_cartograph/lib/python3.10/site-packages/MDAnalysis/coordinates/PDB.py:1154: UserWarning: Found no information for attr: 'elements' Using default value of ' '
#   warnings.warn("Found no information for attr: '{}'"
# /home/pnavarro/.conda/envs/deep_cartograph/lib/python3.10/site-packages/MDAnalysis/coordinates/PDB.py:1154: UserWarning: Found no information for attr: 'formalcharges' Using default value of '0'
#   warnings.warn("Found no information for attr: '{}'"
# INFO:deep_cartograph.tools.traj_cluster.traj_cluster_workflow:Extracting centroid for cluster 2 from trajectory trajectory.xtc at frame 5855.
# INFO:MDAnalysis.core.universe:attribute types has been guessed successfully.
# INFO:MDAnalysis.core.universe:attribute masses has been guessed successfully.
# INFO:deep_cartograph.tools.traj_cluster.traj_cluster_workflow:Extracting centroid for cluster 1 from trajectory trajectory.xtc at frame 5867.
# INFO:MDAnalysis.core.universe:attribute types has been guessed successfully.
# INFO:MDAnalysis.core.universe:attribute masses has been guessed successfully.
# INFO:deep_cartograph:Elapsed time (Train colvars): 00 h 00 min 23 s
# INFO:deep_cartograph:Total elapsed time: 00 h 00 min 44 s
# INFO:deep_cartograph:================
# INFO:deep_cartograph:Analyze geometry
# INFO:deep_cartograph:================
# INFO:deep_cartograph:Elapsed time (Analyze geometry): 00 h 00 min 00 s
# INFO:deep_cartograph:================
# INFO:deep_cartograph:Compute features
# INFO:deep_cartograph:================
# INFO:MDAnalysis.core.universe:attribute types has been guessed successfully.
# INFO:MDAnalysis.core.universe:attribute masses has been guessed successfully.
# INFO:MDAnalysis.core.universe:attribute types has been guessed successfully.
# INFO:MDAnalysis.core.universe:attribute masses has been guessed successfully.
# INFO:deep_cartograph.modules.md.md:Topology does not contain bonds. Bonds will be guessed using a distance criterion (bond_length < 2.0).
# WARNING:deep_cartograph.modules.md.md:Topology does not contain bonds. Using a distance criterion (bond_length < 2.0) to guess bonds.
# INFO:MDAnalysis.core.universe:attribute types has been guessed successfully.
# INFO:MDAnalysis.core.universe:attribute masses has been guessed successfully.
# INFO:deep_cartograph:Computing features for trajectory with topology topology...
# /home/pnavarro/.conda/envs/deep_cartograph/lib/python3.10/site-packages/MDAnalysis/topology/PDBParser.py:350: UserWarning: Element information is missing, elements attribute will not be populated. If needed these can be guessed using universe.guess_TopologyAttrs(context='default', to_guess=['elements']).
#   warnings.warn("Element information is missing, elements attribute "
# INFO:MDAnalysis.core.universe:attribute types has been guessed successfully.
# INFO:MDAnalysis.core.universe:attribute masses has been guessed successfully.
# INFO:MDAnalysis.core.universe:attribute types has been guessed successfully.
# INFO:MDAnalysis.core.universe:attribute masses has been guessed successfully.
# INFO:deep_cartograph.modules.plumed.cli:Executing PLUMED command: plumed driver --plumed /home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/torsions/lag_10_1D/compute_features/trajectory/plumed_input.dat --mf_xtc /home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/input/500K/trajectory.xtc --natoms 22
# INFO:deep_cartograph.modules.plumed.cli:Restored working directory to: /home/pnavarro/repos/mlcolvar
# INFO:deep_cartograph:Elapsed time (Compute features): 00 h 00 min 00 s
# INFO:deep_cartograph:==================
# INFO:deep_cartograph:Filtering features
# INFO:deep_cartograph:==================
# INFO:deep_cartograph:Finding the features that contains the most information about the transitions or conformational changes.
# INFO:deep_cartograph:The following algorithms are available:
# INFO:deep_cartograph:- Hartigan's dip test filter. Keeps features that are not unimodal.
# INFO:deep_cartograph:- Shannon entropy filter. Keeps features with entropy greater than a threshold.
# INFO:deep_cartograph:- Standard deviation filter. Keeps features with standard deviation greater than a threshold.
# INFO:deep_cartograph:Note that the all features must be in the same units to apply the entropy and standard deviation filters meaningfully.
# INFO:deep_cartograph.modules.features.filter:Initializing Filter
# INFO:deep_cartograph.modules.features.filter:Initial size of features set (only common features): 20.
# INFO:deep_cartograph.modules.features.filter:Processed 2/20 features. Estimated time left: 0.28 seconds.
# INFO:deep_cartograph.modules.features.filter:Processed 4/20 features. Estimated time left: 0.25 seconds.
# INFO:deep_cartograph.modules.features.filter:Processed 6/20 features. Estimated time left: 0.22 seconds.
# INFO:deep_cartograph.modules.features.filter:Processed 8/20 features. Estimated time left: 0.18 seconds.
# INFO:deep_cartograph.modules.features.filter:Processed 10/20 features. Estimated time left: 0.15 seconds.
# INFO:deep_cartograph.modules.features.filter:Processed 12/20 features. Estimated time left: 0.12 seconds.
# INFO:deep_cartograph.modules.features.filter:Processed 14/20 features. Estimated time left: 0.09 seconds.
# INFO:deep_cartograph.modules.features.filter:Processed 16/20 features. Estimated time left: 0.06 seconds.
# INFO:deep_cartograph.modules.features.filter:Processed 18/20 features. Estimated time left: 0.03 seconds.
# INFO:deep_cartograph.modules.features.filter:Processed 20/20 features. Estimated time left: 0.00 seconds.
# INFO:deep_cartograph.modules.features.filter:Filtered 6 features.
# INFO:deep_cartograph:Elapsed time (Filter features): 00 h 00 min 00 s
# INFO:deep_cartograph.modules.common.common: Using features in /home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/torsions/lag_10_1D/filter_features/filtered_features.txt
# INFO:deep_cartograph:================================
# INFO:deep_cartograph:Training of Collective Variables
# INFO:deep_cartograph:================================
# INFO:deep_cartograph:Training of collective variables using the mlcolvar library.
# INFO:deep_cartograph.tools.train_colvars.train_colvars_workflow:Collective variables to compute: ['deep_tica']
# INFO:deep_cartograph.modules.cv_learning.cv_calculator:Creating DeepTICA Calculator ...
# INFO:deep_cartograph.modules.cv_learning.cv_calculator:Reading training data from colvars files...
# INFO:deep_cartograph.modules.cv_learning.cv_calculator:Number of features: 14
# INFO:deep_cartograph.modules.cv_learning.cv_calculator:Number of samples: 10001
# /home/pnavarro/repos/mlcolvar/mlcolvar/utils/timelagged.py:140: UserWarning: Monitoring the progress for the search of time-lagged configurations with a progress_bar requires `tqdm`.
#   warnings.warn(
# INFO:deep_cartograph.modules.cv_learning.cv_calculator:Training DeepTICA ...
# INFO:deep_cartograph.modules.cv_learning.cv_calculator:Model architecture: DeepTICA(
#   (loss_fn): ReduceEigenvaluesLoss()
#   (norm_in): Normalization(in_features=14, out_features=14, mode=custom)
#   (nn): FeedForward(
#     (nn): Sequential(
#       (0): Linear(in_features=14, out_features=8, bias=True)
#       (1): LeakyReLU(negative_slope=0.01, inplace=True)
#       (2): Linear(in_features=8, out_features=4, bias=True)
#       (3): LeakyReLU(negative_slope=0.01, inplace=True)
#       (4): Linear(in_features=4, out_features=1, bias=True)
#     )
#   )
#   (tica): TICA(in_features=1, out_features=1)
# )
# /home/pnavarro/.conda/envs/deep_cartograph/lib/python3.10/site-packages/lightning/fabric/plugins/environments/slurm.py:204: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/pnavarro/.conda/envs/deep_cartograph/lib/p ...
# INFO: GPU available: False, used: False
# INFO:lightning.pytorch.utilities.rank_zero:GPU available: False, used: False
# INFO: TPU available: False, using: 0 TPU cores
# INFO:lightning.pytorch.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO: HPU available: False, using: 0 HPUs
# INFO:lightning.pytorch.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:
#   | Name    | Type                  | Params | Mode  | In sizes | Out sizes
# ---------------------------------------------------------------------------------
# 0 | loss_fn | ReduceEigenvaluesLoss | 0      | train | ?        | ?
# 1 | norm_in | Normalization         | 0      | train | [1, 14]  | [1, 14]
# 2 | nn      | FeedForward           | 161    | train | [1, 14]  | [1, 1]
# 3 | tica    | TICA                  | 0      | train | [1, 1]   | [1, 1]
# ---------------------------------------------------------------------------------
# 161       Trainable params
# 0         Non-trainable params
# 161       Total params
# 0.001     Total estimated model params size (MB)
# 10        Modules in train mode
# 0         Modules in eval mode
# INFO:lightning.pytorch.callbacks.model_summary:
#   | Name    | Type                  | Params | Mode  | In sizes | Out sizes
# ---------------------------------------------------------------------------------
# 0 | loss_fn | ReduceEigenvaluesLoss | 0      | train | ?        | ?
# 1 | norm_in | Normalization         | 0      | train | [1, 14]  | [1, 14]
# 2 | nn      | FeedForward           | 161    | train | [1, 14]  | [1, 1]
# 3 | tica    | TICA                  | 0      | train | [1, 1]   | [1, 1]
# ---------------------------------------------------------------------------------
# 161       Trainable params
# 0         Non-trainable params
# 161       Total params
# 0.001     Total estimated model params size (MB)
# 10        Modules in train mode
# 0         Modules in eval mode
# INFO: `Trainer.fit` stopped: `max_epochs=100` reached.
# INFO:lightning.pytorch.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=100` reached.
# INFO:deep_cartograph.modules.cv_learning.cv_calculator:Successfully loaded the 'last' model from: /home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/torsions/lag_10_1D/train_colvars/deep_tica/training/checkpoints/last.ckpt
# INFO:deep_cartograph.modules.cv_learning.cv_calculator:  -> Best Overall Score:      -0.72129
# INFO:deep_cartograph.modules.cv_learning.cv_calculator:  -> Last Model Score:          -0.66881
# /home/pnavarro/repos/mlcolvar/mlcolvar/utils/plot.py:255: UserWarning: Data has no positive values, and therefore cannot be log-scaled.
#   ax.set_yscale(yscale)
# WARNING:deep_cartograph.modules.cv_learning.cv_calculator:Learning rate not found in metrics. Learning rate plot will not be generated.
# INFO:deep_cartograph.modules.cv_learning.cv_calculator:Took 99 epochs
# INFO:deep_cartograph.modules.cv_learning.cv_calculator:Eigenvalue 1: 0.8094186186790466
# INFO:deep_cartograph.modules.common.common:Starting compression to '/home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/torsions/lag_10_1D/train_colvars/deep_tica/training/training_metrics.zip'...
# INFO:deep_cartograph.modules.common.common:Successfully created zip file: '/home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/torsions/lag_10_1D/train_colvars/deep_tica/training/training_metrics.zip'
# INFO:deep_cartograph.modules.cv_learning.cv_calculator:Training metrics saved to /home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/torsions/lag_10_1D/train_colvars/deep_tica/training/training_metrics.zip
# INFO:deep_cartograph.modules.cv_learning.cv_calculator:Projecting data onto DeepTICA ...
# /home/pnavarro/.conda/envs/deep_cartograph/lib/python3.10/site-packages/MDAnalysis/topology/PDBParser.py:350: UserWarning: Element information is missing, elements attribute will not be populated. If needed these can be guessed using universe.guess_TopologyAttrs(context='default', to_guess=['elements']).
#   warnings.warn("Element information is missing, elements attribute "
# INFO:MDAnalysis.core.universe:attribute types has been guessed successfully.
# INFO:MDAnalysis.core.universe:attribute masses has been guessed successfully.
# /home/pnavarro/.conda/envs/deep_cartograph/lib/python3.10/site-packages/MDAnalysis/coordinates/PDB.py:1154: UserWarning: Found no information for attr: 'elements' Using default value of ' '
#   warnings.warn("Found no information for attr: '{}'"
# /home/pnavarro/.conda/envs/deep_cartograph/lib/python3.10/site-packages/MDAnalysis/coordinates/PDB.py:1154: UserWarning: Found no information for attr: 'formalcharges' Using default value of '0'
#   warnings.warn("Found no information for attr: '{}'"
# INFO:deep_cartograph.modules.common.common:Starting compression to '/home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/torsions/lag_10_1D/train_colvars/deep_tica/model.zip'...
# INFO:deep_cartograph.modules.common.common:Successfully created zip file: '/home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/torsions/lag_10_1D/train_colvars/deep_tica/model.zip'
# INFO:deep_cartograph.modules.cv_learning.cv_calculator:Model saved to /home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/torsions/lag_10_1D/train_colvars/deep_tica/model.zip
# KEY:  data
#
#
# KEY:  data_lag
#
#
# KEY:  weights
#
#
# KEY:  weights_lag
# INFO:deep_cartograph.tools.train_colvars.train_colvars_workflow:Processing trajectory: trajectory
# INFO:deep_cartograph.tools.train_colvars.train_colvars_workflow:Corresponding colvars file: /home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/torsions/lag_10_1D/compute_features/trajectory/colvars.dat
# INFO:deep_cartograph.tools.train_colvars.train_colvars_workflow:Corresponding topology file: /home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/input/topology.pdb
# /home/pnavarro/.conda/envs/deep_cartograph/lib/python3.10/site-packages/MDAnalysis/topology/PDBParser.py:350: UserWarning: Element information is missing, elements attribute will not be populated. If needed these can be guessed using universe.guess_TopologyAttrs(context='default', to_guess=['elements']).
#   warnings.warn("Element information is missing, elements attribute "
# INFO:MDAnalysis.core.universe:attribute types has been guessed successfully.
# INFO:MDAnalysis.core.universe:attribute masses has been guessed successfully.
# /home/pnavarro/.conda/envs/deep_cartograph/lib/python3.10/site-packages/MDAnalysis/coordinates/PDB.py:1154: UserWarning: Found no information for attr: 'elements' Using default value of ' '
#   warnings.warn("Found no information for attr: '{}'"
# /home/pnavarro/.conda/envs/deep_cartograph/lib/python3.10/site-packages/MDAnalysis/coordinates/PDB.py:1154: UserWarning: Found no information for attr: 'formalcharges' Using default value of '0'
#   warnings.warn("Found no information for attr: '{}'"
# INFO:MDAnalysis.core.universe:attribute types has been guessed successfully.
# INFO:MDAnalysis.core.universe:attribute masses has been guessed successfully.
# /home/pnavarro/.conda/envs/deep_cartograph/lib/python3.10/site-packages/MDAnalysis/topology/PDBParser.py:350: UserWarning: Element information is missing, elements attribute will not be populated. If needed these can be guessed using universe.guess_TopologyAttrs(context='default', to_guess=['elements']).
#   warnings.warn("Element information is missing, elements attribute "
# INFO:MDAnalysis.core.universe:attribute types has been guessed successfully.
# INFO:MDAnalysis.core.universe:attribute masses has been guessed successfully.
# INFO:deep_cartograph.modules.common.common:Starting compression to '/home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/torsions/lag_10_1D/train_colvars/deep_tica/traj_data/trajectory/plumed_inputs/plumed_deep_tica_unbiased.zip'...
# INFO:deep_cartograph.modules.common.common:Successfully created zip file: '/home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/torsions/lag_10_1D/train_colvars/deep_tica/traj_data/trajectory/plumed_inputs/plumed_deep_tica_unbiased.zip'
# INFO:MDAnalysis.core.universe:attribute types has been guessed successfully.
# INFO:MDAnalysis.core.universe:attribute masses has been guessed successfully.
# INFO:deep_cartograph.modules.common.common:Starting compression to '/home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/torsions/lag_10_1D/train_colvars/deep_tica/traj_data/trajectory/plumed_inputs/plumed_deep_tica_biased.zip'...
# INFO:deep_cartograph.modules.common.common:Successfully created zip file: '/home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/torsions/lag_10_1D/train_colvars/deep_tica/traj_data/trajectory/plumed_inputs/plumed_deep_tica_biased.zip'
# INFO:deep_cartograph:Elapsed time (Train colvars): 00 h 00 min 20 s
# INFO:deep_cartograph:Clustering trajectories in CV space: deep_tica
# INFO:deep_cartograph:=====================================
# INFO:deep_cartograph:Trajectory clustering on the CV space
# INFO:deep_cartograph:=====================================
# INFO:deep_cartograph:Clustering of trajectories using sklearn.
# INFO:deep_cartograph.tools.traj_cluster.traj_cluster_workflow:Starting traj_cluster workflow...
# INFO:deep_cartograph.modules.statistics.statistics:Best number of clusters: 3
# INFO:deep_cartograph.tools.traj_cluster.traj_cluster_workflow:Extracting centroids from the trajectories...
# INFO:deep_cartograph.tools.traj_cluster.traj_cluster_workflow:Extracting centroid for cluster 0 from trajectory trajectory.xtc at frame 968.
# /home/pnavarro/.conda/envs/deep_cartograph/lib/python3.10/site-packages/MDAnalysis/topology/PDBParser.py:350: UserWarning: Element information is missing, elements attribute will not be populated. If needed these can be guessed using universe.guess_TopologyAttrs(context='default', to_guess=['elements']).
#   warnings.warn("Element information is missing, elements attribute "
# INFO:MDAnalysis.core.universe:attribute types has been guessed successfully.
# INFO:MDAnalysis.core.universe:attribute masses has been guessed successfully.
# /home/pnavarro/.conda/envs/deep_cartograph/lib/python3.10/site-packages/MDAnalysis/coordinates/PDB.py:1154: UserWarning: Found no information for attr: 'elements' Using default value of ' '
#   warnings.warn("Found no information for attr: '{}'"
# /home/pnavarro/.conda/envs/deep_cartograph/lib/python3.10/site-packages/MDAnalysis/coordinates/PDB.py:1154: UserWarning: Found no information for attr: 'formalcharges' Using default value of '0'
#   warnings.warn("Found no information for attr: '{}'"
# INFO:deep_cartograph.tools.traj_cluster.traj_cluster_workflow:Extracting centroid for cluster 2 from trajectory trajectory.xtc at frame 1392.
# INFO:MDAnalysis.core.universe:attribute types has been guessed successfully.
# INFO:MDAnalysis.core.universe:attribute masses has been guessed successfully.
# INFO:deep_cartograph.tools.traj_cluster.traj_cluster_workflow:Extracting centroid for cluster 1 from trajectory trajectory.xtc at frame 2446.
# INFO:MDAnalysis.core.universe:attribute types has been guessed successfully.
# INFO:MDAnalysis.core.universe:attribute masses has been guessed successfully.
# INFO:deep_cartograph:Elapsed time (Train colvars): 00 h 00 min 19 s
# INFO:deep_cartograph:Total elapsed time: 00 h 00 min 40 s
# INFO:deep_cartograph:================
# INFO:deep_cartograph:Analyze geometry
# INFO:deep_cartograph:================
# INFO:deep_cartograph:Elapsed time (Analyze geometry): 00 h 00 min 00 s
# INFO:deep_cartograph:================
# INFO:deep_cartograph:Compute features
# INFO:deep_cartograph:================
# INFO:MDAnalysis.core.universe:attribute types has been guessed successfully.
# INFO:MDAnalysis.core.universe:attribute masses has been guessed successfully.
# INFO:MDAnalysis.core.universe:attribute types has been guessed successfully.
# INFO:MDAnalysis.core.universe:attribute masses has been guessed successfully.
# INFO:deep_cartograph.modules.md.md:Topology does not contain bonds. Bonds will be guessed using a distance criterion (bond_length < 2.0).
# WARNING:deep_cartograph.modules.md.md:Topology does not contain bonds. Using a distance criterion (bond_length < 2.0) to guess bonds.
# INFO:MDAnalysis.core.universe:attribute types has been guessed successfully.
# INFO:MDAnalysis.core.universe:attribute masses has been guessed successfully.
# INFO:deep_cartograph:Computing features for trajectory with topology topology...
# /home/pnavarro/.conda/envs/deep_cartograph/lib/python3.10/site-packages/MDAnalysis/topology/PDBParser.py:350: UserWarning: Element information is missing, elements attribute will not be populated. If needed these can be guessed using universe.guess_TopologyAttrs(context='default', to_guess=['elements']).
#   warnings.warn("Element information is missing, elements attribute "
# INFO:MDAnalysis.core.universe:attribute types has been guessed successfully.
# INFO:MDAnalysis.core.universe:attribute masses has been guessed successfully.
# INFO:MDAnalysis.core.universe:attribute types has been guessed successfully.
# INFO:MDAnalysis.core.universe:attribute masses has been guessed successfully.
# INFO:deep_cartograph.modules.plumed.cli:Executing PLUMED command: plumed driver --plumed /home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/torsions/lag_50_1D/compute_features/trajectory/plumed_input.dat --mf_xtc /home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/input/500K/trajectory.xtc --natoms 22
# INFO:deep_cartograph.modules.plumed.cli:Restored working directory to: /home/pnavarro/repos/mlcolvar
# INFO:deep_cartograph:Elapsed time (Compute features): 00 h 00 min 00 s
# INFO:deep_cartograph:==================
# INFO:deep_cartograph:Filtering features
# INFO:deep_cartograph:==================
# INFO:deep_cartograph:Finding the features that contains the most information about the transitions or conformational changes.
# INFO:deep_cartograph:The following algorithms are available:
# INFO:deep_cartograph:- Hartigan's dip test filter. Keeps features that are not unimodal.
# INFO:deep_cartograph:- Shannon entropy filter. Keeps features with entropy greater than a threshold.
# INFO:deep_cartograph:- Standard deviation filter. Keeps features with standard deviation greater than a threshold.
# INFO:deep_cartograph:Note that the all features must be in the same units to apply the entropy and standard deviation filters meaningfully.
# INFO:deep_cartograph.modules.features.filter:Initializing Filter
# INFO:deep_cartograph.modules.features.filter:Initial size of features set (only common features): 20.
# INFO:deep_cartograph.modules.features.filter:Processed 2/20 features. Estimated time left: 0.41 seconds.
# INFO:deep_cartograph.modules.features.filter:Processed 4/20 features. Estimated time left: 0.35 seconds.
# INFO:deep_cartograph.modules.features.filter:Processed 6/20 features. Estimated time left: 0.28 seconds.
# INFO:deep_cartograph.modules.features.filter:Processed 8/20 features. Estimated time left: 0.23 seconds.
# INFO:deep_cartograph.modules.features.filter:Processed 10/20 features. Estimated time left: 0.18 seconds.
# INFO:deep_cartograph.modules.features.filter:Processed 12/20 features. Estimated time left: 0.14 seconds.
# INFO:deep_cartograph.modules.features.filter:Processed 14/20 features. Estimated time left: 0.11 seconds.
# INFO:deep_cartograph.modules.features.filter:Processed 16/20 features. Estimated time left: 0.07 seconds.
# INFO:deep_cartograph.modules.features.filter:Processed 18/20 features. Estimated time left: 0.03 seconds.
# INFO:deep_cartograph.modules.features.filter:Processed 20/20 features. Estimated time left: 0.00 seconds.
# INFO:deep_cartograph.modules.features.filter:Filtered 6 features.
# INFO:deep_cartograph:Elapsed time (Filter features): 00 h 00 min 00 s
# INFO:deep_cartograph.modules.common.common: Using features in /home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/torsions/lag_50_1D/filter_features/filtered_features.txt
# INFO:deep_cartograph:================================
# INFO:deep_cartograph:Training of Collective Variables
# INFO:deep_cartograph:================================
# INFO:deep_cartograph:Training of collective variables using the mlcolvar library.
# INFO:deep_cartograph.tools.train_colvars.train_colvars_workflow:Collective variables to compute: ['deep_tica']
# INFO:deep_cartograph.modules.cv_learning.cv_calculator:Creating DeepTICA Calculator ...
# INFO:deep_cartograph.modules.cv_learning.cv_calculator:Reading training data from colvars files...
# INFO:deep_cartograph.modules.cv_learning.cv_calculator:Number of features: 14
# INFO:deep_cartograph.modules.cv_learning.cv_calculator:Number of samples: 10001
# /home/pnavarro/repos/mlcolvar/mlcolvar/utils/timelagged.py:140: UserWarning: Monitoring the progress for the search of time-lagged configurations with a progress_bar requires `tqdm`.
#   warnings.warn(
# INFO:deep_cartograph.modules.cv_learning.cv_calculator:Training DeepTICA ...
# INFO:deep_cartograph.modules.cv_learning.cv_calculator:Model architecture: DeepTICA(
#   (loss_fn): ReduceEigenvaluesLoss()
#   (norm_in): Normalization(in_features=14, out_features=14, mode=custom)
#   (nn): FeedForward(
#     (nn): Sequential(
#       (0): Linear(in_features=14, out_features=8, bias=True)
#       (1): LeakyReLU(negative_slope=0.01, inplace=True)
#       (2): Linear(in_features=8, out_features=4, bias=True)
#       (3): LeakyReLU(negative_slope=0.01, inplace=True)
#       (4): Linear(in_features=4, out_features=1, bias=True)
#     )
#   )
#   (tica): TICA(in_features=1, out_features=1)
# )
# /home/pnavarro/.conda/envs/deep_cartograph/lib/python3.10/site-packages/lightning/fabric/plugins/environments/slurm.py:204: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/pnavarro/.conda/envs/deep_cartograph/lib/p ...
# INFO: GPU available: False, used: False
# INFO:lightning.pytorch.utilities.rank_zero:GPU available: False, used: False
# INFO: TPU available: False, using: 0 TPU cores
# INFO:lightning.pytorch.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO: HPU available: False, using: 0 HPUs
# INFO:lightning.pytorch.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:
#   | Name    | Type                  | Params | Mode  | In sizes | Out sizes
# ---------------------------------------------------------------------------------
# 0 | loss_fn | ReduceEigenvaluesLoss | 0      | train | ?        | ?
# 1 | norm_in | Normalization         | 0      | train | [1, 14]  | [1, 14]
# 2 | nn      | FeedForward           | 161    | train | [1, 14]  | [1, 1]
# 3 | tica    | TICA                  | 0      | train | [1, 1]   | [1, 1]
# ---------------------------------------------------------------------------------
# 161       Trainable params
# 0         Non-trainable params
# 161       Total params
# 0.001     Total estimated model params size (MB)
# 10        Modules in train mode
# 0         Modules in eval mode
# INFO:lightning.pytorch.callbacks.model_summary:
#   | Name    | Type                  | Params | Mode  | In sizes | Out sizes
# ---------------------------------------------------------------------------------
# 0 | loss_fn | ReduceEigenvaluesLoss | 0      | train | ?        | ?
# 1 | norm_in | Normalization         | 0      | train | [1, 14]  | [1, 14]
# 2 | nn      | FeedForward           | 161    | train | [1, 14]  | [1, 1]
# 3 | tica    | TICA                  | 0      | train | [1, 1]   | [1, 1]
# ---------------------------------------------------------------------------------
# 161       Trainable params
# 0         Non-trainable params
# 161       Total params
# 0.001     Total estimated model params size (MB)
# 10        Modules in train mode
# 0         Modules in eval mode
# INFO: `Trainer.fit` stopped: `max_epochs=100` reached.
# INFO:lightning.pytorch.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=100` reached.
# INFO:deep_cartograph.modules.cv_learning.cv_calculator:Successfully loaded the 'last' model from: /home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/torsions/lag_50_1D/train_colvars/deep_tica/training/checkpoints/last.ckpt
# INFO:deep_cartograph.modules.cv_learning.cv_calculator:  -> Best Overall Score:      -0.13450
# INFO:deep_cartograph.modules.cv_learning.cv_calculator:  -> Last Model Score:          -0.09275
# /home/pnavarro/repos/mlcolvar/mlcolvar/utils/plot.py:255: UserWarning: Data has no positive values, and therefore cannot be log-scaled.
#   ax.set_yscale(yscale)
# WARNING:deep_cartograph.modules.cv_learning.cv_calculator:Learning rate not found in metrics. Learning rate plot will not be generated.
# INFO:deep_cartograph.modules.cv_learning.cv_calculator:Took 99 epochs
# INFO:deep_cartograph.modules.cv_learning.cv_calculator:Eigenvalue 1: 0.29042673110961914
# INFO:deep_cartograph.modules.common.common:Starting compression to '/home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/torsions/lag_50_1D/train_colvars/deep_tica/training/training_metrics.zip'...
# INFO:deep_cartograph.modules.common.common:Successfully created zip file: '/home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/torsions/lag_50_1D/train_colvars/deep_tica/training/training_metrics.zip'
# INFO:deep_cartograph.modules.cv_learning.cv_calculator:Training metrics saved to /home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/torsions/lag_50_1D/train_colvars/deep_tica/training/training_metrics.zip
# INFO:deep_cartograph.modules.cv_learning.cv_calculator:Projecting data onto DeepTICA ...
# ...
# INFO:deep_cartograph:The following algorithms are available:
# INFO:deep_cartograph:- Hartigan's dip test filter. Keeps features that are not unimodal.
# INFO:deep_cartograph:- Shannon entropy filter. Keeps features with entropy greater than a threshold.
# INFO:deep_cartograph:- Standard deviation filter. Keeps features with standard deviation greater than a threshold.
# INFO:deep_cartograph:Note that the all features must be in the same units to apply the entropy and standard deviation filters meaningfully.
# INFO:deep_cartograph.modules.features.filter:Initializing Filter
# INFO:deep_cartograph.modules.features.filter:Initial size of features set (only common features): 20.
# INFO:deep_cartograph.modules.features.filter:Processed 2/20 features. Estimated time left: 0.43 seconds.
# INFO:deep_cartograph.modules.features.filter:Processed 4/20 features. Estimated time left: 0.37 seconds.
# INFO:deep_cartograph.modules.features.filter:Processed 6/20 features. Estimated time left: 0.29 seconds.
# INFO:deep_cartograph.modules.features.filter:Processed 8/20 features. Estimated time left: 0.23 seconds.
# INFO:deep_cartograph.modules.features.filter:Processed 10/20 features. Estimated time left: 0.19 seconds.
# INFO:deep_cartograph.modules.features.filter:Processed 12/20 features. Estimated time left: 0.16 seconds.
# INFO:deep_cartograph.modules.features.filter:Processed 14/20 features. Estimated time left: 0.12 seconds.
# INFO:deep_cartograph.modules.features.filter:Processed 16/20 features. Estimated time left: 0.08 seconds.
# INFO:deep_cartograph.modules.features.filter:Processed 18/20 features. Estimated time left: 0.04 seconds.
# INFO:deep_cartograph.modules.features.filter:Processed 20/20 features. Estimated time left: 0.00 seconds.
# INFO:deep_cartograph.modules.features.filter:Filtered 6 features.
# INFO:deep_cartograph:Elapsed time (Filter features): 00 h 00 min 00 s
# INFO:deep_cartograph.modules.common.common: Using features in /home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/torsions/lag_200_1D/filter_features/filtered_features.txt
# INFO:deep_cartograph:================================
# INFO:deep_cartograph:Training of Collective Variables
# INFO:deep_cartograph:================================
# INFO:deep_cartograph:Training of collective variables using the mlcolvar library.
# INFO:deep_cartograph.tools.train_colvars.train_colvars_workflow:Collective variables to compute: ['deep_tica']
# INFO:deep_cartograph.modules.cv_learning.cv_calculator:Creating DeepTICA Calculator ...
# INFO:deep_cartograph.modules.cv_learning.cv_calculator:Reading training data from colvars files...
# INFO:deep_cartograph.modules.cv_learning.cv_calculator:Number of features: 14
# INFO:deep_cartograph.modules.cv_learning.cv_calculator:Number of samples: 10001
# /home/pnavarro/repos/mlcolvar/mlcolvar/utils/timelagged.py:140: UserWarning: Monitoring the progress for the search of time-lagged configurations with a progress_bar requires `tqdm`.
#   warnings.warn(
# INFO:deep_cartograph.modules.cv_learning.cv_calculator:Training DeepTICA ...
# INFO:deep_cartograph.modules.cv_learning.cv_calculator:Model architecture: DeepTICA(
#   (loss_fn): ReduceEigenvaluesLoss()
#   (norm_in): Normalization(in_features=14, out_features=14, mode=custom)
#   (nn): FeedForward(
#     (nn): Sequential(
#       (0): Linear(in_features=14, out_features=8, bias=True)
#       (1): LeakyReLU(negative_slope=0.01, inplace=True)
#       (2): Linear(in_features=8, out_features=4, bias=True)
#       (3): LeakyReLU(negative_slope=0.01, inplace=True)
#       (4): Linear(in_features=4, out_features=1, bias=True)
#     )
#   )
#   (tica): TICA(in_features=1, out_features=1)
# )
# /home/pnavarro/.conda/envs/deep_cartograph/lib/python3.10/site-packages/lightning/fabric/plugins/environments/slurm.py:204: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/pnavarro/.conda/envs/deep_cartograph/lib/p ...
# INFO: GPU available: False, used: False
# INFO:lightning.pytorch.utilities.rank_zero:GPU available: False, used: False
# INFO: TPU available: False, using: 0 TPU cores
# INFO:lightning.pytorch.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO: HPU available: False, using: 0 HPUs
# INFO:lightning.pytorch.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:
#   | Name    | Type                  | Params | Mode  | In sizes | Out sizes
# ---------------------------------------------------------------------------------
# 0 | loss_fn | ReduceEigenvaluesLoss | 0      | train | ?        | ?
# 1 | norm_in | Normalization         | 0      | train | [1, 14]  | [1, 14]
# 2 | nn      | FeedForward           | 161    | train | [1, 14]  | [1, 1]
# 3 | tica    | TICA                  | 0      | train | [1, 1]   | [1, 1]
# ---------------------------------------------------------------------------------
# 161       Trainable params
# 0         Non-trainable params
# 161       Total params
# 0.001     Total estimated model params size (MB)
# 10        Modules in train mode
# 0         Modules in eval mode
# INFO:lightning.pytorch.callbacks.model_summary:
#   | Name    | Type                  | Params | Mode  | In sizes | Out sizes
# ---------------------------------------------------------------------------------
# 0 | loss_fn | ReduceEigenvaluesLoss | 0      | train | ?        | ?
# 1 | norm_in | Normalization         | 0      | train | [1, 14]  | [1, 14]
# 2 | nn      | FeedForward           | 161    | train | [1, 14]  | [1, 1]
# 3 | tica    | TICA                  | 0      | train | [1, 1]   | [1, 1]
# ---------------------------------------------------------------------------------
# 161       Trainable params
# 0         Non-trainable params
# 161       Total params
# 0.001     Total estimated model params size (MB)
# 10        Modules in train mode
# 0         Modules in eval mode
# INFO: `Trainer.fit` stopped: `max_epochs=100` reached.
# INFO:lightning.pytorch.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=100` reached.
# INFO:deep_cartograph.modules.cv_learning.cv_calculator:Successfully loaded the 'last' model from: /home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/torsions/lag_200_1D/train_colvars/deep_tica/training/checkpoints/last.ckpt
# INFO:deep_cartograph.modules.cv_learning.cv_calculator:  -> Best Overall Score:      -0.01063
# INFO:deep_cartograph.modules.cv_learning.cv_calculator:  -> Last Model Score:          -0.00050
# /home/pnavarro/repos/mlcolvar/mlcolvar/utils/plot.py:255: UserWarning: Data has no positive values, and therefore cannot be log-scaled.
#   ax.set_yscale(yscale)
# WARNING:deep_cartograph.modules.cv_learning.cv_calculator:Learning rate not found in metrics. Learning rate plot will not be generated.
# INFO:deep_cartograph.modules.cv_learning.cv_calculator:Took 99 epochs
# INFO:deep_cartograph.modules.cv_learning.cv_calculator:Eigenvalue 1: -0.008829678408801556
# INFO:deep_cartograph.modules.common.common:Starting compression to '/home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/torsions/lag_200_1D/train_colvars/deep_tica/training/training_metrics.zip'...
# INFO:deep_cartograph.modules.common.common:Successfully created zip file: '/home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/torsions/lag_200_1D/train_colvars/deep_tica/training/training_metrics.zip'
# INFO:deep_cartograph.modules.cv_learning.cv_calculator:Training metrics saved to /home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/torsions/lag_200_1D/train_colvars/deep_tica/training/training_metrics.zip
# INFO:deep_cartograph.modules.cv_learning.cv_calculator:Projecting data onto DeepTICA ...
# /home/pnavarro/.conda/envs/deep_cartograph/lib/python3.10/site-packages/MDAnalysis/topology/PDBParser.py:350: UserWarning: Element information is missing, elements attribute will not be populated. If needed these can be guessed using universe.guess_TopologyAttrs(context='default', to_guess=['elements']).
#   warnings.warn("Element information is missing, elements attribute "
# INFO:MDAnalysis.core.universe:attribute types has been guessed successfully.
# INFO:MDAnalysis.core.universe:attribute masses has been guessed successfully.
# /home/pnavarro/.conda/envs/deep_cartograph/lib/python3.10/site-packages/MDAnalysis/coordinates/PDB.py:1154: UserWarning: Found no information for attr: 'elements' Using default value of ' '
#   warnings.warn("Found no information for attr: '{}'"
# /home/pnavarro/.conda/envs/deep_cartograph/lib/python3.10/site-packages/MDAnalysis/coordinates/PDB.py:1154: UserWarning: Found no information for attr: 'formalcharges' Using default value of '0'
#   warnings.warn("Found no information for attr: '{}'"
# INFO:deep_cartograph.modules.common.common:Starting compression to '/home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/torsions/lag_200_1D/train_colvars/deep_tica/model.zip'...
# INFO:deep_cartograph.modules.common.common:Successfully created zip file: '/home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/torsions/lag_200_1D/train_colvars/deep_tica/model.zip'
# INFO:deep_cartograph.modules.cv_learning.cv_calculator:Model saved to /home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/torsions/lag_200_1D/train_colvars/deep_tica/model.zip
# KEY:  data
#
#
# KEY:  data_lag
#
#
# KEY:  weights
#
#
# KEY:  weights_lag
# INFO:deep_cartograph.tools.train_colvars.train_colvars_workflow:Processing trajectory: trajectory
# INFO:deep_cartograph.tools.train_colvars.train_colvars_workflow:Corresponding colvars file: /home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/torsions/lag_200_1D/compute_features/trajectory/colvars.dat
# INFO:deep_cartograph.tools.train_colvars.train_colvars_workflow:Corresponding topology file: /home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/input/topology.pdb
# /home/pnavarro/.conda/envs/deep_cartograph/lib/python3.10/site-packages/MDAnalysis/topology/PDBParser.py:350: UserWarning: Element information is missing, elements attribute will not be populated. If needed these can be guessed using universe.guess_TopologyAttrs(context='default', to_guess=['elements']).
#   warnings.warn("Element information is missing, elements attribute "
# INFO:MDAnalysis.core.universe:attribute types has been guessed successfully.
# INFO:MDAnalysis.core.universe:attribute masses has been guessed successfully.
# /home/pnavarro/.conda/envs/deep_cartograph/lib/python3.10/site-packages/MDAnalysis/coordinates/PDB.py:1154: UserWarning: Found no information for attr: 'elements' Using default value of ' '
#   warnings.warn("Found no information for attr: '{}'"
# /home/pnavarro/.conda/envs/deep_cartograph/lib/python3.10/site-packages/MDAnalysis/coordinates/PDB.py:1154: UserWarning: Found no information for attr: 'formalcharges' Using default value of '0'
#   warnings.warn("Found no information for attr: '{}'"
# INFO:MDAnalysis.core.universe:attribute types has been guessed successfully.
# INFO:MDAnalysis.core.universe:attribute masses has been guessed successfully.
# /home/pnavarro/.conda/envs/deep_cartograph/lib/python3.10/site-packages/MDAnalysis/topology/PDBParser.py:350: UserWarning: Element information is missing, elements attribute will not be populated. If needed these can be guessed using universe.guess_TopologyAttrs(context='default', to_guess=['elements']).
#   warnings.warn("Element information is missing, elements attribute "
# INFO:MDAnalysis.core.universe:attribute types has been guessed successfully.
# INFO:MDAnalysis.core.universe:attribute masses has been guessed successfully.
# INFO:deep_cartograph.modules.common.common:Starting compression to '/home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/torsions/lag_200_1D/train_colvars/deep_tica/traj_data/trajectory/plumed_inputs/plumed_deep_tica_unbiased.zip'...
# INFO:deep_cartograph.modules.common.common:Successfully created zip file: '/home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/torsions/lag_200_1D/train_colvars/deep_tica/traj_data/trajectory/plumed_inputs/plumed_deep_tica_unbiased.zip'
# INFO:MDAnalysis.core.universe:attribute types has been guessed successfully.
# INFO:MDAnalysis.core.universe:attribute masses has been guessed successfully.
# INFO:deep_cartograph.modules.common.common:Starting compression to '/home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/torsions/lag_200_1D/train_colvars/deep_tica/traj_data/trajectory/plumed_inputs/plumed_deep_tica_biased.zip'...
# INFO:deep_cartograph.modules.common.common:Successfully created zip file: '/home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/torsions/lag_200_1D/train_colvars/deep_tica/traj_data/trajectory/plumed_inputs/plumed_deep_tica_biased.zip'
# INFO:deep_cartograph:Elapsed time (Train colvars): 00 h 00 min 43 s
# INFO:deep_cartograph:Clustering trajectories in CV space: deep_tica
# INFO:deep_cartograph:=====================================
# INFO:deep_cartograph:Trajectory clustering on the CV space
# INFO:deep_cartograph:=====================================
# INFO:deep_cartograph:Clustering of trajectories using sklearn.
# INFO:deep_cartograph.tools.traj_cluster.traj_cluster_workflow:Starting traj_cluster workflow...
# INFO:deep_cartograph.modules.statistics.statistics:Best number of clusters: 4
# INFO:deep_cartograph.tools.traj_cluster.traj_cluster_workflow:Extracting centroids from the trajectories...
# INFO:deep_cartograph.tools.traj_cluster.traj_cluster_workflow:Extracting centroid for cluster 2 from trajectory trajectory.xtc at frame 58.
# /home/pnavarro/.conda/envs/deep_cartograph/lib/python3.10/site-packages/MDAnalysis/topology/PDBParser.py:350: UserWarning: Element information is missing, elements attribute will not be populated. If needed these can be guessed using universe.guess_TopologyAttrs(context='default', to_guess=['elements']).
#   warnings.warn("Element information is missing, elements attribute "
# INFO:MDAnalysis.core.universe:attribute types has been guessed successfully.
# INFO:MDAnalysis.core.universe:attribute masses has been guessed successfully.
# /home/pnavarro/.conda/envs/deep_cartograph/lib/python3.10/site-packages/MDAnalysis/coordinates/PDB.py:1154: UserWarning: Found no information for attr: 'elements' Using default value of ' '
#   warnings.warn("Found no information for attr: '{}'"
# /home/pnavarro/.conda/envs/deep_cartograph/lib/python3.10/site-packages/MDAnalysis/coordinates/PDB.py:1154: UserWarning: Found no information for attr: 'formalcharges' Using default value of '0'
#   warnings.warn("Found no information for attr: '{}'"
# INFO:deep_cartograph.tools.traj_cluster.traj_cluster_workflow:Extracting centroid for cluster 3 from trajectory trajectory.xtc at frame 2962.
# INFO:MDAnalysis.core.universe:attribute types has been guessed successfully.
# INFO:MDAnalysis.core.universe:attribute masses has been guessed successfully.
# INFO:deep_cartograph.tools.traj_cluster.traj_cluster_workflow:Extracting centroid for cluster 0 from trajectory trajectory.xtc at frame 5656.
# INFO:MDAnalysis.core.universe:attribute types has been guessed successfully.
# INFO:MDAnalysis.core.universe:attribute masses has been guessed successfully.
# INFO:deep_cartograph.tools.traj_cluster.traj_cluster_workflow:Extracting centroid for cluster 1 from trajectory trajectory.xtc at frame 9768.
# INFO:MDAnalysis.core.universe:attribute types has been guessed successfully.
# INFO:MDAnalysis.core.universe:attribute masses has been guessed successfully.
# INFO:deep_cartograph:Elapsed time (Train colvars): 00 h 00 min 23 s
# INFO:deep_cartograph:Total elapsed time: 00 h 01 min 08 s

# %%
# Show results for the Deep TICA model

for lag_time in lag_times:

    print(f"Lag time: {lag_time} ----------------------------------------------- #")

    # Name of the test
    test_name = f'lag_{lag_time}_1D'

    # Show main results
    show_results(features, temperature, 'deep_tica', test_name)
# Out:
# Lag time: 1 ----------------------------------------------- #
# Output folder: /home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/torsions/lag_1_1D
# Phi psi path: /home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/input/500K/phi_psi.dat
# Final model score: -9.5487E-1
# Eigenvalue 1: 9.7676E-1
# <img src="/home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/torsions/lag_1_1D/train_colvars/deep_tica/traj_data/trajectory/DeepTIC 1_ramachandran.png?1765904125" style="width: 600px; margin-right: 10px;">
# Lag time: 10 ----------------------------------------------- #
# Output folder: /home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/torsions/lag_10_1D
# Phi psi path: /home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/input/500K/phi_psi.dat
# Final model score: -6.6881E-1
# Eigenvalue 1: 8.0942E-1
# <img src="/home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/torsions/lag_10_1D/train_colvars/deep_tica/traj_data/trajectory/DeepTIC 1_ramachandran.png?1765904126" style="width: 600px; margin-right: 10px;">
# Lag time: 50 ----------------------------------------------- #
# Output folder: /home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/torsions/lag_50_1D
# Phi psi path: /home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/input/500K/phi_psi.dat
# Final model score: -9.2748E-2
# Eigenvalue 1: 2.9043E-1
# <img src="/home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/torsions/lag_50_1D/train_colvars/deep_tica/traj_data/trajectory/DeepTIC 1_ramachandran.png?1765904126" style="width: 600px; margin-right: 10px;">
# Lag time: 200 ----------------------------------------------- #
# Output folder: /home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/torsions/lag_200_1D
# Phi psi path: /home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/input/500K/phi_psi.dat
# Final model score: -4.9800E-4
# Eigenvalue 1: -8.8297E-3
# <img src="/home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/torsions/lag_200_1D/train_colvars/deep_tica/traj_data/trajectory/DeepTIC 1_ramachandran.png?1765904127" style="width: 600px; margin-right: 10px;">

# %% [markdown]
# We see here that:
#
# - Small lag time (1 ps) captures all slow transitions with a stable training.
# - Large lag times (> 100 ps) only capture the main slow mode and yield unstable trainings.

# %% [markdown]
# Until now we where working with torsion features. In this case, two of the torsion angles are enough to describe the slow modes of the system ($\phi$ and $\psi$). Thus the relationship between the input features and the slow modes is trivial. In the following section we use distances between heavy atoms as a less trivial input feature set.
#
# ### Testing distances
#
# Here we use distances between heavy atoms as input features. The relationship between the input features and the slow modes now is less trivial.

# %%
# Choose the features to work with (torsions or distances)
features = 'distances'

# Load initial configuration
config_path = f"{data_folder}/alanine_dipeptide/input/{features}_config.yml"

with open(config_path, 'r') as file:
    configuration = yaml.load(file, Loader = yaml.FullLoader)

# Select model
configuration['train_colvars']['cvs'] = models

for batch_size in batch_sizes:

    # Name of the test
    test_name = f'bs_{batch_size}'

    # Make a copy of the initial configuration
    test_configuration = configuration.copy()

    # Update batch size
    test_configuration['train_colvars']['common']['training']['general']['batch_size'] = batch_size

    # Run deep cartograph
    run_deep_cartograph(test_configuration, features, temperature, test_name)
# Out:
# INFO:deep_cartograph:================
# INFO:deep_cartograph:Analyze geometry
# INFO:deep_cartograph:================
# INFO:deep_cartograph:Elapsed time (Analyze geometry): 00 h 00 min 00 s
# INFO:deep_cartograph:================
# INFO:deep_cartograph:Compute features
# INFO:deep_cartograph:================
# /home/pnavarro/.conda/envs/deep_cartograph/lib/python3.10/site-packages/MDAnalysis/topology/PDBParser.py:350: UserWarning: Element information is missing, elements attribute will not be populated. If needed these can be guessed using universe.guess_TopologyAttrs(context='default', to_guess=['elements']).
#   warnings.warn("Element information is missing, elements attribute "
# INFO:MDAnalysis.core.universe:attribute types has been guessed successfully.
# INFO:MDAnalysis.core.universe:attribute masses has been guessed successfully.
# /home/pnavarro/.conda/envs/deep_cartograph/lib/python3.10/site-packages/MDAnalysis/coordinates/PDB.py:1154: UserWarning: Found no information for attr: 'elements' Using default value of ' '
#   warnings.warn("Found no information for attr: '{}'"
# /home/pnavarro/.conda/envs/deep_cartograph/lib/python3.10/site-packages/MDAnalysis/coordinates/PDB.py:1154: UserWarning: Found no information for attr: 'formalcharges' Using default value of '0'
#   warnings.warn("Found no information for attr: '{}'"
# INFO:MDAnalysis.core.universe:attribute types has been guessed successfully.
# INFO:MDAnalysis.core.universe:attribute masses has been guessed successfully.
# WARNING:deep_cartograph.modules.md.md:Provided topology does not contain bonds. Bonds will be guessed using a distance criterion (bond_length < 2.0). Distances between bonded atoms will be excluded.
# WARNING:deep_cartograph.modules.md.md:Distances between atoms in the same residue or neighboring residues will be included. These are unlikely to contain relevant information. To exclude them use 'skip_neigh_residues: True'.
# INFO:MDAnalysis.core.universe:attribute types has been guessed successfully.
# INFO:MDAnalysis.core.universe:attribute masses has been guessed successfully.
# INFO:deep_cartograph:Computing features for trajectory with topology topology...
# /home/pnavarro/.conda/envs/deep_cartograph/lib/python3.10/site-packages/MDAnalysis/topology/PDBParser.py:350: UserWarning: Element information is missing, elements attribute will not be populated. If needed these can be guessed using universe.guess_TopologyAttrs(context='default', to_guess=['elements']).
#   warnings.warn("Element information is missing, elements attribute "
# INFO:MDAnalysis.core.universe:attribute types has been guessed successfully.
# INFO:MDAnalysis.core.universe:attribute masses has been guessed successfully.
# INFO:MDAnalysis.core.universe:attribute types has been guessed successfully.
# INFO:MDAnalysis.core.universe:attribute masses has been guessed successfully.
# INFO:deep_cartograph.modules.plumed.cli:Executing PLUMED command: plumed driver --plumed /home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/distances/bs_128/compute_features/trajectory/plumed_input.dat --mf_xtc /home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/input/500K/trajectory.xtc --natoms 22
# INFO:deep_cartograph.modules.plumed.cli:Restored working directory to: /home/pnavarro/repos/mlcolvar
# INFO:deep_cartograph:Elapsed time (Compute features): 00 h 00 min 00 s
# INFO:deep_cartograph:==================
# INFO:deep_cartograph:Filtering features
# INFO:deep_cartograph:==================
# INFO:deep_cartograph:Finding the features that contains the most information about the transitions or conformational changes.
# INFO:deep_cartograph:The following algorithms are available:
# INFO:deep_cartograph:- Hartigan's dip test filter. Keeps features that are not unimodal.
# INFO:deep_cartograph:- Shannon entropy filter. Keeps features with entropy greater than a threshold.
# INFO:deep_cartograph:- Standard deviation filter. Keeps features with standard deviation greater than a threshold.
# INFO:deep_cartograph:Note that the all features must be in the same units to apply the entropy and standard deviation filters meaningfully.
# INFO:deep_cartograph.modules.features.filter:Initializing Filter
# INFO:deep_cartograph.modules.features.filter:Initial size of features set (only common features): 36.
# INFO:deep_cartograph.modules.features.filter:Processed 3/36 features. Estimated time left: 0.75 seconds.
# INFO:deep_cartograph.modules.features.filter:Processed 6/36 features. Estimated time left: 0.68 seconds.
# INFO:deep_cartograph.modules.features.filter:Processed 9/36 features. Estimated time left: 0.61 seconds.
# INFO:deep_cartograph.modules.features.filter:Processed 12/36 features. Estimated time left: 0.57 seconds.
# INFO:deep_cartograph.modules.features.filter:Processed 15/36 features. Estimated time left: 0.49 seconds.
# INFO:deep_cartograph.modules.features.filter:Processed 18/36 features. Estimated time left: 0.42 seconds.
# INFO:deep_cartograph.modules.features.filter:Processed 21/36 features. Estimated time left: 0.35 seconds.
# INFO:deep_cartograph.modules.features.filter:Processed 24/36 features. Estimated time left: 0.28 seconds.
# INFO:deep_cartograph.modules.features.filter:Processed 27/36 features. Estimated time left: 0.21 seconds.
# INFO:deep_cartograph.modules.features.filter:Processed 30/36 features. Estimated time left: 0.14 seconds.
# INFO:deep_cartograph.modules.features.filter:Processed 33/36 features. Estimated time left: 0.07 seconds.
# INFO:deep_cartograph.modules.features.filter:Processed 36/36 features. Estimated time left: 0.00 seconds.
# INFO:deep_cartograph.modules.features.filter:Filtered 16 features.
# INFO:deep_cartograph:Elapsed time (Filter features): 00 h 00 min 00 s
# INFO:deep_cartograph.modules.common.common: Using features in /home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/distances/bs_128/filter_features/filtered_features.txt
# INFO:deep_cartograph:================================
# INFO:deep_cartograph:Training of Collective Variables
# INFO:deep_cartograph:================================
# INFO:deep_cartograph:Training of collective variables using the mlcolvar library.
# INFO:deep_cartograph.tools.train_colvars.train_colvars_workflow:Collective variables to compute: ['deep_tica']
# INFO:deep_cartograph.modules.cv_learning.cv_calculator:Creating DeepTICA Calculator ...
# INFO:deep_cartograph.modules.cv_learning.cv_calculator:Reading training data from colvars files...
# INFO:deep_cartograph.modules.cv_learning.cv_calculator:Number of features: 20
# INFO:deep_cartograph.modules.cv_learning.cv_calculator:Number of samples: 10001
# /home/pnavarro/repos/mlcolvar/mlcolvar/utils/timelagged.py:140: UserWarning: Monitoring the progress for the search of time-lagged configurations with a progress_bar requires `tqdm`.
#   warnings.warn(
# INFO:deep_cartograph.modules.cv_learning.cv_calculator:Training DeepTICA ...
# INFO:deep_cartograph.modules.cv_learning.cv_calculator:Model architecture: DeepTICA(
#   (loss_fn): ReduceEigenvaluesLoss()
#   (norm_in): Normalization(in_features=20, out_features=20, mode=custom)
#   (nn): FeedForward(
#     (nn): Sequential(
#       (0): Linear(in_features=20, out_features=8, bias=True)
#       (1): LeakyReLU(negative_slope=0.01, inplace=True)
#       (2): Linear(in_features=8, out_features=4, bias=True)
#       (3): LeakyReLU(negative_slope=0.01, inplace=True)
#       (4): Linear(in_features=4, out_features=1, bias=True)
#     )
#   )
#   (tica): TICA(in_features=1, out_features=1)
# )
# /home/pnavarro/.conda/envs/deep_cartograph/lib/python3.10/site-packages/lightning/fabric/plugins/environments/slurm.py:204: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/pnavarro/.conda/envs/deep_cartograph/lib/p ...
# INFO: GPU available: False, used: False
# INFO:lightning.pytorch.utilities.rank_zero:GPU available: False, used: False
# INFO: TPU available: False, using: 0 TPU cores
# INFO:lightning.pytorch.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO: HPU available: False, using: 0 HPUs
# INFO:lightning.pytorch.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:
#   | Name    | Type                  | Params | Mode  | In sizes | Out sizes
# ---------------------------------------------------------------------------------
# 0 | loss_fn | ReduceEigenvaluesLoss | 0      | train | ?        | ?
# 1 | norm_in | Normalization         | 0      | train | [1, 20]  | [1, 20]
# 2 | nn      | FeedForward           | 209    | train | [1, 20]  | [1, 1]
# 3 | tica    | TICA                  | 0      | train | [1, 1]   | [1, 1]
# ---------------------------------------------------------------------------------
# 209       Trainable params
# 0         Non-trainable params
# 209       Total params
# 0.001     Total estimated model params size (MB)
# 10        Modules in train mode
# 0         Modules in eval mode
# INFO:lightning.pytorch.callbacks.model_summary:
#   | Name    | Type                  | Params | Mode  | In sizes | Out sizes
# ---------------------------------------------------------------------------------
# 0 | loss_fn | ReduceEigenvaluesLoss | 0      | train | ?        | ?
# 1 | norm_in | Normalization         | 0      | train | [1, 20]  | [1, 20]
# 2 | nn      | FeedForward           | 209    | train | [1, 20]  | [1, 1]
# 3 | tica    | TICA                  | 0      | train | [1, 1]   | [1, 1]
# ---------------------------------------------------------------------------------
# 209       Trainable params
# 0         Non-trainable params
# 209       Total params
# 0.001     Total estimated model params size (MB)
# 10        Modules in train mode
# 0         Modules in eval mode
# INFO: `Trainer.fit` stopped: `max_epochs=100` reached.
# INFO:lightning.pytorch.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=100` reached.
# INFO:deep_cartograph.modules.cv_learning.cv_calculator:Successfully loaded the 'last' model from: /home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/distances/bs_128/train_colvars/deep_tica/training/checkpoints/last.ckpt
# INFO:deep_cartograph.modules.cv_learning.cv_calculator:  -> Best Overall Score:      -1.00965
# INFO:deep_cartograph.modules.cv_learning.cv_calculator:  -> Last Model Score:          -0.98512
# /home/pnavarro/repos/mlcolvar/mlcolvar/utils/plot.py:255: UserWarning: Data has no positive values, and therefore cannot be log-scaled.
#   ax.set_yscale(yscale)
# WARNING:deep_cartograph.modules.cv_learning.cv_calculator:Learning rate not found in metrics. Learning rate plot will not be generated.
# INFO:deep_cartograph.modules.cv_learning.cv_calculator:Took 99 epochs
# INFO:deep_cartograph.modules.cv_learning.cv_calculator:Eigenvalue 1: 0.9900119304656982
# INFO:deep_cartograph.modules.common.common:Starting compression to '/home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/distances/bs_128/train_colvars/deep_tica/training/training_metrics.zip'...
# INFO:deep_cartograph.modules.common.common:Successfully created zip file: '/home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/distances/bs_128/train_colvars/deep_tica/training/training_metrics.zip'
# INFO:deep_cartograph.modules.cv_learning.cv_calculator:Training metrics saved to /home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/distances/bs_128/train_colvars/deep_tica/training/training_metrics.zip
# INFO:deep_cartograph.modules.cv_learning.cv_calculator:Projecting data onto DeepTICA ...
# /home/pnavarro/.conda/envs/deep_cartograph/lib/python3.10/site-packages/MDAnalysis/topology/PDBParser.py:350: UserWarning: Element information is missing, elements attribute will not be populated. If needed these can be guessed using universe.guess_TopologyAttrs(context='default', to_guess=['elements']).
#   warnings.warn("Element information is missing, elements attribute "
# INFO:MDAnalysis.core.universe:attribute types has been guessed successfully.
# INFO:MDAnalysis.core.universe:attribute masses has been guessed successfully.
# /home/pnavarro/.conda/envs/deep_cartograph/lib/python3.10/site-packages/MDAnalysis/coordinates/PDB.py:1154: UserWarning: Found no information for attr: 'elements' Using default value of ' '
#   warnings.warn("Found no information for attr: '{}'"
# /home/pnavarro/.conda/envs/deep_cartograph/lib/python3.10/site-packages/MDAnalysis/coordinates/PDB.py:1154: UserWarning: Found no information for attr: 'formalcharges' Using default value of '0'
#   warnings.warn("Found no information for attr: '{}'"
# INFO:deep_cartograph.modules.common.common:Starting compression to '/home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/distances/bs_128/train_colvars/deep_tica/model.zip'...
# INFO:deep_cartograph.modules.common.common:Successfully created zip file: '/home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/distances/bs_128/train_colvars/deep_tica/model.zip'
# INFO:deep_cartograph.modules.cv_learning.cv_calculator:Model saved to /home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/distances/bs_128/train_colvars/deep_tica/model.zip
# KEY:  data
#
#
# KEY:  data_lag
#
#
# KEY:  weights
#
#
# KEY:  weights_lag
# INFO:deep_cartograph.tools.train_colvars.train_colvars_workflow:Processing trajectory: trajectory
# INFO:deep_cartograph.tools.train_colvars.train_colvars_workflow:Corresponding colvars file: /home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/distances/bs_128/compute_features/trajectory/colvars.dat
# INFO:deep_cartograph.tools.train_colvars.train_colvars_workflow:Corresponding topology file: /home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/input/topology.pdb
# /home/pnavarro/.conda/envs/deep_cartograph/lib/python3.10/site-packages/MDAnalysis/topology/PDBParser.py:350: UserWarning: Element information is missing, elements attribute will not be populated. If needed these can be guessed using universe.guess_TopologyAttrs(context='default', to_guess=['elements']).
#   warnings.warn("Element information is missing, elements attribute "
# INFO:MDAnalysis.core.universe:attribute types has been guessed successfully.
# INFO:MDAnalysis.core.universe:attribute masses has been guessed successfully.
# /home/pnavarro/.conda/envs/deep_cartograph/lib/python3.10/site-packages/MDAnalysis/coordinates/PDB.py:1154: UserWarning: Found no information for attr: 'elements' Using default value of ' '
#   warnings.warn("Found no information for attr: '{}'"
# /home/pnavarro/.conda/envs/deep_cartograph/lib/python3.10/site-packages/MDAnalysis/coordinates/PDB.py:1154: UserWarning: Found no information for attr: 'formalcharges' Using default value of '0'
#   warnings.warn("Found no information for attr: '{}'"
# INFO:MDAnalysis.core.universe:attribute types has been guessed successfully.
# INFO:MDAnalysis.core.universe:attribute masses has been guessed successfully.
# /home/pnavarro/.conda/envs/deep_cartograph/lib/python3.10/site-packages/MDAnalysis/topology/PDBParser.py:350: UserWarning: Element information is missing, elements attribute will not be populated. If needed these can be guessed using universe.guess_TopologyAttrs(context='default', to_guess=['elements']).
#   warnings.warn("Element information is missing, elements attribute "
# INFO:MDAnalysis.core.universe:attribute types has been guessed successfully.
# INFO:MDAnalysis.core.universe:attribute masses has been guessed successfully.
# INFO:deep_cartograph.modules.common.common:Starting compression to '/home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/distances/bs_128/train_colvars/deep_tica/traj_data/trajectory/plumed_inputs/plumed_deep_tica_unbiased.zip'...
# INFO:deep_cartograph.modules.common.common:Successfully created zip file: '/home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/distances/bs_128/train_colvars/deep_tica/traj_data/trajectory/plumed_inputs/plumed_deep_tica_unbiased.zip'
# INFO:MDAnalysis.core.universe:attribute types has been guessed successfully.
# INFO:MDAnalysis.core.universe:attribute masses has been guessed successfully.
# INFO:deep_cartograph.modules.common.common:Starting compression to '/home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/distances/bs_128/train_colvars/deep_tica/traj_data/trajectory/plumed_inputs/plumed_deep_tica_biased.zip'...
# INFO:deep_cartograph.modules.common.common:Successfully created zip file: '/home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/distances/bs_128/train_colvars/deep_tica/traj_data/trajectory/plumed_inputs/plumed_deep_tica_biased.zip'
# INFO:deep_cartograph:Elapsed time (Train colvars): 00 h 00 min 33 s
# INFO:deep_cartograph:Clustering trajectories in CV space: deep_tica
# INFO:deep_cartograph:=====================================
# INFO:deep_cartograph:Trajectory clustering on the CV space
# INFO:deep_cartograph:=====================================
# INFO:deep_cartograph:Clustering of trajectories using sklearn.
# INFO:deep_cartograph.tools.traj_cluster.traj_cluster_workflow:Starting traj_cluster workflow...
# INFO:deep_cartograph.modules.statistics.statistics:Best number of clusters: 4
# INFO:deep_cartograph.tools.traj_cluster.traj_cluster_workflow:Extracting centroids from the trajectories...
# INFO:deep_cartograph.tools.traj_cluster.traj_cluster_workflow:Extracting centroid for cluster 1 from trajectory trajectory.xtc at frame 24.
# /home/pnavarro/.conda/envs/deep_cartograph/lib/python3.10/site-packages/MDAnalysis/topology/PDBParser.py:350: UserWarning: Element information is missing, elements attribute will not be populated. If needed these can be guessed using universe.guess_TopologyAttrs(context='default', to_guess=['elements']).
#   warnings.warn("Element information is missing, elements attribute "
# INFO:MDAnalysis.core.universe:attribute types has been guessed successfully.
# INFO:MDAnalysis.core.universe:attribute masses has been guessed successfully.
# /home/pnavarro/.conda/envs/deep_cartograph/lib/python3.10/site-packages/MDAnalysis/coordinates/PDB.py:1154: UserWarning: Found no information for attr: 'elements' Using default value of ' '
#   warnings.warn("Found no information for attr: '{}'"
# /home/pnavarro/.conda/envs/deep_cartograph/lib/python3.10/site-packages/MDAnalysis/coordinates/PDB.py:1154: UserWarning: Found no information for attr: 'formalcharges' Using default value of '0'
#   warnings.warn("Found no information for attr: '{}'"
# INFO:deep_cartograph.tools.traj_cluster.traj_cluster_workflow:Extracting centroid for cluster 2 from trajectory trajectory.xtc at frame 2466.
# INFO:MDAnalysis.core.universe:attribute types has been guessed successfully.
# INFO:MDAnalysis.core.universe:attribute masses has been guessed successfully.
# INFO:deep_cartograph.tools.traj_cluster.traj_cluster_workflow:Extracting centroid for cluster 3 from trajectory trajectory.xtc at frame 4132.
# INFO:MDAnalysis.core.universe:attribute types has been guessed successfully.
# INFO:MDAnalysis.core.universe:attribute masses has been guessed successfully.
# INFO:deep_cartograph.tools.traj_cluster.traj_cluster_workflow:Extracting centroid for cluster 0 from trajectory trajectory.xtc at frame 5888.
# INFO:MDAnalysis.core.universe:attribute types has been guessed successfully.
# INFO:MDAnalysis.core.universe:attribute masses has been guessed successfully.
# INFO:deep_cartograph:Elapsed time (Train colvars): 00 h 00 min 25 s
# INFO:deep_cartograph:Total elapsed time: 00 h 01 min 00 s
# INFO:deep_cartograph:================
# INFO:deep_cartograph:Analyze geometry
# INFO:deep_cartograph:================
# INFO:deep_cartograph:Elapsed time (Analyze geometry): 00 h 00 min 00 s
# INFO:deep_cartograph:================
# INFO:deep_cartograph:Compute features
# INFO:deep_cartograph:================
# INFO:MDAnalysis.core.universe:attribute types has been guessed successfully.
# INFO:MDAnalysis.core.universe:attribute masses has been guessed successfully.
# INFO:MDAnalysis.core.universe:attribute types has been guessed successfully.
# INFO:MDAnalysis.core.universe:attribute masses has been guessed successfully.
# WARNING:deep_cartograph.modules.md.md:Provided topology does not contain bonds. Bonds will be guessed using a distance criterion (bond_length < 2.0). Distances between bonded atoms will be excluded.
# WARNING:deep_cartograph.modules.md.md:Distances between atoms in the same residue or neighboring residues will be included. These are unlikely to contain relevant information. To exclude them use 'skip_neigh_residues: True'.
# INFO:MDAnalysis.core.universe:attribute types has been guessed successfully.
# INFO:MDAnalysis.core.universe:attribute masses has been guessed successfully.
# INFO:deep_cartograph:Computing features for trajectory with topology topology...
# /home/pnavarro/.conda/envs/deep_cartograph/lib/python3.10/site-packages/MDAnalysis/topology/PDBParser.py:350: UserWarning: Element information is missing, elements attribute will not be populated. If needed these can be guessed using universe.guess_TopologyAttrs(context='default', to_guess=['elements']).
#   warnings.warn("Element information is missing, elements attribute "
# INFO:MDAnalysis.core.universe:attribute types has been guessed successfully.
# INFO:MDAnalysis.core.universe:attribute masses has been guessed successfully.
# INFO:MDAnalysis.core.universe:attribute types has been guessed successfully.
# INFO:MDAnalysis.core.universe:attribute masses has been guessed successfully.
# INFO:deep_cartograph.modules.plumed.cli:Executing PLUMED command: plumed driver --plumed /home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/distances/bs_2048/compute_features/trajectory/plumed_input.dat --mf_xtc /home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/input/500K/trajectory.xtc --natoms 22
# INFO:deep_cartograph.modules.plumed.cli:Restored working directory to: /home/pnavarro/repos/mlcolvar
# INFO:deep_cartograph:Elapsed time (Compute features): 00 h 00 min 00 s
# INFO:deep_cartograph:==================
# INFO:deep_cartograph:Filtering features
# INFO:deep_cartograph:==================
# INFO:deep_cartograph:Finding the features that contains the most information about the transitions or conformational changes.
# INFO:deep_cartograph:The following algorithms are available:
# INFO:deep_cartograph:- Hartigan's dip test filter. Keeps features that are not unimodal.
# INFO:deep_cartograph:- Shannon entropy filter. Keeps features with entropy greater than a threshold.
# INFO:deep_cartograph:- Standard deviation filter. Keeps features with standard deviation greater than a threshold.
# INFO:deep_cartograph:Note that the all features must be in the same units to apply the entropy and standard deviation filters meaningfully.
# INFO:deep_cartograph.modules.features.filter:Initializing Filter
# INFO:deep_cartograph.modules.features.filter:Initial size of features set (only common features): 36.
# INFO:deep_cartograph.modules.features.filter:Processed 3/36 features. Estimated time left: 0.75 seconds.
# INFO:deep_cartograph.modules.features.filter:Processed 6/36 features. Estimated time left: 0.68 seconds.
# INFO:deep_cartograph.modules.features.filter:Processed 9/36 features. Estimated time left: 0.61 seconds.
# INFO:deep_cartograph.modules.features.filter:Processed 12/36 features. Estimated time left: 0.54 seconds.
# INFO:deep_cartograph.modules.features.filter:Processed 15/36 features. Estimated time left: 0.48 seconds.
# INFO:deep_cartograph.modules.features.filter:Processed 18/36 features. Estimated time left: 0.41 seconds.
# INFO:deep_cartograph.modules.features.filter:Processed 21/36 features. Estimated time left: 0.34 seconds.
# INFO:deep_cartograph.modules.features.filter:Processed 24/36 features. Estimated time left: 0.27 seconds.
# INFO:deep_cartograph.modules.features.filter:Processed 27/36 features. Estimated time left: 0.20 seconds.
# INFO:deep_cartograph.modules.features.filter:Processed 30/36 features. Estimated time left: 0.14 seconds.
# INFO:deep_cartograph.modules.features.filter:Processed 33/36 features. Estimated time left: 0.07 seconds.
# INFO:deep_cartograph.modules.features.filter:Processed 36/36 features. Estimated time left: 0.00 seconds.
# INFO:deep_cartograph.modules.features.filter:Filtered 16 features.
# INFO:deep_cartograph:Elapsed time (Filter features): 00 h 00 min 00 s
# INFO:deep_cartograph.modules.common.common: Using features in /home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/distances/bs_2048/filter_features/filtered_features.txt
# INFO:deep_cartograph:================================
# INFO:deep_cartograph:Training of Collective Variables
# INFO:deep_cartograph:================================
# INFO:deep_cartograph:Training of collective variables using the mlcolvar library.
# INFO:deep_cartograph.tools.train_colvars.train_colvars_workflow:Collective variables to compute: ['deep_tica']
# INFO:deep_cartograph.modules.cv_learning.cv_calculator:Creating DeepTICA Calculator ...
# INFO:deep_cartograph.modules.cv_learning.cv_calculator:Reading training data from colvars files...
# INFO:deep_cartograph.modules.cv_learning.cv_calculator:Number of features: 20
# INFO:deep_cartograph.modules.cv_learning.cv_calculator:Number of samples: 10001
# /home/pnavarro/repos/mlcolvar/mlcolvar/utils/timelagged.py:140: UserWarning: Monitoring the progress for the search of time-lagged configurations with a progress_bar requires `tqdm`.
#   warnings.warn(
# INFO:deep_cartograph.modules.cv_learning.cv_calculator:Training DeepTICA ...
# INFO:deep_cartograph.modules.cv_learning.cv_calculator:Model architecture: DeepTICA(
#   (loss_fn): ReduceEigenvaluesLoss()
#   (norm_in): Normalization(in_features=20, out_features=20, mode=custom)
#   (nn): FeedForward(
#     (nn): Sequential(
#       (0): Linear(in_features=20, out_features=8, bias=True)
#       (1): LeakyReLU(negative_slope=0.01, inplace=True)
#       (2): Linear(in_features=8, out_features=4, bias=True)
#       (3): LeakyReLU(negative_slope=0.01, inplace=True)
#       (4): Linear(in_features=4, out_features=1, bias=True)
#     )
#   )
#   (tica): TICA(in_features=1, out_features=1)
# )
# /home/pnavarro/.conda/envs/deep_cartograph/lib/python3.10/site-packages/lightning/fabric/plugins/environments/slurm.py:204: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python3.10 /home/pnavarro/.conda/envs/deep_cartograph/lib/p ...
# INFO: GPU available: False, used: False
# INFO:lightning.pytorch.utilities.rank_zero:GPU available: False, used: False
# INFO: TPU available: False, using: 0 TPU cores
# INFO:lightning.pytorch.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO: HPU available: False, using: 0 HPUs
# INFO:lightning.pytorch.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:
#   | Name    | Type                  | Params | Mode  | In sizes | Out sizes
# ---------------------------------------------------------------------------------
# 0 | loss_fn | ReduceEigenvaluesLoss | 0      | train | ?        | ?
# 1 | norm_in | Normalization         | 0      | train | [1, 20]  | [1, 20]
# 2 | nn      | FeedForward           | 209    | train | [1, 20]  | [1, 1]
# 3 | tica    | TICA                  | 0      | train | [1, 1]   | [1, 1]
# ---------------------------------------------------------------------------------
# 209       Trainable params
# 0         Non-trainable params
# 209       Total params
# 0.001     Total estimated model params size (MB)
# 10        Modules in train mode
# 0         Modules in eval mode
# INFO:lightning.pytorch.callbacks.model_summary:
#   | Name    | Type                  | Params | Mode  | In sizes | Out sizes
# ---------------------------------------------------------------------------------
# 0 | loss_fn | ReduceEigenvaluesLoss | 0      | train | ?        | ?
# 1 | norm_in | Normalization         | 0      | train | [1, 20]  | [1, 20]
# 2 | nn      | FeedForward           | 209    | train | [1, 20]  | [1, 1]
# 3 | tica    | TICA                  | 0      | train | [1, 1]   | [1, 1]
# ---------------------------------------------------------------------------------
# 209       Trainable params
# 0         Non-trainable params
# 209       Total params
# 0.001     Total estimated model params size (MB)
# 10        Modules in train mode
# 0         Modules in eval mode
# INFO: `Trainer.fit` stopped: `max_epochs=100` reached.
# INFO:lightning.pytorch.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=100` reached.
# INFO:deep_cartograph.modules.cv_learning.cv_calculator:Successfully loaded the 'last' model from: /home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/distances/bs_2048/train_colvars/deep_tica/training/checkpoints/last.ckpt
# INFO:deep_cartograph.modules.cv_learning.cv_calculator:  -> Best Overall Score:      -0.81395
# INFO:deep_cartograph.modules.cv_learning.cv_calculator:  -> Last Model Score:          -0.81395
# /home/pnavarro/repos/mlcolvar/mlcolvar/utils/plot.py:255: UserWarning: Data has no positive values, and therefore cannot be log-scaled.
#   ax.set_yscale(yscale)
# WARNING:deep_cartograph.modules.cv_learning.cv_calculator:Learning rate not found in metrics. Learning rate plot will not be generated.
# INFO:deep_cartograph.modules.cv_learning.cv_calculator:Took 99 epochs
# INFO:deep_cartograph.modules.cv_learning.cv_calculator:Eigenvalue 1: 0.902191162109375
# INFO:deep_cartograph.modules.common.common:Starting compression to '/home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/distances/bs_2048/train_colvars/deep_tica/training/training_metrics.zip'...
# INFO:deep_cartograph.modules.common.common:Successfully created zip file: '/home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/distances/bs_2048/train_colvars/deep_tica/training/training_metrics.zip'
# INFO:deep_cartograph.modules.cv_learning.cv_calculator:Training metrics saved to /home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/distances/bs_2048/train_colvars/deep_tica/training/training_metrics.zip
# INFO:deep_cartograph.modules.cv_learning.cv_calculator:Projecting data onto DeepTICA ...
# /home/pnavarro/.conda/envs/deep_cartograph/lib/python3.10/site-packages/MDAnalysis/topology/PDBParser.py:350: UserWarning: Element information is missing, elements attribute will not be populated. If needed these can be guessed using universe.guess_TopologyAttrs(context='default', to_guess=['elements']).
#   warnings.warn("Element information is missing, elements attribute "
# INFO:MDAnalysis.core.universe:attribute types has been guessed successfully.
# INFO:MDAnalysis.core.universe:attribute masses has been guessed successfully.
# /home/pnavarro/.conda/envs/deep_cartograph/lib/python3.10/site-packages/MDAnalysis/coordinates/PDB.py:1154: UserWarning: Found no information for attr: 'elements' Using default value of ' '
#   warnings.warn("Found no information for attr: '{}'"
# /home/pnavarro/.conda/envs/deep_cartograph/lib/python3.10/site-packages/MDAnalysis/coordinates/PDB.py:1154: UserWarning: Found no information for attr: 'formalcharges' Using default value of '0'
#   warnings.warn("Found no information for attr: '{}'"
# INFO:deep_cartograph.modules.common.common:Starting compression to '/home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/distances/bs_2048/train_colvars/deep_tica/model.zip'...
# INFO:deep_cartograph.modules.common.common:Successfully created zip file: '/home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/distances/bs_2048/train_colvars/deep_tica/model.zip'
# INFO:deep_cartograph.modules.cv_learning.cv_calculator:Model saved to /home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/distances/bs_2048/train_colvars/deep_tica/model.zip
# KEY:  data
#
#
# KEY:  data_lag
#
#
# KEY:  weights
#
#
# KEY:  weights_lag
# INFO:deep_cartograph.tools.train_colvars.train_colvars_workflow:Processing trajectory: trajectory
# INFO:deep_cartograph.tools.train_colvars.train_colvars_workflow:Corresponding colvars file: /home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/distances/bs_2048/compute_features/trajectory/colvars.dat
# INFO:deep_cartograph.tools.train_colvars.train_colvars_workflow:Corresponding topology file: /home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/input/topology.pdb
# /home/pnavarro/.conda/envs/deep_cartograph/lib/python3.10/site-packages/MDAnalysis/topology/PDBParser.py:350: UserWarning: Element information is missing, elements attribute will not be populated. If needed these can be guessed using universe.guess_TopologyAttrs(context='default', to_guess=['elements']).
#   warnings.warn("Element information is missing, elements attribute "
# INFO:MDAnalysis.core.universe:attribute types has been guessed successfully.
# INFO:MDAnalysis.core.universe:attribute masses has been guessed successfully.
# /home/pnavarro/.conda/envs/deep_cartograph/lib/python3.10/site-packages/MDAnalysis/coordinates/PDB.py:1154: UserWarning: Found no information for attr: 'elements' Using default value of ' '
#   warnings.warn("Found no information for attr: '{}'"
# /home/pnavarro/.conda/envs/deep_cartograph/lib/python3.10/site-packages/MDAnalysis/coordinates/PDB.py:1154: UserWarning: Found no information for attr: 'formalcharges' Using default value of '0'
#   warnings.warn("Found no information for attr: '{}'"
# INFO:MDAnalysis.core.universe:attribute types has been guessed successfully.
# INFO:MDAnalysis.core.universe:attribute masses has been guessed successfully.
# /home/pnavarro/.conda/envs/deep_cartograph/lib/python3.10/site-packages/MDAnalysis/topology/PDBParser.py:350: UserWarning: Element information is missing, elements attribute will not be populated. If needed these can be guessed using universe.guess_TopologyAttrs(context='default', to_guess=['elements']).
#   warnings.warn("Element information is missing, elements attribute "
# INFO:MDAnalysis.core.universe:attribute types has been guessed successfully.
# INFO:MDAnalysis.core.universe:attribute masses has been guessed successfully.
# INFO:deep_cartograph.modules.common.common:Starting compression to '/home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/distances/bs_2048/train_colvars/deep_tica/traj_data/trajectory/plumed_inputs/plumed_deep_tica_unbiased.zip'...
# INFO:deep_cartograph.modules.common.common:Successfully created zip file: '/home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/distances/bs_2048/train_colvars/deep_tica/traj_data/trajectory/plumed_inputs/plumed_deep_tica_unbiased.zip'
# INFO:MDAnalysis.core.universe:attribute types has been guessed successfully.
# INFO:MDAnalysis.core.universe:attribute masses has been guessed successfully.
# INFO:deep_cartograph.modules.common.common:Starting compression to '/home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/distances/bs_2048/train_colvars/deep_tica/traj_data/trajectory/plumed_inputs/plumed_deep_tica_biased.zip'...
# INFO:deep_cartograph.modules.common.common:Successfully created zip file: '/home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/distances/bs_2048/train_colvars/deep_tica/traj_data/trajectory/plumed_inputs/plumed_deep_tica_biased.zip'
# INFO:deep_cartograph:Elapsed time (Train colvars): 00 h 00 min 06 s
# INFO:deep_cartograph:Clustering trajectories in CV space: deep_tica
# INFO:deep_cartograph:=====================================
# INFO:deep_cartograph:Trajectory clustering on the CV space
# INFO:deep_cartograph:=====================================
# INFO:deep_cartograph:Clustering of trajectories using sklearn.
# INFO:deep_cartograph.tools.traj_cluster.traj_cluster_workflow:Starting traj_cluster workflow...
# INFO:deep_cartograph.modules.statistics.statistics:Best number of clusters: 3
# INFO:deep_cartograph.tools.traj_cluster.traj_cluster_workflow:Extracting centroids from the trajectories...
# INFO:deep_cartograph.tools.traj_cluster.traj_cluster_workflow:Extracting centroid for cluster 2 from trajectory trajectory.xtc at frame 429.
# /home/pnavarro/.conda/envs/deep_cartograph/lib/python3.10/site-packages/MDAnalysis/topology/PDBParser.py:350: UserWarning: Element information is missing, elements attribute will not be populated. If needed these can be guessed using universe.guess_TopologyAttrs(context='default', to_guess=['elements']).
#   warnings.warn("Element information is missing, elements attribute "
# INFO:MDAnalysis.core.universe:attribute types has been guessed successfully.
# INFO:MDAnalysis.core.universe:attribute masses has been guessed successfully.
# /home/pnavarro/.conda/envs/deep_cartograph/lib/python3.10/site-packages/MDAnalysis/coordinates/PDB.py:1154: UserWarning: Found no information for attr: 'elements' Using default value of ' '
#   warnings.warn("Found no information for attr: '{}'"
# /home/pnavarro/.conda/envs/deep_cartograph/lib/python3.10/site-packages/MDAnalysis/coordinates/PDB.py:1154: UserWarning: Found no information for attr: 'formalcharges' Using default value of '0'
#   warnings.warn("Found no information for attr: '{}'"
# INFO:deep_cartograph.tools.traj_cluster.traj_cluster_workflow:Extracting centroid for cluster 1 from trajectory trajectory.xtc at frame 2309.
# INFO:MDAnalysis.core.universe:attribute types has been guessed successfully.
# INFO:MDAnalysis.core.universe:attribute masses has been guessed successfully.
# INFO:deep_cartograph.tools.traj_cluster.traj_cluster_workflow:Extracting centroid for cluster 0 from trajectory trajectory.xtc at frame 8999.
# INFO:MDAnalysis.core.universe:attribute types has been guessed successfully.
# INFO:MDAnalysis.core.universe:attribute masses has been guessed successfully.
# INFO:deep_cartograph:Elapsed time (Train colvars): 00 h 00 min 20 s
# INFO:deep_cartograph:Total elapsed time: 00 h 00 min 28 s

# %% [markdown]
# ### Testing batch size

# %%
# Show results for the Autoencoder, Variational Autoencoder and Deep TICA models with different batch sizes
for model in ['ae', 'vae', 'deep_tica']:
    
    print(f"Model: {model} ########################################################### #")
    
    for batch_size in batch_sizes:

        print(f"Batch size: {batch_size} ----------------------------------------------- #")

        # Test name
        test_name = f'bs_{batch_size}'

        # Show main results
        show_results(features, temperature, model, test_name)
# Out:
# Model: ae ########################################################### #
# Batch size: 128 ----------------------------------------------- #
# Output folder: /home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/distances/bs_128
# Phi psi path: /home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/input/500K/phi_psi.dat
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[19], line 14
#      11 test_name = f'bs_{batch_size}'
#      13 # Show main results
# ---> 14 show_results(features, temperature, model, test_name)
#
# Cell In[11], line 266, in show_results(features, temperature, model_name, test_name, phi_psi_path)
#     263         print("Eigenvalues file not found")
#     265 # Project CV onto Ramachandran space
# --> 266 ramachandran_projection(phi_psi_path, cv_path)
#     268 # Paths to images
#     269 loss = os.path.join(model_path, 'loss.png')
#
# Cell In[11], line 161, in show_results.<locals>.ramachandran_projection(phi_psi_path, cv_path)
#     158 phi_psi_df = phi_psi_df.drop(columns = ['time'])
#     160 # Read CV csv as pandas dataframe
# --> 161 cv_df = pd.read_csv(cv_path)
#     163 # Find model path
#     164 model_path = Path(cv_path).parent
#
# File ~/.conda/envs/deep_cartograph/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~/.conda/envs/deep_cartograph/lib/python3.10/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~/.conda/envs/deep_cartograph/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~/.conda/envs/deep_cartograph/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File ~/.conda/envs/deep_cartograph/lib/python3.10/site-packages/pandas/io/common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/distances/bs_128/train_colvars/ae/traj_data/trajectory/projected_trajectory.csv'

# %% [markdown]
# - The Autoencoder captures just the second slowest transition (the most frequent one) but not the slowest one, this behavior seems independent of the batch size.
#
# The autoencoder is discarding the slowest transition because it is not very well represented in the data.

# %% [markdown]
# - The Deep TICA model is able to capture all slow transitions from the data.
#
# We can see that when the relationship between the features and the slow modes is not trivial and one of the metastable states is underrepresented in the data, the Deep TICA model better at capturing the slow modes compared to the Autoencoder.

# %% [markdown]
# ### Training with very rare transitions
#
# The trajectory at 400 K shows contains less transitions between C5/C7eq and C7ax conformations. We can use this trajectory to further test the performance of the models when trained with very rare transitions.
#
# When using distances we saw that the Autoencoder was not able to capture the slowest transition which was underrepresented in the data. Using torsion angles though, the relation between the input features and the slow modes is trivial and the Autoencoder was able to capture the slowest transition. Let's see if this is still the case when the slowest transition is even more underrepresented in the data by switching to the 400 K trajectory.

# %%
# Choose the features to work with (torsions or distances)
features = 'torsions'

# Choose temperature of the simulations (300 K shows just one transition, 400 K starts to show two, 500 K clearly shows two transitions)
temperature = 400

# Load initial configuration
config_path = f"{data_folder}/alanine_dipeptide/input/{features}_config.yml"

with open(config_path, 'r') as file:
    configuration = yaml.load(file, Loader = yaml.FullLoader)

# Select model
configuration['train_colvars']['cvs'] = models

# Select batch size
batch_size = 128

# Name of the test
test_name = f'1D'

# Make a copy of the initial configuration
test_configuration = configuration.copy()

# Update configuration
test_configuration['train_colvars']['common']['training']['general']['batch_size'] = batch_size

# Run deep cartograph
run_deep_cartograph(test_configuration, features, temperature, test_name)
# Out:
# INFO:deep_cartograph:================
# INFO:deep_cartograph:Compute features
# INFO:deep_cartograph:================
# INFO:deep_cartograph:Trajectory file: ../../data/alanine_dipeptide/input/400K/trajectory.xtc
# /shared/work/pnavarro/envs/deep_cartograph/lib/python3.10/site-packages/MDAnalysis/topology/PDBParser.py:317: UserWarning: Element information is missing, elements attribute will not be populated. If needed these can be guessed using MDAnalysis.topology.guessers.
#   warnings.warn("Element information is missing, elements attribute "
# /shared/work/pnavarro/envs/deep_cartograph/lib/python3.10/site-packages/MDAnalysis/coordinates/PDB.py:1078: UserWarning: Found no information for attr: 'elements' Using default value of ' '
#   warnings.warn("Found no information for attr: '{}'"
# INFO:deep_cartograph.modules.md.md:Topology does not contain bonds. Bonds will be guessed using a distance criterion (bond_length < 2.0).
# WARNING:deep_cartograph.modules.md.md:Topology does not contain bonds. Using a distance criterion (bond_length < 2.0) to guess bonds.
# INFO:deep_cartograph.modules.plumed.input_file.input_file:Found 20 features for tor
# INFO:deep_cartograph.modules.plumed.utils:Executing PLUMED driver command: ml PLUMED/2.9.0-intel-2021b && unset I_MPI_PMI_LIBRARY && /eb/x86_64/software/PLUMED/2.9.0-intel-2021b/bin/plumed driver --plumed /shared/work/pnavarro/repos/deep_cartograph/data/alanine_dipeptide/output/400K/torsions/1D/compute_features_traj/torsions.dat --ixtc /shared/work/pnavarro/repos/deep_cartograph/data/alanine_dipeptide/input/400K/trajectory.xtc --natoms 22
# INFO:deep_cartograph:Elapsed time (Compute features): 00 h 00 min 01 s
# INFO:deep_cartograph:==================
# INFO:deep_cartograph:Filtering features
# INFO:deep_cartograph:==================
# INFO:deep_cartograph:Finding the features that contains the most information about the transitions or conformational changes.
# INFO:deep_cartograph:The following algorithms are available:
# INFO:deep_cartograph:- Hartigan's dip test filter. Keeps features that are not unimodal.
# INFO:deep_cartograph:- Shannon entropy filter. Keeps features with entropy greater than a threshold.
# INFO:deep_cartograph:- Standard deviation filter. Keeps features with standard deviation greater than a threshold.
# INFO:deep_cartograph:- Final Mutual information clustering (AMINO). Clusters filtered features according to a mutual information based distance and selects one feature per cluster minimizing the distorsion.
# INFO:deep_cartograph:Note that the all features must be in the same units to apply the entropy and standard deviation filters meaningfully.
# INFO:deep_cartograph:Initial size of features set: 20.
# INFO:deep_cartograph.tools.filter_features.filtering:Computing dip test.
# INFO:deep_cartograph.tools.filter_features.filtering:Filtered 12 features.
# INFO:deep_cartograph.modules.amino.amino:Skipping AMINO clustering.
# INFO:deep_cartograph:Elapsed time (Filter features): 00 h 00 min 00 s
# INFO:deep_cartograph:================================
# INFO:deep_cartograph:Training of Collective Variables
# INFO:deep_cartograph:================================
# INFO:deep_cartograph:Training of collective variables using the mlcolvar library.
# INFO:deep_cartograph:Creating datasets from colvars...
# INFO:deep_cartograph:Number of samples: 10001
# INFO:deep_cartograph:Number of features: 8
# /shared/work/pnavarro/envs/deep_cartograph/lib/python3.10/site-packages/mlcolvar/data/datamodule.py:133: UserWarning: A torch.generator was provided but it is not used with random_split=False
#   warnings.warn(
# INFO:deep_cartograph.tools.train_colvars.utils:Training Autoencoder CV...
# /shared/work/pnavarro/envs/deep_cartograph/lib/python3.10/site-packages/lightning/fabric/plugins/environments/slurm.py:204: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python /shared/work/pnavarro/envs/deep_cartograph/lib/pytho ...
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
#
#   | Name    | Type          | Params | Mode  | In sizes | Out sizes
# -------------------------------------------------------------------------
# 0 | loss_fn | MSELoss       | 0      | train | ?        | ?
# 1 | norm_in | Normalization | 0      | train | [1, 8]   | [1, 8]
# 2 | encoder | FeedForward   | 211    | train | [1, 8]   | [1, 1]
# 3 | decoder | FeedForward   | 218    | train | ?        | ?
# -------------------------------------------------------------------------
# 429       Trainable params
# 0         Non-trainable params
# 429       Total params
# 0.002     Total estimated model params size (MB)
# INFO:deep_cartograph.tools.train_colvars.utils:Best model score: 0.007702057249844074
# /shared/work/pnavarro/envs/deep_cartograph/lib/python3.10/site-packages/mlcolvar/core/nn/utils.py:13: TracerWarning: Converting a tensor to a Python number might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   sp0 = F.softplus(torch.zeros(1), self.beta, self.threshold).item()
# INFO:deep_cartograph.tools.train_colvars.utils:Projecting trajectory...
# /shared/work/pnavarro/envs/deep_cartograph/lib/python3.10/site-packages/mlcolvar/utils/timelagged.py:140: UserWarning: Monitoring the progress for the search of time-lagged configurations with a progress_bar requires `tqdm`.
#   warnings.warn(
# /shared/work/pnavarro/envs/deep_cartograph/lib/python3.10/site-packages/mlcolvar/data/datamodule.py:133: UserWarning: A torch.generator was provided but it is not used with random_split=False
#   warnings.warn(
# INFO:deep_cartograph.tools.train_colvars.utils:Calculating DeepTICA CV...
# /shared/work/pnavarro/envs/deep_cartograph/lib/python3.10/site-packages/lightning/fabric/plugins/environments/slurm.py:204: The `srun` command is available on your system but is not used. HINT: If your intention is to run Lightning on SLURM, prepend your python command with `srun` like so: srun python /shared/work/pnavarro/envs/deep_cartograph/lib/pytho ...
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
#
#   | Name    | Type                  | Params | Mode  | In sizes | Out sizes
# ---------------------------------------------------------------------------------
# 0 | loss_fn | ReduceEigenvaluesLoss | 0      | train | ?        | ?
# 1 | norm_in | Normalization         | 0      | train | [1, 8]   | [1, 8]
# 2 | nn      | FeedForward           | 211    | train | [1, 8]   | [1, 1]
# 3 | tica    | TICA                  | 0      | train | [1, 1]   | [1, 1]
# ---------------------------------------------------------------------------------
# 211       Trainable params
# 0         Non-trainable params
# 211       Total params
# 0.001     Total estimated model params size (MB)
# INFO:deep_cartograph.tools.train_colvars.utils:Best model score: -0.39250004291534424
# INFO:deep_cartograph.tools.train_colvars.utils:Took 257 epochs
# INFO:deep_cartograph.tools.train_colvars.utils:Eigenvalue 1: 0.6208598017692566
# /shared/work/pnavarro/envs/deep_cartograph/lib/python3.10/site-packages/mlcolvar/core/nn/utils.py:13: TracerWarning: Converting a tensor to a Python number might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   sp0 = F.softplus(torch.zeros(1), self.beta, self.threshold).item()
# INFO:deep_cartograph.tools.train_colvars.utils:Projecting trajectory...
# INFO:deep_cartograph:Elapsed time (Train colvars): 00 h 00 min 52 s
# INFO:deep_cartograph:Total elapsed time: 00 h 00 min 54 s

# %%
# Show results for both

# Name of the test
test_name = f'1D'

# Show results for the Autoencoder, Variational Autoencoder and Deep TICA models with different batch sizes
for model in models:
    
    print(f"Model: {model} ########################################################### #")

    # Show main results
    show_results(features, temperature, model, test_name)
# Out:
# Autoencoder ----------------------------------------------- #
# Output folder: /home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/distances/1D
# Phi psi path: /home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/input/500K/phi_psi.dat
# Score file not found
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[22], line 8
#       4 test_name = f'1D'
#       6 print("Autoencoder ----------------------------------------------- #")
# ----> 8 show_results(features, temperature, 'ae', test_name)
#      10 print("Deep TICA   ----------------------------------------------- #")
#      12 show_results(features, temperature, 'deep_tica', test_name)
#
# Cell In[5], line 265, in show_results(features, temperature, model_name, test_name, phi_psi_path)
#     262         print("Eigenvalues file not found")
#     264 # Project CV onto Ramachandran space
# --> 265 ramachandran_projection(phi_psi_path, cv_path)
#     267 # Paths to images
#     268 loss = os.path.join(model_path, 'loss.png')
#
# Cell In[5], line 160, in show_results.<locals>.ramachandran_projection(phi_psi_path, cv_path)
#     157 phi_psi_df = phi_psi_df.drop(columns = ['time'])
#     159 # Read CV csv as pandas dataframe
# --> 160 cv_df = pd.read_csv(cv_path)
#     162 # Find model path
#     163 model_path = Path(cv_path).parent
#
# File ~/.conda/envs/deep_cartograph/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~/.conda/envs/deep_cartograph/lib/python3.10/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~/.conda/envs/deep_cartograph/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~/.conda/envs/deep_cartograph/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File ~/.conda/envs/deep_cartograph/lib/python3.10/site-packages/pandas/io/common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/pnavarro/repos/NBDsoftware/deep_cartograph/deep_cartograph/data/alanine_dipeptide/output/500K/distances/1D/train_colvars/ae/traj_data/trajectory/projected_trajectory.csv'

# %% [markdown]
# We can see how the Deep TICA model is able to capture the slowest transition even when it is underrepresented in the data while the Autoencoder is not able to do so even when using torsion angles as input features.
#
# - When a metastable state is underrepresented in the data, the Deep TICA model will be able to identify the transition between the rare state and the rest more easily than the Autoencoder.

# %% [markdown]
# ### Training with scarce data
#
# What happens if we try to train the models with fewer and fewer data points? How small a trajectory can be to learn the slow modes effectively from it?
#
# Let's compare the performance of the models when trained with 10000, 5000, 2500, 1000, 300 and 150 points.
#
# Try to fine tune the hyper-parameters to make the training more resilient to scarce data. Two concepts are important here:
#
# #### Overfitting
#
# Overfitting refers to a model that memorizes the training data and generalizes poorly to new data. You can detect overfitting by comparing the training and validation losses. If the training loss is much lower than the validation loss, the model is overfitting. The less data we have the more difficult it will be for the model to generalize instead of memorizing the training data.
# Some strategies to avoid overfitting are:
#
# - Regularization: increase droupout, weight decay or adjust early stopping.
# - Reduce model complexity.
# - Reduce learning rate.
# - Use an Adam optimizer (it's the default one already but you may try AdamW).
# - Try with and without a learning rate scheduler (Adam optimizer already has a similar mechanism).
#
# #### Underfitting
#
# Underfitting refers to a model that is too simple to capture the underlying structure of the data. If the training loss is much higher than the validation loss and the model is not learning the slow modes, the model is underfitting. The less samples we have, the less represented some slow modes / movements will be in the data and the more difficult it will be for the models to capture them.
# Some strategies to avoid underfitting are:
#
# - Regularization: reduce dropout, weight decay or adjust early stopping.
# - Increase model complexity.
# - Increase learning rate.
# - Use a smaller batch size to introduce more noise in the gradient updates.
# - Try with Adam or AdamW optimizer.
# - Try with and without a learning rate scheduler.

# %%
from deep_cartograph.modules.md import extract_frames
from deep_cartograph.modules.common import write_as_csv
from sklearn.neighbors import NearestNeighbors
from sklearn.neighbors import KernelDensity

def sub_sample_data(df_path: str, num_samples: int):
    """
    Sub-sample data from a pandas dataframe trying to keep the same distribution as the original data
    using kernel density estimation, ensuring no repeated samples. The function returns the sub-sampled
    dataframe along with the original indices of the selected samples.

    Input
    -----

        df_path:     path to the csv file with the data
        num_samples: number of samples to keep
    """

    # Read the data
    df = read_colvars(df_path)

    # Estimate the joint distribution of the torsion angles
    kde = KernelDensity(kernel='gaussian', bandwidth=0.1).fit(df[['phi', 'psi']])

    # Initialize a list to hold the sub-sampled data
    sub_sampled_indices = []

    # Store the original dataframe indices
    original_df = df.copy()

    # Iteratively sample and remove used points
    for _ in range(min(num_samples, len(df))):

        # Sample one point from the estimated distribution
        sample = kde.sample(1)

        # Convert the sampled point to a DataFrame to preserve feature names
        sample_df = pd.DataFrame(sample, columns=['phi', 'psi'])

        # Find the nearest neighbor in the remaining original dataframe
        neigh = NearestNeighbors(n_neighbors=1, algorithm='ball_tree').fit(df[['phi', 'psi']])
        distances, indices = neigh.kneighbors(sample_df)

        # Get the index of the nearest neighbor
        closest_index = indices.flatten()[0]
    
        # Map this index back to the original dataframe's index
        original_index = df.index[closest_index]
        sub_sampled_indices.append(original_index)

        # Remove the selected sample from the original dataframe
        df = df.drop(index=original_index)

    # Sort the indices
    sub_sampled_indices.sort()

    # Create a new dataframe with the sub-sampled data
    sub_sampled_df = original_df.loc[sub_sampled_indices]

    # Check that all the samples are unique
    assert len(sub_sampled_df) == len(set(sub_sampled_df.index)), "Some samples are repeated!"

    # Check all the samples are in the original dataframe
    assert all([index in original_df.index for index in sub_sampled_df.index]), "Some samples are not in the original dataframe!"

    # Ensure that the indices match
    assert list(sub_sampled_df.index) == sub_sampled_indices, "The indices do not match!"

    return sub_sampled_df

def create_smaller_input(temperature: int, num_samples: int):
    """
    Create a smaller input for the alanine dipeptide simulations at a certain temperature
    by sub-sampling the phi psi data and extracting the corresponding frames from the trajectory.

    Input
    -----

        temperature:  temperature of the alanine dipeptide simulations
        num_samples:  number of samples to keep

    Output
    ------

        new_data_path: path to the new sub-sampled data (phi psi timeseries)
        new_traj_path: path to the new sub-sampled trajectory
    """

    # Path to original data
    phi_psi_path = f"{data_folder}/alanine_dipeptide/input/{temperature}K/phi_psi.dat"
    traj_path = f"{data_folder}/alanine_dipeptide/input/{temperature}K/trajectory.xtc"
    topology_path = f"{data_folder}/alanine_dipeptide/input/topology.pdb"

    # Read original data to get the number of samples
    phi_psi = read_colvars(phi_psi_path)
    original_num_samples = phi_psi.shape[0]

    # Sub-sample data if needed
    if num_samples >= original_num_samples:
        return phi_psi_path, traj_path
    else:
        phi_psi_df = sub_sample_data(phi_psi_path, num_samples)

    # Save sub-sampled data to a new file
    new_data_path = f"{data_folder}/alanine_dipeptide/input/{temperature}K/phi_psi_{num_samples}.dat"
    if os.path.exists(new_data_path):
        os.remove(new_data_path)
    write_as_csv(phi_psi_df, new_data_path)

    # Find list of frames corresponding to the sub-sampled data
    frames = list(phi_psi_df.index)   

    # Extract corresponding frames from the original trajectory and save them in a new trajectory
    new_traj_path = f"{data_folder}/alanine_dipeptide/input/{temperature}K/trajectory_{num_samples}.xtc"
    extract_frames(traj_path, topology_path, frames, new_traj_path)

    return new_data_path, new_traj_path

# %%
temperature = 400

# Choose the features to work with (torsions or distances)
features = 'torsions'

# Load initial configuration
config_path = f"{data_folder}/alanine_dipeptide/input/{features}_config.yml"
with open(config_path, 'r') as file:
    configuration = yaml.load(file, Loader = yaml.FullLoader)

# Select models to use
configuration['train_colvars']['cvs'] = models

###################
# COMMON SETTINGS #
###################
# These settings apply to all the models by default

# Architecture 
#  hidden layers
configuration['train_colvars']['common']['architecture']['encoder'] = [5, 5]         # [10, 10]
#  lag time
configuration['train_colvars']['common']['lag_time'] = 1                   # 1

# General
#  batch size
configuration['train_colvars']['common']['training']['general']['batch_size'] = 128        # 256   
#  maximum number of epochs
configuration['train_colvars']['common']['training']['general']['max_epochs'] = 10000      # 1000
#  length of training and validation sets
configuration['train_colvars']['common']['training']['general']['lengths'] = [0.8, 0.2]    # [0.8, 0.2]
#  dropout
configuration['train_colvars']['common']['training']['general']['dropout'] = 0.1           # 0.1

# Early stopping
#  patience
configuration['train_colvars']['common']['training']['early_stopping']['patience'] = 100   # 20 
#  min delta
configuration['train_colvars']['common']['training']['early_stopping']['min_delta'] = 1e-5 # 1e-5

# Optimizer 
#  name of the optimizer
configuration['train_colvars']['common']['training']['optimizer']['name'] = 'Adam'         # Adam
#  kwargs for the optimizer
kwargs = {'lr': 1e-5,                                                                      # 1e-3 
          'weight_decay': 0.01}                                                            # 0                                             
configuration['train_colvars']['common']['training']['optimizer']['kwargs'] = kwargs

###############
# AE SETTINGS #
###############
# These settings only apply to the Autoencoder model and are prioritized over the common settings

# Add AE settings to the configuration
configuration['train_colvars']['ae'] = {'dimension': 1, 'arquitecture': {}, 'training': {}}

# Architecture 
#  hidden layers
configuration['train_colvars']['ae']['architecture'] = {'encoder': [10, 10]}

# General
#  batch size and max epochs
configuration['train_colvars']['ae']['training']['general'] = {'batch_size': 128, 'max_epochs': 10000}

# Early stopping
#  patience
configuration['train_colvars']['ae']['training'] = {'early_stopping': {'patience': 100, 'min_delta': 1e-5}}

# Optimizer 
#  name of the optimizer
configuration['train_colvars']['ae']['training'] = {'optimizer' : {'name' : 'Adam'}}
#  kwargs for the optimizer
kwargs = {'lr': 1e-2,           
          'weight_decay': 0}
configuration['train_colvars']['ae']['training']['optimizer']['kwargs'] = kwargs

# Train the models with decreasing number of samples
num_samples = [10000, 5000, 2500, 1000, 300] 

for ns in num_samples:

    # Create smaller input
    new_data_path, new_traj_path = create_smaller_input(temperature, ns)

    # Name of the test
    test_name = f'samples_{ns}'

    # Run deep cartograph
    run_deep_cartograph(configuration, features, temperature, test_name, new_traj_path)

# %%
# Show results for the Autoencoder

for ns in num_samples:

    print(f"Number of samples: {ns}")

    # Name of the test
    test_name = f'samples_{ns}'

    new_phi_psi_path = f"{data_folder}/alanine_dipeptide/input/{temperature}K/phi_psi_{ns}.dat"

    # Show main results
    show_results(features, temperature, 'ae', test_name, new_phi_psi_path)
# Out:
# Number of samples: 5000
# Output folder: ../../data/alanine_dipeptide/output/400K/torsions/samples_5000
# Phi psi path: ../../data/alanine_dipeptide/input/400K/phi_psi_5000.dat
# Final model score: 5.4920E-3
# <img src="../../data/alanine_dipeptide/output/400K/torsions/samples_5000/train_colvars/ae/AE 1_ramachandran.png?1724913715" style="width: 600px; margin-right: 10px;">
# <img src="../../data/alanine_dipeptide/output/400K/torsions/samples_5000/train_colvars/ae/loss.png?1724913716" style="width: 600px; margin-right: 10px;">
# Number of samples: 2500
# Output folder: ../../data/alanine_dipeptide/output/400K/torsions/samples_2500
# Phi psi path: ../../data/alanine_dipeptide/input/400K/phi_psi_2500.dat
# Final model score: 6.0684E-3
# <img src="../../data/alanine_dipeptide/output/400K/torsions/samples_2500/train_colvars/ae/AE 1_ramachandran.png?1724913716" style="width: 600px; margin-right: 10px;">
# <img src="../../data/alanine_dipeptide/output/400K/torsions/samples_2500/train_colvars/ae/loss.png?1724913716" style="width: 600px; margin-right: 10px;">
# Number of samples: 1000
# Output folder: ../../data/alanine_dipeptide/output/400K/torsions/samples_1000
# Phi psi path: ../../data/alanine_dipeptide/input/400K/phi_psi_1000.dat
# Final model score: 5.7844E-3
# <img src="../../data/alanine_dipeptide/output/400K/torsions/samples_1000/train_colvars/ae/AE 1_ramachandran.png?1724913716" style="width: 600px; margin-right: 10px;">
# <img src="../../data/alanine_dipeptide/output/400K/torsions/samples_1000/train_colvars/ae/loss.png?1724913716" style="width: 600px; margin-right: 10px;">
# Number of samples: 300
# Output folder: ../../data/alanine_dipeptide/output/400K/torsions/samples_300
# Phi psi path: ../../data/alanine_dipeptide/input/400K/phi_psi_300.dat
# Final model score: 5.5341E-3
# <img src="../../data/alanine_dipeptide/output/400K/torsions/samples_300/train_colvars/ae/AE 1_ramachandran.png?1724913716" style="width: 600px; margin-right: 10px;">
# <img src="../../data/alanine_dipeptide/output/400K/torsions/samples_300/train_colvars/ae/loss.png?1724913716" style="width: 600px; margin-right: 10px;">

# %% [markdown]
# From the tests we can observe that the Autoencoder is more prone to underfitting in this dataset. Results can be improved with respect to the default hyper-parameters by using a smaller batch size, a larger initial learning rate combined with a learning rate scheduler.

# %%
# Show results for the Deep TICA model

for ns in num_samples:

    print(f"Number of samples: {ns}")

    # Name of the test
    test_name = f'samples_{ns}'

    new_phi_psi_path = f"{data_folder}/alanine_dipeptide/input/{temperature}K/phi_psi_{ns}.dat"

    # Show main results
    show_results(features, temperature, 'deep_tica', test_name, new_phi_psi_path)
# Out:
# Number of samples: 5000
# Output folder: ../../data/alanine_dipeptide/output/400K/torsions/samples_5000
# Phi psi path: ../../data/alanine_dipeptide/input/400K/phi_psi_5000.dat
# Final model score: -2.0288E-1
# Eigenvalue 0: 4.4708E-1
# <img src="../../data/alanine_dipeptide/output/400K/torsions/samples_5000/train_colvars/deep_tica/DeepTIC 1_ramachandran.png?1724913742" style="width: 600px; margin-right: 10px;">
# <img src="../../data/alanine_dipeptide/output/400K/torsions/samples_5000/train_colvars/deep_tica/loss.png?1724913743" style="width: 600px; margin-right: 10px;"><img src="../../data/alanine_dipeptide/output/400K/torsions/samples_5000/train_colvars/deep_tica/eigenvalues.png?1724913743" style="width: 600px; margin-right: 10px;">
# Number of samples: 2500
# Output folder: ../../data/alanine_dipeptide/output/400K/torsions/samples_2500
# Phi psi path: ../../data/alanine_dipeptide/input/400K/phi_psi_2500.dat
# Final model score: -1.3231E-1
# Eigenvalue 0: 3.4503E-1
# <img src="../../data/alanine_dipeptide/output/400K/torsions/samples_2500/train_colvars/deep_tica/DeepTIC 1_ramachandran.png?1724913743" style="width: 600px; margin-right: 10px;">
# <img src="../../data/alanine_dipeptide/output/400K/torsions/samples_2500/train_colvars/deep_tica/loss.png?1724913743" style="width: 600px; margin-right: 10px;"><img src="../../data/alanine_dipeptide/output/400K/torsions/samples_2500/train_colvars/deep_tica/eigenvalues.png?1724913743" style="width: 600px; margin-right: 10px;">
# Number of samples: 1000
# Output folder: ../../data/alanine_dipeptide/output/400K/torsions/samples_1000
# Phi psi path: ../../data/alanine_dipeptide/input/400K/phi_psi_1000.dat
# Final model score: -3.9621E-2
# Eigenvalue 0: 1.9905E-1
# <img src="../../data/alanine_dipeptide/output/400K/torsions/samples_1000/train_colvars/deep_tica/DeepTIC 1_ramachandran.png?1724913743" style="width: 600px; margin-right: 10px;">
# <img src="../../data/alanine_dipeptide/output/400K/torsions/samples_1000/train_colvars/deep_tica/loss.png?1724913744" style="width: 600px; margin-right: 10px;"><img src="../../data/alanine_dipeptide/output/400K/torsions/samples_1000/train_colvars/deep_tica/eigenvalues.png?1724913744" style="width: 600px; margin-right: 10px;">
# Number of samples: 300
# Output folder: ../../data/alanine_dipeptide/output/400K/torsions/samples_300
# Phi psi path: ../../data/alanine_dipeptide/input/400K/phi_psi_300.dat
# Final model score: -1.6460E-2
# Eigenvalue 0: 1.2829E-1
# <img src="../../data/alanine_dipeptide/output/400K/torsions/samples_300/train_colvars/deep_tica/DeepTIC 1_ramachandran.png?1724913744" style="width: 600px; margin-right: 10px;">
# <img src="../../data/alanine_dipeptide/output/400K/torsions/samples_300/train_colvars/deep_tica/loss.png?1724913744" style="width: 600px; margin-right: 10px;"><img src="../../data/alanine_dipeptide/output/400K/torsions/samples_300/train_colvars/deep_tica/eigenvalues.png?1724913744" style="width: 600px; margin-right: 10px;">

# %% [markdown]
# The Deep TICA model is more prone to overfitting than the Autoencoder in this dataset. Results can be improved by using a smaller initial learning rate, adding weight decay and using a simpler model.
